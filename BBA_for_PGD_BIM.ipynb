# %% [markdown]
# # Kaggle installation

# %% [markdown]
# These are steps to be followed to import the kaggle dataset to the colab runspace

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 3.2 MB/s
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=37b3c8687291b0970d5a0a383e7cf0f0efa6c5a2637f43e48611a8aad57ec36c
#   Stored in directory: /root/.cache/pip/wheels/62/d6/58/5853130f941e75b2177d281eb7e44b4a98ed46dd155f556dc5
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# Successfully installed kaggle-1.5.12

# %% [markdown]
# Download the kaggle.json api token from your kaggle account and upload here

# %%
#download kaggle.json from your account from create new api token
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-974c1a3b-74df-496d-b65a-149eb162b34d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-974c1a3b-74df-496d-b65a-149eb162b34d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"pranavaramanbms","key":"34b741a6073b028c2af6dac99de176e4"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download sovitrath/diabetic-retinopathy-2015-data-colored-resized
# Out:
# Downloading diabetic-retinopathy-2015-data-colored-resized.zip to /content
# 100% 1.94G/1.94G [00:08<00:00, 247MB/s]
# 100% 1.94G/1.94G [00:08<00:00, 250MB/s]

# %% [markdown]
# Exporting the files from the dataset.

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "/content/diabetic-retinopathy-2015-data-colored-resized.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    #zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %% [markdown]
# # Imports & model import

# %%
import os
import numpy as np
import tensorflow as tf
import math
from tensorflow.keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array, save_img
from tensorflow.keras.models import load_model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import random
import cv2
import pandas as pd

# %% [markdown]
# **Mount your google drive**
#
# * Create a shortcut to the model file to your desired location on your Drive
# * Import the file from the drive using the given code
#
# [Click here to get the model file](https://drive.google.com/file/d/1S-NrS5h4jG_OkuEt7dqUhKj6dlHD7viO/view?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!cp $from_location $to_location

# !cp '/content/drive/MyDrive/Colab Notebooks/Models/vgg16_Model_Retinopathy_new_new.zip' 'original_model.zip'

# %% [markdown]
# **Model Details**
#
# Model Courtesy: Team - Sreeratcha and Preeti Krishnaveni
#
# * This is a binary_classification model trained using transfer-learning of "VGG16" to the current requirement
# * This model has a training accuracy of: 87% and testing accuracy of: 65%
# * for an almost balanced dataset of 13.5k images
#
# ![image.png](data:image/png;base64,...)

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "original_model.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# saved_model/                                   2021-06-24 04:10:24            0
# saved_model/vgg16_Model_Retinopathy_new_new/   2021-06-24 04:10:26            0
# saved_model/vgg16_Model_Retinopathy_new_new/variables/ 2021-06-24 04:10:26            0
# saved_model/vgg16_Model_Retinopathy_new_new/variables/variables.data-00000-of-00001 2021-06-24 04:10:26    367178332
# saved_model/vgg16_Model_Retinopathy_new_new/variables/variables.index 2021-06-24 04:10:26         3191
# saved_model/vgg16_Model_Retinopathy_new_new/assets/ 2021-06-24 04:10:26            0
# saved_model/vgg16_Model_Retinopathy_new_new/keras_metadata.pb 2021-06-24 04:10:26        53570
# saved_model/vgg16_Model_Retinopathy_new_new/saved_model.pb 2021-06-24 04:10:26       377406
# Extracting all the files now...
# Done!

# %% [markdown]
# # Model Loading

# %%
#set the location to your model's location
model_location = 'saved_model/vgg16_Model_Retinopathy_new_new'

from tensorflow.keras.models import load_model
model = load_model(model_location)
model.trainable = False

# %%
#change to your model's input img_size
img_size = 224 

# custom-preprocessing function
def preprocessing_image(data):
    img_resize = cv2.resize(data, dsize=(img_size, img_size))
    image = np.array(img_resize, dtype='float32')
    image = tf.expand_dims(image,0)
    return image

#function that returns the predicted value
def prediction(data):
    value = model.predict(data)   
    return value[0][0]

# %%
#checking if the model works

image_location = 'colored_images/colored_images/Proliferate_DR/10017_left.png'

image = cv2.imread(image_location)
plt.imshow(image)
image = preprocessing_image(image)
plt.show()
pred = prediction(image)
print(pred)
# Out:
# 0.6380057

# %% [markdown]
# # Attacker's model Creation

# %% [markdown]
# ## datageneration

# %% [markdown]
# Data that the attacker has

# %%
img = [] #create a list of (image, prediction_label)
i=0
for data in os.listdir('colored_images/colored_images/No_DR'):
        img_d = cv2.imread('colored_images/colored_images/No_DR/{}'.format(data))
        img_d = preprocessing_image(img_d)
        pred = prediction(img_d)  #get the prediction from the original model

        y_val = 0
        if pred>0.5:
          y_val = 1   #change the label

        img.append([img_d, y_val])    #append the image along with label in the list
        i+=1
        if i>=1000:
          break

#do it for all classes (1000 for No_DR), (250 each for other 4)

# %%
i=0
for data in os.listdir('colored_images/colored_images/Mild'):
        img_d = cv2.imread('colored_images/colored_images/Mild/{}'.format(data))
        img_d = preprocessing_image(img_d)
        pred = prediction(img_d)

        y_val = 0
        if pred>0.5:
          y_val = 1
          
        img.append([img_d, y_val])
        i+=1
        if i>=250:
          break


i=0
for data in os.listdir('colored_images/colored_images/Moderate'):
        img_d = cv2.imread('colored_images/colored_images/Moderate/{}'.format(data))
        img_d = preprocessing_image(img_d)
        pred = prediction(img_d)

        y_val = 0
        if pred>0.5:
          y_val = 1
          
        img.append([img_d, y_val])
        i+=1
        if i>=250:
          break

i=0
for data in os.listdir('colored_images/colored_images/Proliferate_DR'):
        img_d = cv2.imread('colored_images/colored_images/Proliferate_DR/{}'.format(data))
        img_d = preprocessing_image(img_d)
        pred = prediction(img_d)

        y_val = 0
        if pred>0.5:
          y_val = 1
          
        img.append([img_d, y_val])
        i+=1
        if i>=250:
          break

i=0
for data in os.listdir('colored_images/colored_images/Severe'):
        img_d = cv2.imread('colored_images/colored_images/Severe/{}'.format(data))
        img_d = preprocessing_image(img_d)
        pred = prediction(img_d)

        y_val = 0
        if pred>0.5:
          y_val = 1
          
        img.append([img_d, y_val])
        i+=1
        if i>=250:
          break

# %%
img = np.array(img, dtype=object)
img[0][1]
# Out:
# 0

# %%
plt.hist(img[:,1].astype('int'))
plt.title('No. of images in each classes as per prediction by original model(0=NO_DR, 1=DR)')
plt.xlabel('label')
plt.ylabel('images')
plt.show()

# %% [markdown]
# ## dataset separation

# %%
import random
from sklearn.model_selection import train_test_split
random.shuffle(img)
X_img = []
Y_lab = []
for data in img:
    X_img.append(data[0][0])
    Y_lab.append(data[1])

X_arr_img = np.array(X_img)

X_train, X_test, Y_train, Y_test = train_test_split(X_arr_img, Y_lab, test_size=0.2)

X_train = np.array(X_train)
X_test = np.array(X_test)
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1600, 224, 224, 3)
# (400, 224, 224, 3)
# (1600,)
# (400,)

# %% [markdown]
# ## attacker's model creation

# %%
from tensorflow.keras.applications.vgg16 import VGG16

def vgg16_new_model(base_model):
  x = layers.Flatten()(base_model.output)
  x = layers.Dense(1024, activation='relu')(x)
  x = layers.Dropout(0.2)(x)
  x = layers.Dense(1, activation='sigmoid')(x)
  model = tf.keras.models.Model(base_model.input, x)
  return model

base_model = VGG16(input_shape = (img_size, img_size, 3), include_top = False, weights = 'imagenet')
for layer in base_model.layers:
    layer.trainable = False

new_model = vgg16_new_model(base_model)
new_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 40,406,849
# Trainable params: 25,692,161
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
new_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics = ['accuracy'])

# %%
history_new = new_model.fit(X_train,Y_train,
                    epochs=5,
                    validation_data=(X_test,Y_test),
                    verbose=1)
# Out:
# Epoch 1/5
# 50/50 [==============================] - 42s 535ms/step - loss: 10.4428 - accuracy: 0.6994 - val_loss: 3.3697 - val_accuracy: 0.7700
# Epoch 2/5
# 50/50 [==============================] - 19s 376ms/step - loss: 1.4941 - accuracy: 0.8338 - val_loss: 0.9472 - val_accuracy: 0.8325
# Epoch 3/5
# 50/50 [==============================] - 19s 377ms/step - loss: 0.2419 - accuracy: 0.9406 - val_loss: 0.7785 - val_accuracy: 0.8400
# Epoch 4/5
# 50/50 [==============================] - 19s 376ms/step - loss: 0.0831 - accuracy: 0.9731 - val_loss: 0.6773 - val_accuracy: 0.8700
# Epoch 5/5
# 50/50 [==============================] - 19s 377ms/step - loss: 0.0485 - accuracy: 0.9862 - val_loss: 0.6760 - val_accuracy: 0.8600

# %%
plt.plot(history_new.history['accuracy'], label='accuracy')
plt.plot(history_new.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
plt.plot(history_new.history['loss'], label='loss')
plt.plot(history_new.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
y_pred = new_model.predict(X_test)
y = []
for i,d in enumerate(y_pred):
  if d[0] <= 0.5:
    y.append(0)
  else:
    y.append(1)

# %%
from sklearn.metrics import confusion_matrix, classification_report
conf_mat = confusion_matrix(Y_test, y)
print(conf_mat)
# Out:
# [[248  23]
#  [ 33  96]]

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

binary1 = np.array(conf_mat)

fig, ax = plot_confusion_matrix(conf_mat=binary1)
plt.title('Confusion matrix for the new_model on the validation dataset')
plt.show()

# %%
# !mkdir -p attack_model
new_model.save('attack_model/vgg16_Retinopathy_attacker')
# Out:
# INFO:tensorflow:Assets written to: attack_model/vgg16_Retinopathy_attacker/assets

# %%
# !zip -r ./vgg16_Retinopathy_attacker.zip ./attack_model/
# Out:
#   adding: attack_model/ (stored 0%)
#   adding: attack_model/vgg16_Retinopathy_attacker/ (stored 0%)
#   adding: attack_model/vgg16_Retinopathy_attacker/variables/ (stored 0%)
#   adding: attack_model/vgg16_Retinopathy_attacker/variables/variables.index (deflated 67%)
#   adding: attack_model/vgg16_Retinopathy_attacker/variables/variables.data-00000-of-00001 (deflated 31%)
#   adding: attack_model/vgg16_Retinopathy_attacker/assets/ (stored 0%)
#   adding: attack_model/vgg16_Retinopathy_attacker/keras_metadata.pb (deflated 95%)
#   adding: attack_model/vgg16_Retinopathy_attacker/saved_model.pb (deflated 90%)

# %%
# !cp vgg16_Retinopathy_attacker.zip 'drive/MyDrive/models/vgg16__Retinopathy_attacker_model.zip'

# %% [markdown]
# # PGD ATTACK

# %% [markdown]
# This function computes the L-2 Norm of the given matrix
#
#
# ---
#
#
#
# *   First it converts the 3d matrix into a 1d array
# *   Then it performs L-2 norm where
# ![l2norm.png](data:image/png;base64,...)
# *   Then the normalized output is returned

# %%
def l2_norm(z):
    """Compute norms over all but the first dimension"""

    mat = z.numpy()
    mat = mat.reshape((mat.shape[0], -1))
    out = np.linalg.norm(mat, ord=2)
    return out

    # The pytorch version of the code
    # return Z.view(Z.shape[0], -1).norm(dim=1)[:,None,None,None]

# %% [markdown]
#  **PGD Function**
#
# The PGD used here is an iterative version of ‘Normalized Steepest Gradient Descent’. It perturbs a normal example x for a number of steps with the step size α being set between ϵ /T to ϵ. Here again we have made the model to iterate till it’s loss reaches a certain value
#
# **Repeat:**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Some of the references used while creating this PGD are listed below:
# * [Adversarial Examples, solving the inner maximization](https://adversarial-ml-tutorial.org/adversarial_examples/)
#  - This helped us understand PGD much better and implemented in a better way
# * [Understanding Adversarial Attacks on Deep Learning Based
# Medical Image Analysis Systems](https://arxiv.org/pdf/1907.10456.pdf)

# %% [markdown]
# **The inner_pgd function returns the delta after one step**
#
# The normalized steepest descent method has been used to find the noise to be
# added to the the image.
#
# In contrast to Fast Gradient Sign Method, where
# ```
# delta = alpha * tf.sign(grad)
# ```
#
# We are us
# ```
# delta = alpha  * (grad/l2_norm(grad))
# ```

# %%
def inner_pgd(x, y_adv, alpha):
    loss_func = tf.keras.losses.BinaryCrossentropy()
    with tf.GradientTape() as gt:
        gt.watch(x)
        
        label = new_model(x)
        loss = loss_func(y_adv, label)
        outputloss = loss.numpy()
        #print (loss)
        
    grad = gt.gradient(loss, x)


    norm_grad = l2_norm(grad)
    #here it is an implementation of normalized steepest descent
    if norm_grad:
      delta = alpha  * (grad/norm_grad)
    else:
      delta = alpha * tf.sign(grad)

    return delta, outputloss

# %% [markdown]
# **Projection function:**
#
# ![image.png](data:image/png;base64,...)
#
# This particular projection function was mentioned in this article:
#
# [Source](https://adversarial-ml-tutorial.org/adversarial_examples/)

# %%
def projection(x, eps):
  norm_x = l2_norm(x)
  out = eps * (x / np.maximum(eps, norm_x))*255
  
  #here we found that the output value is very less because the value 
  #becomes in the range of 0 to 1 while the image is in the range of 0-255
  #so the output is multiplied with 255

  return out

# %% [markdown]
# In contrast with many places where the number of iterations for the PGD is already given,
#
# here the iteration goes on until the loss for the given image and desired target becomes lesser that a certain threshold (in this case 0.5), the attack stops
#
# Of course, this is not always the desirable way to do, as there is no fixed timeline for the attack to finish.
#
# On our experiences usualy an image takes about 6-7 iterations

# %%
def PGD(x, y_adv, eps):

  # attack changes from BIM to Madry's PGD
  delta = np.random.uniform(-eps,eps,x.shape)
  x = x+delta

  alpha = eps/10

  itr = 0

  while 1:
    noise, loss = inner_pgd(x, y_adv,alpha)
    #noise_new = tf.clip_by_value(x-noise-img, -eps, eps)
    noise_new = projection(noise , eps)
    x = x - noise_new
    #x = projection(x, eps)
    #print(x)

    #preds = new_model.predict(x)
    #print(preds)

    itr+=1
    if loss<1e-5 or itr>=10:
      break

  return x, itr

# %% [markdown]
# ## creation of perturbed data
#
# Here we will see an example of how the image is affected by the adversarial attack

# %% [markdown]
# **Create_Perturb**
#
# This function takes in the image details and target value (to which the image has to change to) and saves the perturbed image in the given destination.

# %%
def create_perturb_pgd(old_img, image_name, tofolder, y_val):
  #old_img = cv2.imread(fromfolder+'/'+image_name)
  old_img = preprocessing_image(old_img)

  #actual prediction by the model
  preds = new_model.predict(old_img)
  print("The prediction of the image before attack: ", preds)

  #y_val = 0
    
  #if preds[0][0]<0.5:
    #y_val = 1
    
  #target value
  y_adv_label = y_val
  y_adv = tf.reshape(y_adv_label, shape=[1, preds.shape[-1]])


  #adverserial image


  x_adv, itrs = PGD(old_img, y_adv, 1.4)

  #here noise is calculated to display it, it is not necessary to show the noise
  #noise = x_adv - img
  #plt.imshow(noise[0])
  #plt.show()


  #prediction by the model after adversarial attack
  newpreds = new_model.predict(x_adv)
  print("The prediction of the image after %d iterations of PGD attack: %f" % ( itrs, newpreds[0][0]))

  #saving image to the destination
  save_img(tofolder+'/'+image_name, x_adv[0])

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/Models/vgg16__Retinopathy_attacker_model.zip' vgg16_retinopathy_attacker.zip

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "vgg16_retinopathy_attacker.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# attack_model/                                  2021-06-29 13:17:16            0
# attack_model/vgg16_Retinopathy_attacker/       2021-06-29 15:18:30            0
# attack_model/vgg16_Retinopathy_attacker/saved_model.pb 2021-06-29 15:18:30       377422
# attack_model/vgg16_Retinopathy_attacker/assets/ 2021-06-29 13:17:18            0
# attack_model/vgg16_Retinopathy_attacker/keras_metadata.pb 2021-06-29 15:18:30        53520
# attack_model/vgg16_Retinopathy_attacker/variables/ 2021-06-29 15:18:30            0
# attack_model/vgg16_Retinopathy_attacker/variables/variables.data-00000-of-00001 2021-06-29 15:18:30    367178320
# attack_model/vgg16_Retinopathy_attacker/variables/variables.index 2021-06-29 15:18:30         3191
# Extracting all the files now...
# Done!

# %%
model_location = 'attack_model/vgg16_Retinopathy_attacker'

from tensorflow.keras.models import load_model
new_model = load_model(model_location)
new_model.trainable = False

# %% [markdown]
# Example image:-

# %%
which_number = 94

#new_img = img[which_number][0]
#actual_label = img[which_number][1]

new_img = X_train[which_number]
actual_label = Y_train[which_number]

new_img = preprocessing_image(new_img)

y_label = 0
if actual_label==0:
  y_label = 1

old_pred = new_model.predict(new_img)
plt.imshow(new_img[0]/255)
plt.title('Original Image, Pred: '+str(old_pred[0][0]))
plt.show()

y_adv = tf.reshape(y_label, shape=[1, old_pred.shape[-1]])

x_adv, itrs = PGD(new_img, y_adv, 1.4)

noise = x_adv - new_img
plt.imshow(noise[0])
plt.title('Noise while trying to attack')
plt.show()

new_preds = new_model.predict(x_adv)
print("The prediction of the image after %d iterations of PGD attack %f" % ( itrs, new_preds[0][0]))

plt.imshow(x_adv[0]/255)
plt.title('Perturbed image Preds: '+str(new_preds[0][0]))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The prediction of the image after 3 iterations of PGD attack 1.000000

# %%
# !mkdir PGD_BBA_perturbed_img

# %%
# !mkdir PGD_BBA_perturbed_img/No_DR
# !mkdir PGD_BBA_perturbed_img/DR

# %%
dr = 0
no_dr = 0

for i,d in enumerate(X_train):
  print(i)
  if Y_train[i] == 1:
    create_perturb_pgd(d, 'DR('+str(dr)+').png', 'PGD_BBA_perturbed_img/DR/', 0)
    print('DR('+str(dr)+').png')
    dr+=1
  else:
    create_perturb_pgd(d, 'No_DR('+str(no_dr)+').png', 'PGD_BBA_perturbed_img/No_DR/', 1)
    print('No_DR('+str(no_dr)+').png')
    no_dr+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# 350
# The prediction of the image before attack:  [[0.00308061]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(117).png
# 351
# The prediction of the image before attack:  [[1.0556156e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(233).png
# 352
# The prediction of the image before attack:  [[0.3999959]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(118).png
# 353
# The prediction of the image before attack:  [[0.7007907]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(234).png
# 354
# The prediction of the image before attack:  [[0.00025572]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(235).png
# 355
# The prediction of the image before attack:  [[0.9657152]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(236).png
# 356
# The prediction of the image before attack:  [[0.00436948]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(237).png
# 357
# The prediction of the image before attack:  [[0.14137271]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(119).png
# 358
# The prediction of the image before attack:  [[0.00044321]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(120).png
# 359
# The prediction of the image before attack:  [[0.55488294]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(121).png
# 360
# The prediction of the image before attack:  [[0.11842241]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(238).png
# 361
# The prediction of the image before attack:  [[0.76074356]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(239).png
# 362
# The prediction of the image before attack:  [[0.00038507]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(240).png
# 363
# The prediction of the image before attack:  [[4.551396e-08]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(122).png
# 364
# The prediction of the image before attack:  [[0.79690456]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(123).png
# 365
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(124).png
# 366
# The prediction of the image before attack:  [[0.00642736]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(125).png
# 367
# The prediction of the image before attack:  [[0.02609403]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(241).png
# 368
# The prediction of the image before attack:  [[0.00237168]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(242).png
# 369
# The prediction of the image before attack:  [[0.04075756]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(126).png
# 370
# The prediction of the image before attack:  [[0.53924215]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(127).png
# 371
# The prediction of the image before attack:  [[1.2438064e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(243).png
# 372
# The prediction of the image before attack:  [[0.6049641]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(128).png
# 373
# The prediction of the image before attack:  [[0.11820357]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(129).png
# 374
# The prediction of the image before attack:  [[0.00167728]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(244).png
# 375
# The prediction of the image before attack:  [[0.9996604]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(130).png
# 376
# The prediction of the image before attack:  [[0.00013524]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(245).png
# 377
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(246).png
# 378
# The prediction of the image before attack:  [[0.00281985]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(131).png
# 379
# The prediction of the image before attack:  [[0.00029971]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(247).png
# 380
# The prediction of the image before attack:  [[0.00098392]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(132).png
# 381
# The prediction of the image before attack:  [[0.02431036]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(133).png
# 382
# The prediction of the image before attack:  [[0.9998196]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(134).png
# 383
# The prediction of the image before attack:  [[1.80076e-08]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(248).png
# 384
# The prediction of the image before attack:  [[0.00050446]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(249).png
# 385
# The prediction of the image before attack:  [[0.9746494]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(250).png
# 386
# The prediction of the image before attack:  [[0.00194008]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(251).png
# 387
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(252).png
# 388
# The prediction of the image before attack:  [[0.91776156]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(135).png
# 389
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(253).png
# 390
# The prediction of the image before attack:  [[0.00333084]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(254).png
# 391
# The prediction of the image before attack:  [[0.000794]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(255).png
# 392
# The prediction of the image before attack:  [[0.99462056]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(256).png
# 393
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(257).png
# 394
# The prediction of the image before attack:  [[0.00021997]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(258).png
# 395
# The prediction of the image before attack:  [[3.1753276e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(259).png
# 396
# The prediction of the image before attack:  [[0.02906004]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(260).png
# 397
# The prediction of the image before attack:  [[0.2111554]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(261).png
# 398
# The prediction of the image before attack:  [[0.0980843]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(136).png
# 399
# The prediction of the image before attack:  [[0.20053637]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(137).png
# 400
# The prediction of the image before attack:  [[4.567325e-09]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(262).png
# 401
# The prediction of the image before attack:  [[0.22908147]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(263).png
# 402
# The prediction of the image before attack:  [[0.01048725]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(138).png
# 403
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(139).png
# 404
# The prediction of the image before attack:  [[0.6649728]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(140).png
# 405
# The prediction of the image before attack:  [[0.9998771]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(264).png
# 406
# The prediction of the image before attack:  [[0.01388274]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(265).png
# 407
# The prediction of the image before attack:  [[0.00425439]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(266).png
# 408
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(267).png
# 409
# The prediction of the image before attack:  [[6.873569e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(268).png
# 410
# The prediction of the image before attack:  [[0.91776156]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(141).png
# 411
# The prediction of the image before attack:  [[0.82776695]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(269).png
# 412
# The prediction of the image before attack:  [[1.1526508e-09]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(270).png
# 413
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(271).png
# 414
# The prediction of the image before attack:  [[0.00618463]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(272).png
# 415
# The prediction of the image before attack:  [[9.672188e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(273).png
# 416
# The prediction of the image before attack:  [[0.0001202]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(142).png
# 417
# The prediction of the image before attack:  [[2.7734975e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(274).png
# 418
# The prediction of the image before attack:  [[0.0006958]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(275).png
# 419
# The prediction of the image before attack:  [[0.00194008]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(276).png
# 420
# The prediction of the image before attack:  [[0.01250794]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(143).png
# 421
# The prediction of the image before attack:  [[0.98192775]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(144).png
# 422
# The prediction of the image before attack:  [[3.857305e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(277).png
# 423
# The prediction of the image before attack:  [[0.02159305]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(278).png
# 424
# The prediction of the image before attack:  [[0.01972254]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(279).png
# 425
# The prediction of the image before attack:  [[0.6849009]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(145).png
# 426
# The prediction of the image before attack:  [[0.02159305]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(280).png
# 427
# The prediction of the image before attack:  [[1.3902683e-06]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(146).png
# 428
# The prediction of the image before attack:  [[3.352865e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(147).png
# 429
# The prediction of the image before attack:  [[0.4075514]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(148).png
# 430
# The prediction of the image before attack:  [[0.9653203]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(281).png
# 431
# The prediction of the image before attack:  [[0.81141186]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(149).png
# 432
# The prediction of the image before attack:  [[8.2811246e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(282).png
# 433
# The prediction of the image before attack:  [[0.9452299]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(283).png
# 434
# The prediction of the image before attack:  [[0.8812657]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(284).png
# 435
# The prediction of the image before attack:  [[0.00045607]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(285).png
# 436
# The prediction of the image before attack:  [[0.19288674]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(150).png
# 437
# The prediction of the image before attack:  [[2.8480761e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(286).png
# 438
# The prediction of the image before attack:  [[4.6686748e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(151).png
# 439
# The prediction of the image before attack:  [[0.00095634]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(287).png
# 440
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(288).png
# 441
# The prediction of the image before attack:  [[0.63804716]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(289).png
# 442
# The prediction of the image before attack:  [[0.93048275]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(152).png
# 443
# The prediction of the image before attack:  [[1.0214059e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(290).png
# 444
# The prediction of the image before attack:  [[0.02565962]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(153).png
# 445
# The prediction of the image before attack:  [[0.00108271]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(291).png
# 446
# The prediction of the image before attack:  [[0.00028064]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(292).png
# 447
# The prediction of the image before attack:  [[0.12639117]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(293).png
# 448
# The prediction of the image before attack:  [[0.00657429]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(294).png
# 449
# The prediction of the image before attack:  [[0.00240135]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(154).png
# 450
# The prediction of the image before attack:  [[0.00171243]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(295).png
# 451
# The prediction of the image before attack:  [[2.8797892e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(296).png
# 452
# The prediction of the image before attack:  [[1.0714039e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(297).png
# 453
# The prediction of the image before attack:  [[1.0972515e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(298).png
# 454
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(155).png
# 455
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(299).png
# 456
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(300).png
# 457
# The prediction of the image before attack:  [[0.05606256]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(301).png
# 458
# The prediction of the image before attack:  [[0.9849262]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(156).png
# 459
# The prediction of the image before attack:  [[0.9973008]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(157).png
# 460
# The prediction of the image before attack:  [[1.80076e-08]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(302).png
# 461
# The prediction of the image before attack:  [[0.6805642]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(303).png
# 462
# The prediction of the image before attack:  [[0.31663716]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(158).png
# 463
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(304).png
# 464
# The prediction of the image before attack:  [[0.00064854]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(159).png
# 465
# The prediction of the image before attack:  [[0.14264268]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(305).png
# 466
# The prediction of the image before attack:  [[0.00092721]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(306).png
# 467
# The prediction of the image before attack:  [[0.09689156]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(307).png
# 468
# The prediction of the image before attack:  [[0.81115144]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(308).png
# 469
# The prediction of the image before attack:  [[0.91776156]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(160).png
# 470
# The prediction of the image before attack:  [[0.1556925]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(161).png
# 471
# The prediction of the image before attack:  [[3.52073e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(309).png
# 472
# The prediction of the image before attack:  [[0.00131614]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(162).png
# 473
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(310).png
# 474
# The prediction of the image before attack:  [[0.00906687]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(163).png
# 475
# The prediction of the image before attack:  [[0.00069425]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(311).png
# 476
# The prediction of the image before attack:  [[0.00549212]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(312).png
# 477
# The prediction of the image before attack:  [[0.3172152]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(313).png
# 478
# The prediction of the image before attack:  [[6.0126324e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(164).png
# 479
# The prediction of the image before attack:  [[0.0011865]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(165).png
# 480
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(314).png
# 481
# The prediction of the image before attack:  [[0.14195918]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(166).png
# 482
# The prediction of the image before attack:  [[0.00634325]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(167).png
# 483
# The prediction of the image before attack:  [[0.8196551]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(168).png
# 484
# The prediction of the image before attack:  [[3.5726886e-09]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(315).png
# 485
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(169).png
# 486
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(316).png
# 487
# The prediction of the image before attack:  [[0.28092766]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(170).png
# 488
# The prediction of the image before attack:  [[0.21893604]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(171).png
# 489
# The prediction of the image before attack:  [[0.64962786]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(317).png
# 490
# The prediction of the image before attack:  [[2.2648354e-07]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(318).png
# 491
# The prediction of the image before attack:  [[0.01919848]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(319).png
# 492
# The prediction of the image before attack:  [[0.00061567]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(320).png
# 493
# The prediction of the image before attack:  [[6.333943e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(172).png
# 494
# The prediction of the image before attack:  [[0.06742729]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(321).png
# 495
# The prediction of the image before attack:  [[0.00044614]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(322).png
# 496
# The prediction of the image before attack:  [[0.00088025]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(323).png
# 497
# The prediction of the image before attack:  [[9.8534194e-08]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(324).png
# 498
# The prediction of the image before attack:  [[0.10651375]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(173).png
# 499
# The prediction of the image before attack:  [[6.7619467e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(325).png
# 500
# The prediction of the image before attack:  [[0.00032921]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(326).png
# 501
# The prediction of the image before attack:  [[0.4838058]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(174).png
# 502
# The prediction of the image before attack:  [[0.00016847]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(327).png
# 503
# The prediction of the image before attack:  [[0.92571294]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(328).png
# 504
# The prediction of the image before attack:  [[0.02404518]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(175).png
# 505
# The prediction of the image before attack:  [[0.9482253]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(176).png
# 506
# The prediction of the image before attack:  [[0.5842693]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(177).png
# 507
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(329).png
# 508
# The prediction of the image before attack:  [[0.06692699]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(178).png
# 509
# The prediction of the image before attack:  [[9.788784e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(330).png
# 510
# The prediction of the image before attack:  [[0.10658266]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(179).png
# 511
# The prediction of the image before attack:  [[0.3671662]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(331).png
# 512
# The prediction of the image before attack:  [[0.00658796]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(180).png
# 513
# The prediction of the image before attack:  [[0.00143322]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(332).png
# 514
# The prediction of the image before attack:  [[0.8812657]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(333).png
# 515
# The prediction of the image before attack:  [[9.559799e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(181).png
# 516
# The prediction of the image before attack:  [[0.00039309]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(334).png
# 517
# The prediction of the image before attack:  [[0.9757639]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(335).png
# 518
# The prediction of the image before attack:  [[0.13221613]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(336).png
# 519
# The prediction of the image before attack:  [[1.8413666e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(337).png
# 520
# The prediction of the image before attack:  [[8.7201696e-10]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(182).png
# 521
# The prediction of the image before attack:  [[0.48785657]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(183).png
# 522
# The prediction of the image before attack:  [[5.298946e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(338).png
# 523
# The prediction of the image before attack:  [[0.22254983]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(339).png
# 524
# The prediction of the image before attack:  [[0.00056519]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(340).png
# 525
# The prediction of the image before attack:  [[0.14624096]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(341).png
# 526
# The prediction of the image before attack:  [[0.48151445]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(184).png
# 527
# The prediction of the image before attack:  [[2.607421e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(185).png
# 528
# The prediction of the image before attack:  [[7.7317134e-07]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(342).png
# 529
# The prediction of the image before attack:  [[6.9116404e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(343).png
# 530
# The prediction of the image before attack:  [[0.00050446]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(344).png
# 531
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(345).png
# 532
# The prediction of the image before attack:  [[2.704636e-07]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(346).png
# 533
# The prediction of the image before attack:  [[0.08791583]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(347).png
# 534
# The prediction of the image before attack:  [[9.667175e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(186).png
# 535
# The prediction of the image before attack:  [[0.00012458]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(348).png
# 536
# The prediction of the image before attack:  [[0.05894894]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(349).png
# 537
# The prediction of the image before attack:  [[7.345336e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(350).png
# 538
# The prediction of the image before attack:  [[0.01178681]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(187).png
# 539
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(351).png
# 540
# The prediction of the image before attack:  [[0.00064854]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(188).png
# 541
# The prediction of the image before attack:  [[0.72377217]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(352).png
# 542
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(353).png
# 543
# The prediction of the image before attack:  [[0.9425777]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(354).png
# 544
# The prediction of the image before attack:  [[0.91801476]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(355).png
# 545
# The prediction of the image before attack:  [[1.570678e-08]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(356).png
# 546
# The prediction of the image before attack:  [[0.1524244]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(357).png
# 547
# The prediction of the image before attack:  [[0.82602227]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(189).png
# 548
# The prediction of the image before attack:  [[0.07602445]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(190).png
# 549
# The prediction of the image before attack:  [[0.45366988]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(191).png
# 550
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(358).png
# 551
# The prediction of the image before attack:  [[0.9866448]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(359).png
# 552
# The prediction of the image before attack:  [[0.7836448]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(192).png
# 553
# The prediction of the image before attack:  [[1.7084611e-06]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(360).png
# 554
# The prediction of the image before attack:  [[0.08337271]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(193).png
# 555
# The prediction of the image before attack:  [[0.06591602]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(361).png
# 556
# The prediction of the image before attack:  [[4.9967824e-17]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(362).png
# 557
# The prediction of the image before attack:  [[0.00060145]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(363).png
# 558
# The prediction of the image before attack:  [[0.99988794]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(194).png
# 559
# The prediction of the image before attack:  [[0.00243411]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(195).png
# 560
# The prediction of the image before attack:  [[0.00032921]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(364).png
# 561
# The prediction of the image before attack:  [[6.800973e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(365).png
# 562
# The prediction of the image before attack:  [[0.04678323]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(366).png
# 563
# The prediction of the image before attack:  [[0.00194008]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(367).png
# 564
# The prediction of the image before attack:  [[0.99999833]]
# The prediction of the image after 1 iterations of PGD attack: 1.000000
# No_DR(368).png
# 565
# The prediction of the image before attack:  [[0.02384421]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(196).png
# 566
# The prediction of the image before attack:  [[0.91801476]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(369).png
# 567
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(197).png
# 568
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(370).png
# 569
# The prediction of the image before attack:  [[2.7630045e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(371).png
# 570
# The prediction of the image before attack:  [[0.1833121]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(372).png
# 571
# The prediction of the image before attack:  [[0.6224208]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(198).png
# 572
# The prediction of the image before attack:  [[0.03587515]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(199).png
# 573
# The prediction of the image before attack:  [[0.53757423]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(200).png
# 574
# The prediction of the image before attack:  [[0.95027727]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(373).png
# 575
# The prediction of the image before attack:  [[0.00398282]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(201).png
# 576
# The prediction of the image before attack:  [[0.00160271]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(374).png
# 577
# The prediction of the image before attack:  [[0.03679655]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(202).png
# 578
# The prediction of the image before attack:  [[0.9950217]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(203).png
# 579
# The prediction of the image before attack:  [[0.00016781]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(204).png
# 580
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(375).png
# 581
# The prediction of the image before attack:  [[0.39527103]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(376).png
# 582
# The prediction of the image before attack:  [[3.6705593e-08]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(377).png
# 583
# The prediction of the image before attack:  [[0.9999608]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(205).png
# 584
# The prediction of the image before attack:  [[0.00060364]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(206).png
# 585
# The prediction of the image before attack:  [[0.995852]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(207).png
# 586
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(208).png
# 587
# The prediction of the image before attack:  [[0.05576917]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(209).png
# 588
# The prediction of the image before attack:  [[0.06591602]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(378).png
# 589
# The prediction of the image before attack:  [[0.01226045]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(379).png
# 590
# The prediction of the image before attack:  [[0.01052546]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(210).png
# 591
# The prediction of the image before attack:  [[0.9237534]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(380).png
# 592
# The prediction of the image before attack:  [[5.595746e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(381).png
# 593
# The prediction of the image before attack:  [[0.12399739]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(382).png
# 594
# The prediction of the image before attack:  [[0.00877646]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(383).png
# 595
# The prediction of the image before attack:  [[0.22254983]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(384).png
# 596
# The prediction of the image before attack:  [[0.00149528]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(211).png
# 597
# The prediction of the image before attack:  [[0.08085898]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(385).png
# 598
# The prediction of the image before attack:  [[0.97145647]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(212).png
# 599
# The prediction of the image before attack:  [[0.9977506]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(213).png
# 600
# The prediction of the image before attack:  [[0.36040846]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(214).png
# 601
# The prediction of the image before attack:  [[0.0015113]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(386).png
# 602
# The prediction of the image before attack:  [[0.94158846]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(215).png
# 603
# The prediction of the image before attack:  [[0.9818131]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(216).png
# 604
# The prediction of the image before attack:  [[0.93315125]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(217).png
# 605
# The prediction of the image before attack:  [[0.08976168]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(218).png
# 606
# The prediction of the image before attack:  [[0.00791752]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(219).png
# 607
# The prediction of the image before attack:  [[0.36287826]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(387).png
# 608
# The prediction of the image before attack:  [[0.01090473]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(388).png
# 609
# The prediction of the image before attack:  [[0.02565962]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(220).png
# 610
# The prediction of the image before attack:  [[0.00901614]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(389).png
# 611
# The prediction of the image before attack:  [[3.425824e-08]]
# The prediction of the image after 8 iterations of PGD attack: 1.000000
# No_DR(390).png
# 612
# The prediction of the image before attack:  [[0.51017857]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(391).png
# 613
# The prediction of the image before attack:  [[1.2588877e-05]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(221).png
# 614
# The prediction of the image before attack:  [[0.00100879]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(392).png
# 615
# The prediction of the image before attack:  [[0.02159305]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(393).png
# 616
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(394).png
# 617
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(395).png
# 618
# The prediction of the image before attack:  [[0.7967367]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(396).png
# 619
# The prediction of the image before attack:  [[0.00185376]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(222).png
# 620
# The prediction of the image before attack:  [[0.00050446]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(397).png
# 621
# The prediction of the image before attack:  [[0.01965475]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(398).png
# 622
# The prediction of the image before attack:  [[0.00149925]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(399).png
# 623
# The prediction of the image before attack:  [[5.298946e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(400).png
# 624
# The prediction of the image before attack:  [[0.03156444]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(223).png
# 625
# The prediction of the image before attack:  [[0.00157976]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(401).png
# 626
# The prediction of the image before attack:  [[0.0004024]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(402).png
# 627
# The prediction of the image before attack:  [[0.00143322]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(403).png
# 628
# The prediction of the image before attack:  [[0.00056069]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(404).png
# 629
# The prediction of the image before attack:  [[0.04591046]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(224).png
# 630
# The prediction of the image before attack:  [[0.8502883]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(225).png
# 631
# The prediction of the image before attack:  [[0.07359327]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(405).png
# 632
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(406).png
# 633
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(407).png
# 634
# The prediction of the image before attack:  [[0.99736905]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(226).png
# 635
# The prediction of the image before attack:  [[0.9514641]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(227).png
# 636
# The prediction of the image before attack:  [[0.99407274]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(228).png
# 637
# The prediction of the image before attack:  [[0.61422247]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(229).png
# 638
# The prediction of the image before attack:  [[7.002205e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(408).png
# 639
# The prediction of the image before attack:  [[0.07510153]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(409).png
# 640
# The prediction of the image before attack:  [[3.753372e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(410).png
# 641
# The prediction of the image before attack:  [[0.00053785]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(411).png
# 642
# The prediction of the image before attack:  [[0.07510153]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(412).png
# 643
# The prediction of the image before attack:  [[0.3550741]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(413).png
# 644
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(414).png
# 645
# The prediction of the image before attack:  [[0.04460326]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(415).png
# 646
# The prediction of the image before attack:  [[0.00045607]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(416).png
# 647
# The prediction of the image before attack:  [[4.473232e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(417).png
# 648
# The prediction of the image before attack:  [[0.00073064]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(418).png
# 649
# The prediction of the image before attack:  [[0.98245037]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(419).png
# 650
# The prediction of the image before attack:  [[0.00365365]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(420).png
# 651
# The prediction of the image before attack:  [[0.00028699]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(421).png
# 652
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(422).png
# 653
# The prediction of the image before attack:  [[4.6163215e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(423).png
# 654
# The prediction of the image before attack:  [[0.82776695]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(424).png
# 655
# The prediction of the image before attack:  [[1.3685975e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(425).png
# 656
# The prediction of the image before attack:  [[0.14876297]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(426).png
# 657
# The prediction of the image before attack:  [[0.02345846]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(230).png
# 658
# The prediction of the image before attack:  [[0.60213625]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(427).png
# 659
# The prediction of the image before attack:  [[0.00260435]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(231).png
# 660
# The prediction of the image before attack:  [[0.02366401]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(428).png
# 661
# The prediction of the image before attack:  [[0.0001089]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(429).png
# 662
# The prediction of the image before attack:  [[0.00403929]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(232).png
# 663
# The prediction of the image before attack:  [[0.13539086]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(430).png
# 664
# The prediction of the image before attack:  [[1.9194299e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(233).png
# 665
# The prediction of the image before attack:  [[0.9406184]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(234).png
# 666
# The prediction of the image before attack:  [[8.69548e-06]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(235).png
# 667
# The prediction of the image before attack:  [[0.03836177]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(431).png
# 668
# The prediction of the image before attack:  [[0.02345846]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(236).png
# 669
# The prediction of the image before attack:  [[5.327553e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(432).png
# 670
# The prediction of the image before attack:  [[4.473232e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(433).png
# 671
# The prediction of the image before attack:  [[0.21155718]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(237).png
# 672
# The prediction of the image before attack:  [[0.00326598]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(434).png
# 673
# The prediction of the image before attack:  [[0.4470897]]
# ...
# No_DR(1005).png
# 1494
# The prediction of the image before attack:  [[0.00521278]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1006).png
# 1495
# The prediction of the image before attack:  [[9.788784e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1007).png
# 1496
# The prediction of the image before attack:  [[2.3138304e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(488).png
# 1497
# The prediction of the image before attack:  [[0.00138076]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1008).png
# 1498
# The prediction of the image before attack:  [[0.8823319]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1009).png
# 1499
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(489).png
# 1500
# The prediction of the image before attack:  [[0.00261813]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1010).png
# 1501
# The prediction of the image before attack:  [[0.39107764]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1011).png
# 1502
# The prediction of the image before attack:  [[0.00029284]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1012).png
# 1503
# The prediction of the image before attack:  [[0.00199972]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1013).png
# 1504
# The prediction of the image before attack:  [[0.24016888]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1014).png
# 1505
# The prediction of the image before attack:  [[7.908018e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1015).png
# 1506
# The prediction of the image before attack:  [[8.9093476e-08]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1016).png
# 1507
# The prediction of the image before attack:  [[3.5726886e-09]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1017).png
# 1508
# The prediction of the image before attack:  [[0.05858029]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1018).png
# 1509
# The prediction of the image before attack:  [[0.2757057]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1019).png
# 1510
# The prediction of the image before attack:  [[0.15997481]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(490).png
# 1511
# The prediction of the image before attack:  [[1.0480946e-12]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1020).png
# 1512
# The prediction of the image before attack:  [[0.23375365]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1021).png
# 1513
# The prediction of the image before attack:  [[0.00511268]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1022).png
# 1514
# The prediction of the image before attack:  [[5.3096286e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1023).png
# 1515
# The prediction of the image before attack:  [[0.00032962]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1024).png
# 1516
# The prediction of the image before attack:  [[0.00742758]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1025).png
# 1517
# The prediction of the image before attack:  [[0.9216149]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(491).png
# 1518
# The prediction of the image before attack:  [[2.704636e-07]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1026).png
# 1519
# The prediction of the image before attack:  [[0.00045607]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1027).png
# 1520
# The prediction of the image before attack:  [[0.00103255]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1028).png
# 1521
# The prediction of the image before attack:  [[0.14727314]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1029).png
# 1522
# The prediction of the image before attack:  [[2.6512302e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(492).png
# 1523
# The prediction of the image before attack:  [[2.9034663e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1030).png
# 1524
# The prediction of the image before attack:  [[3.030244e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1031).png
# 1525
# The prediction of the image before attack:  [[0.03129081]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1032).png
# 1526
# The prediction of the image before attack:  [[0.7265784]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1033).png
# 1527
# The prediction of the image before attack:  [[0.04678323]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1034).png
# 1528
# The prediction of the image before attack:  [[1.206994e-05]]
# The prediction of the image after 8 iterations of PGD attack: 1.000000
# No_DR(1035).png
# 1529
# The prediction of the image before attack:  [[0.45545417]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1036).png
# 1530
# The prediction of the image before attack:  [[8.084696e-05]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1037).png
# 1531
# The prediction of the image before attack:  [[9.291316e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1038).png
# 1532
# The prediction of the image before attack:  [[0.9866448]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1039).png
# 1533
# The prediction of the image before attack:  [[4.5706916e-08]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1040).png
# 1534
# The prediction of the image before attack:  [[0.9207249]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(493).png
# 1535
# The prediction of the image before attack:  [[9.0500784e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(494).png
# 1536
# The prediction of the image before attack:  [[0.00033168]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1041).png
# 1537
# The prediction of the image before attack:  [[1.6197973e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1042).png
# 1538
# The prediction of the image before attack:  [[0.00943055]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1043).png
# 1539
# The prediction of the image before attack:  [[0.04642906]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1044).png
# 1540
# The prediction of the image before attack:  [[0.3550741]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1045).png
# 1541
# The prediction of the image before attack:  [[0.00126557]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1046).png
# 1542
# The prediction of the image before attack:  [[0.12745546]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1047).png
# 1543
# The prediction of the image before attack:  [[0.9792875]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(495).png
# 1544
# The prediction of the image before attack:  [[0.00012458]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1048).png
# 1545
# The prediction of the image before attack:  [[0.97103506]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1049).png
# 1546
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1050).png
# 1547
# The prediction of the image before attack:  [[0.644052]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1051).png
# 1548
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1052).png
# 1549
# The prediction of the image before attack:  [[0.9964263]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1053).png
# 1550
# The prediction of the image before attack:  [[3.8865826e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1054).png
# 1551
# The prediction of the image before attack:  [[0.03687299]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1055).png
# 1552
# The prediction of the image before attack:  [[6.9116404e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1056).png
# 1553
# The prediction of the image before attack:  [[8.230261e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1057).png
# 1554
# The prediction of the image before attack:  [[0.9774889]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1058).png
# 1555
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1059).png
# 1556
# The prediction of the image before attack:  [[0.6945233]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(496).png
# 1557
# The prediction of the image before attack:  [[0.05108991]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1060).png
# 1558
# The prediction of the image before attack:  [[0.9571061]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1061).png
# 1559
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1062).png
# 1560
# The prediction of the image before attack:  [[0.00160271]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1063).png
# 1561
# The prediction of the image before attack:  [[0.0050884]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(497).png
# 1562
# The prediction of the image before attack:  [[1.9054237e-12]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1064).png
# 1563
# The prediction of the image before attack:  [[0.7967367]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1065).png
# 1564
# The prediction of the image before attack:  [[0.0065155]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1066).png
# 1565
# The prediction of the image before attack:  [[4.0940467e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(498).png
# 1566
# The prediction of the image before attack:  [[0.00013427]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1067).png
# 1567
# The prediction of the image before attack:  [[1.4545836e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1068).png
# 1568
# The prediction of the image before attack:  [[3.9369195e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1069).png
# 1569
# The prediction of the image before attack:  [[2.4135594e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1070).png
# 1570
# The prediction of the image before attack:  [[0.0050884]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(499).png
# 1571
# The prediction of the image before attack:  [[0.01116391]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1071).png
# 1572
# The prediction of the image before attack:  [[1.496588e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(500).png
# 1573
# The prediction of the image before attack:  [[0.00032962]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1072).png
# 1574
# The prediction of the image before attack:  [[0.9747]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(501).png
# 1575
# The prediction of the image before attack:  [[2.607421e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(502).png
# 1576
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(503).png
# 1577
# The prediction of the image before attack:  [[5.6514627e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1073).png
# 1578
# The prediction of the image before attack:  [[0.00067976]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(504).png
# 1579
# The prediction of the image before attack:  [[1.7467291e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1074).png
# 1580
# The prediction of the image before attack:  [[0.00665907]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(505).png
# 1581
# The prediction of the image before attack:  [[0.09100016]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1075).png
# 1582
# The prediction of the image before attack:  [[0.02402207]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1076).png
# 1583
# The prediction of the image before attack:  [[0.16997996]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(506).png
# 1584
# The prediction of the image before attack:  [[0.00042179]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(507).png
# 1585
# The prediction of the image before attack:  [[0.11996242]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1077).png
# 1586
# The prediction of the image before attack:  [[0.9998504]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(508).png
# 1587
# The prediction of the image before attack:  [[0.9863614]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1078).png
# 1588
# The prediction of the image before attack:  [[0.00032921]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1079).png
# 1589
# The prediction of the image before attack:  [[1.6281061e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1080).png
# 1590
# The prediction of the image before attack:  [[0.01972254]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1081).png
# 1591
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1082).png
# 1592
# The prediction of the image before attack:  [[0.35573596]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(509).png
# 1593
# The prediction of the image before attack:  [[2.8639932e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1083).png
# 1594
# The prediction of the image before attack:  [[4.4849956e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(510).png
# 1595
# The prediction of the image before attack:  [[0.9996081]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(511).png
# 1596
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1084).png
# 1597
# The prediction of the image before attack:  [[7.1238894e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1085).png
# 1598
# The prediction of the image before attack:  [[5.56557e-06]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1086).png
# 1599
# The prediction of the image before attack:  [[8.230261e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1087).png

# %%
for i,d in enumerate(X_test):
  print(i)
  if Y_test[i] == 1:
    create_perturb_pgd(d, 'DR('+str(dr)+').png', 'PGD_BBA_perturbed_img/DR/', 0)
    print('DR('+str(dr)+').png')
    dr+=1
  else:
    create_perturb_pgd(d, 'No_DR('+str(no_dr)+').png', 'PGD_BBA_perturbed_img/No_DR/', 1)
    print('No_DR('+str(no_dr)+').png')
    no_dr+=1
# Out:
# 0
# The prediction of the image before attack:  [[0.95027727]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1088).png
# 1
# The prediction of the image before attack:  [[0.8282469]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1089).png
# 2
# The prediction of the image before attack:  [[0.00511268]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1090).png
# 3
# The prediction of the image before attack:  [[0.0001213]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1091).png
# 4
# The prediction of the image before attack:  [[1.5924453e-08]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1092).png
# 5
# The prediction of the image before attack:  [[0.10658266]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(512).png
# 6
# The prediction of the image before attack:  [[0.35441938]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(513).png
# 7
# The prediction of the image before attack:  [[0.9849262]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(514).png
# 8
# The prediction of the image before attack:  [[0.81115144]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1093).png
# 9
# The prediction of the image before attack:  [[0.2297796]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(515).png
# 10
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(516).png
# 11
# The prediction of the image before attack:  [[5.2572952e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1094).png
# 12
# The prediction of the image before attack:  [[0.01768238]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(517).png
# 13
# The prediction of the image before attack:  [[0.5207427]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(518).png
# 14
# The prediction of the image before attack:  [[1.0556156e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1095).png
# 15
# The prediction of the image before attack:  [[0.12940425]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1096).png
# 16
# The prediction of the image before attack:  [[0.16997996]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(519).png
# 17
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1097).png
# 18
# The prediction of the image before attack:  [[7.1540067e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1098).png
# 19
# The prediction of the image before attack:  [[0.00025167]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1099).png
# 20
# The prediction of the image before attack:  [[0.9657152]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1100).png
# 21
# The prediction of the image before attack:  [[0.9818131]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(520).png
# 22
# The prediction of the image before attack:  [[0.00073064]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1101).png
# 23
# The prediction of the image before attack:  [[0.0085095]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1102).png
# 24
# The prediction of the image before attack:  [[2.4621357e-12]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1103).png
# 25
# The prediction of the image before attack:  [[2.3138304e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(521).png
# 26
# The prediction of the image before attack:  [[0.00010947]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1104).png
# 27
# The prediction of the image before attack:  [[0.99953496]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(522).png
# 28
# The prediction of the image before attack:  [[0.03346151]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1105).png
# 29
# The prediction of the image before attack:  [[2.7734975e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1106).png
# 30
# The prediction of the image before attack:  [[0.00652593]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1107).png
# 31
# The prediction of the image before attack:  [[0.01226045]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1108).png
# 32
# The prediction of the image before attack:  [[0.3671662]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1109).png
# 33
# The prediction of the image before attack:  [[0.07399887]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1110).png
# 34
# The prediction of the image before attack:  [[0.00126557]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1111).png
# 35
# The prediction of the image before attack:  [[1.0344526e-06]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(523).png
# 36
# The prediction of the image before attack:  [[1.6133988e-07]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1112).png
# 37
# The prediction of the image before attack:  [[0.5131379]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1113).png
# 38
# The prediction of the image before attack:  [[0.16997996]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(524).png
# 39
# The prediction of the image before attack:  [[0.00171243]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1114).png
# 40
# The prediction of the image before attack:  [[0.00211565]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1115).png
# 41
# The prediction of the image before attack:  [[0.19161919]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1116).png
# 42
# The prediction of the image before attack:  [[0.07618525]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1117).png
# 43
# The prediction of the image before attack:  [[0.11886895]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1118).png
# 44
# The prediction of the image before attack:  [[0.00567226]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1119).png
# 45
# The prediction of the image before attack:  [[0.755463]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(525).png
# 46
# The prediction of the image before attack:  [[0.05439005]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(526).png
# 47
# The prediction of the image before attack:  [[8.0108954e-08]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1120).png
# 48
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1121).png
# 49
# The prediction of the image before attack:  [[0.0010417]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1122).png
# 50
# The prediction of the image before attack:  [[0.00943055]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1123).png
# 51
# The prediction of the image before attack:  [[0.21893604]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(527).png
# 52
# The prediction of the image before attack:  [[0.00308061]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(528).png
# 53
# The prediction of the image before attack:  [[0.87203944]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1124).png
# 54
# The prediction of the image before attack:  [[0.18038169]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(529).png
# 55
# The prediction of the image before attack:  [[0.00281357]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1125).png
# 56
# The prediction of the image before attack:  [[2.5735055e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1126).png
# 57
# The prediction of the image before attack:  [[0.08380187]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1127).png
# 58
# The prediction of the image before attack:  [[0.00261813]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1128).png
# 59
# The prediction of the image before attack:  [[0.98308635]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1129).png
# 60
# The prediction of the image before attack:  [[0.9665322]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1130).png
# 61
# The prediction of the image before attack:  [[0.00124306]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1131).png
# 62
# The prediction of the image before attack:  [[8.69548e-06]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(530).png
# 63
# The prediction of the image before attack:  [[0.48151445]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(531).png
# 64
# The prediction of the image before attack:  [[0.9664462]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1132).png
# 65
# The prediction of the image before attack:  [[0.98851585]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1133).png
# 66
# The prediction of the image before attack:  [[0.9514641]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(532).png
# 67
# The prediction of the image before attack:  [[0.63804716]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1134).png
# 68
# The prediction of the image before attack:  [[0.02670408]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1135).png
# 69
# The prediction of the image before attack:  [[0.91366065]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(533).png
# 70
# The prediction of the image before attack:  [[9.983456e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1136).png
# 71
# The prediction of the image before attack:  [[0.00080311]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1137).png
# 72
# The prediction of the image before attack:  [[2.8402103e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1138).png
# 73
# The prediction of the image before attack:  [[1.1336475e-08]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(534).png
# 74
# The prediction of the image before attack:  [[0.00294215]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1139).png
# 75
# The prediction of the image before attack:  [[4.925735e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1140).png
# 76
# The prediction of the image before attack:  [[0.48785657]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(535).png
# 77
# The prediction of the image before attack:  [[0.77484065]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1141).png
# 78
# The prediction of the image before attack:  [[0.0006984]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1142).png
# 79
# The prediction of the image before attack:  [[0.72377217]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1143).png
# 80
# The prediction of the image before attack:  [[0.99462056]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1144).png
# 81
# The prediction of the image before attack:  [[2.8402103e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1145).png
# 82
# The prediction of the image before attack:  [[4.6879666e-07]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1146).png
# 83
# The prediction of the image before attack:  [[0.06239355]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1147).png
# 84
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1148).png
# 85
# The prediction of the image before attack:  [[0.01233116]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1149).png
# 86
# The prediction of the image before attack:  [[8.0108954e-08]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1150).png
# 87
# The prediction of the image before attack:  [[0.00124568]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(536).png
# 88
# The prediction of the image before attack:  [[2.7734975e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1151).png
# 89
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1152).png
# 90
# The prediction of the image before attack:  [[4.473232e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1153).png
# 91
# The prediction of the image before attack:  [[0.00011643]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(537).png
# 92
# The prediction of the image before attack:  [[0.00064249]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1154).png
# 93
# The prediction of the image before attack:  [[0.96418]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(538).png
# 94
# The prediction of the image before attack:  [[0.8763002]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(539).png
# 95
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1155).png
# 96
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(540).png
# 97
# The prediction of the image before attack:  [[1.7467291e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1156).png
# 98
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1157).png
# 99
# The prediction of the image before attack:  [[5.8333414e-11]]
# The prediction of the image after 7 iterations of PGD attack: 0.999999
# No_DR(1158).png
# 100
# The prediction of the image before attack:  [[0.00016683]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(541).png
# 101
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1159).png
# 102
# The prediction of the image before attack:  [[0.08380187]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1160).png
# 103
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1161).png
# 104
# The prediction of the image before attack:  [[0.00029304]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1162).png
# 105
# The prediction of the image before attack:  [[0.55745065]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(542).png
# 106
# The prediction of the image before attack:  [[0.7343615]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1163).png
# 107
# The prediction of the image before attack:  [[0.80058706]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1164).png
# 108
# The prediction of the image before attack:  [[0.19224326]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1165).png
# 109
# The prediction of the image before attack:  [[0.00187634]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(543).png
# 110
# The prediction of the image before attack:  [[0.00033384]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1166).png
# 111
# The prediction of the image before attack:  [[0.01890841]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1167).png
# 112
# The prediction of the image before attack:  [[0.01252573]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1168).png
# 113
# The prediction of the image before attack:  [[0.15997481]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(544).png
# 114
# The prediction of the image before attack:  [[0.80625325]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1169).png
# 115
# The prediction of the image before attack:  [[0.00059036]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1170).png
# 116
# The prediction of the image before attack:  [[0.1524244]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1171).png
# 117
# The prediction of the image before attack:  [[0.01731405]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1172).png
# 118
# The prediction of the image before attack:  [[0.00092721]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1173).png
# 119
# The prediction of the image before attack:  [[0.00521278]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1174).png
# 120
# The prediction of the image before attack:  [[0.00229791]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1175).png
# 121
# The prediction of the image before attack:  [[0.35244268]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1176).png
# 122
# The prediction of the image before attack:  [[0.00065558]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1177).png
# 123
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1178).png
# 124
# The prediction of the image before attack:  [[0.00111131]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1179).png
# 125
# The prediction of the image before attack:  [[0.23375365]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1180).png
# 126
# The prediction of the image before attack:  [[0.01410274]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(545).png
# 127
# The prediction of the image before attack:  [[0.06591602]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1181).png
# 128
# The prediction of the image before attack:  [[0.0001047]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1182).png
# 129
# The prediction of the image before attack:  [[3.9192833e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1183).png
# 130
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1184).png
# 131
# The prediction of the image before attack:  [[0.00041705]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1185).png
# 132
# The prediction of the image before attack:  [[0.7680307]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1186).png
# 133
# The prediction of the image before attack:  [[0.9641809]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(546).png
# 134
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1187).png
# 135
# The prediction of the image before attack:  [[0.82776695]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1188).png
# 136
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1189).png
# 137
# The prediction of the image before attack:  [[0.89291495]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(547).png
# 138
# The prediction of the image before attack:  [[0.34635127]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1190).png
# 139
# The prediction of the image before attack:  [[0.9746494]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1191).png
# 140
# The prediction of the image before attack:  [[3.309812e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1192).png
# 141
# The prediction of the image before attack:  [[0.98245037]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1193).png
# 142
# The prediction of the image before attack:  [[0.06171538]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1194).png
# 143
# The prediction of the image before attack:  [[0.01090473]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1195).png
# 144
# The prediction of the image before attack:  [[0.11996242]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1196).png
# 145
# The prediction of the image before attack:  [[0.7537676]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(548).png
# 146
# The prediction of the image before attack:  [[0.2899885]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(549).png
# 147
# The prediction of the image before attack:  [[0.01508688]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1197).png
# 148
# The prediction of the image before attack:  [[0.9062649]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1198).png
# 149
# The prediction of the image before attack:  [[2.0621967e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1199).png
# 150
# The prediction of the image before attack:  [[3.8281373e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1200).png
# 151
# The prediction of the image before attack:  [[2.0023249e-08]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1201).png
# 152
# The prediction of the image before attack:  [[0.48479295]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1202).png
# 153
# The prediction of the image before attack:  [[0.0014462]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(550).png
# 154
# The prediction of the image before attack:  [[0.99832517]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(551).png
# 155
# The prediction of the image before attack:  [[0.9989748]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1203).png
# 156
# The prediction of the image before attack:  [[0.03687299]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1204).png
# 157
# The prediction of the image before attack:  [[0.9571061]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1205).png
# 158
# The prediction of the image before attack:  [[0.13221613]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1206).png
# 159
# The prediction of the image before attack:  [[0.6224208]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(552).png
# 160
# The prediction of the image before attack:  [[0.2574256]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1207).png
# 161
# The prediction of the image before attack:  [[5.3238047e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1208).png
# 162
# The prediction of the image before attack:  [[1.7388478e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(553).png
# 163
# The prediction of the image before attack:  [[0.00046021]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1209).png
# 164
# The prediction of the image before attack:  [[0.00044321]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(554).png
# 165
# The prediction of the image before attack:  [[0.8282469]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1210).png
# 166
# The prediction of the image before attack:  [[0.02437929]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1211).png
# 167
# The prediction of the image before attack:  [[0.5951768]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(555).png
# 168
# The prediction of the image before attack:  [[0.00401406]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(556).png
# 169
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1212).png
# 170
# The prediction of the image before attack:  [[0.644052]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1213).png
# 171
# The prediction of the image before attack:  [[5.2572952e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1214).png
# 172
# The prediction of the image before attack:  [[0.8502883]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(557).png
# 173
# The prediction of the image before attack:  [[0.9757639]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1215).png
# 174
# The prediction of the image before attack:  [[0.35244268]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1216).png
# 175
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1217).png
# 176
# The prediction of the image before attack:  [[0.08085898]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1218).png
# 177
# The prediction of the image before attack:  [[0.07602445]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(558).png
# 178
# The prediction of the image before attack:  [[0.0523413]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(559).png
# 179
# The prediction of the image before attack:  [[0.53924215]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(560).png
# 180
# The prediction of the image before attack:  [[0.00038719]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(561).png
# 181
# The prediction of the image before attack:  [[0.0340356]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1219).png
# 182
# The prediction of the image before attack:  [[0.04642906]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1220).png
# 183
# The prediction of the image before attack:  [[0.92924917]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(562).png
# 184
# The prediction of the image before attack:  [[2.0023249e-08]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1221).png
# 185
# The prediction of the image before attack:  [[0.44018596]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1222).png
# 186
# The prediction of the image before attack:  [[0.05402877]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(563).png
# 187
# The prediction of the image before attack:  [[0.19161919]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1223).png
# 188
# The prediction of the image before attack:  [[3.5726886e-09]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1224).png
# 189
# The prediction of the image before attack:  [[7.345336e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1225).png
# 190
# The prediction of the image before attack:  [[1.7489676e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(564).png
# 191
# The prediction of the image before attack:  [[0.06118567]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(565).png
# 192
# The prediction of the image before attack:  [[6.1810056e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1226).png
# 193
# The prediction of the image before attack:  [[4.9366975e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(566).png
# 194
# The prediction of the image before attack:  [[0.18038169]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(567).png
# 195
# The prediction of the image before attack:  [[0.51295435]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(568).png
# 196
# The prediction of the image before attack:  [[0.5924966]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(569).png
# 197
# The prediction of the image before attack:  [[0.0585801]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(570).png
# 198
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1227).png
# 199
# The prediction of the image before attack:  [[0.03637663]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(571).png
# 200
# The prediction of the image before attack:  [[0.82602227]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(572).png
# 201
# The prediction of the image before attack:  [[0.46801025]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(573).png
# 202
# The prediction of the image before attack:  [[0.95526206]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1228).png
# 203
# The prediction of the image before attack:  [[1.357162e-10]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(574).png
# 204
# The prediction of the image before attack:  [[1.55166e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1229).png
# 205
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1230).png
# 206
# The prediction of the image before attack:  [[0.8231158]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1231).png
# 207
# The prediction of the image before attack:  [[7.546458e-05]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1232).png
# 208
# The prediction of the image before attack:  [[0.2549423]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1233).png
# 209
# The prediction of the image before attack:  [[0.00818116]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(575).png
# 210
# The prediction of the image before attack:  [[0.0111364]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1234).png
# 211
# The prediction of the image before attack:  [[0.9252692]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(576).png
# 212
# The prediction of the image before attack:  [[0.08791583]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1235).png
# 213
# The prediction of the image before attack:  [[0.00012458]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1236).png
# 214
# The prediction of the image before attack:  [[3.6641464e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1237).png
# 215
# The prediction of the image before attack:  [[0.00427582]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(577).png
# 216
# The prediction of the image before attack:  [[0.79659384]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1238).png
# 217
# The prediction of the image before attack:  [[0.02769594]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(578).png
# 218
# The prediction of the image before attack:  [[0.01079439]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(579).png
# 219
# The prediction of the image before attack:  [[0.04496685]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(580).png
# 220
# The prediction of the image before attack:  [[4.0403347e-06]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1239).png
# 221
# The prediction of the image before attack:  [[1.596684e-07]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1240).png
# 222
# The prediction of the image before attack:  [[0.51295435]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(581).png
# 223
# The prediction of the image before attack:  [[0.1701446]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(582).png
# 224
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1241).png
# 225
# The prediction of the image before attack:  [[2.4343742e-06]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(583).png
# 226
# The prediction of the image before attack:  [[0.12737097]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(584).png
# 227
# The prediction of the image before attack:  [[0.9436395]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1242).png
# 228
# The prediction of the image before attack:  [[0.9870738]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1243).png
# 229
# The prediction of the image before attack:  [[0.00021997]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1244).png
# 230
# The prediction of the image before attack:  [[0.00237168]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1245).png
# 231
# The prediction of the image before attack:  [[0.04380035]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1246).png
# 232
# The prediction of the image before attack:  [[0.12462782]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(585).png
# 233
# The prediction of the image before attack:  [[0.00030531]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1247).png
# 234
# The prediction of the image before attack:  [[0.01196312]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1248).png
# 235
# The prediction of the image before attack:  [[8.69548e-06]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(586).png
# 236
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1249).png
# 237
# The prediction of the image before attack:  [[9.8534194e-08]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1250).png
# 238
# The prediction of the image before attack:  [[0.00038507]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1251).png
# 239
# The prediction of the image before attack:  [[0.99462056]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1252).png
# 240
# The prediction of the image before attack:  [[8.171725e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(587).png
# 241
# The prediction of the image before attack:  [[3.8281373e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1253).png
# 242
# The prediction of the image before attack:  [[1.5924453e-08]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1254).png
# 243
# The prediction of the image before attack:  [[0.01064173]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1255).png
# 244
# The prediction of the image before attack:  [[0.91801476]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1256).png
# 245
# The prediction of the image before attack:  [[0.77233565]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1257).png
# 246
# The prediction of the image before attack:  [[0.00029679]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(588).png
# 247
# The prediction of the image before attack:  [[1.220644e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1258).png
# 248
# The prediction of the image before attack:  [[6.602297e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1259).png
# 249
# The prediction of the image before attack:  [[0.00246892]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(589).png
# 250
# The prediction of the image before attack:  [[6.7619467e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1260).png
# 251
# The prediction of the image before attack:  [[6.36641e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1261).png
# 252
# The prediction of the image before attack:  [[0.00736253]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1262).png
# 253
# The prediction of the image before attack:  [[0.02114774]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1263).png
# 254
# The prediction of the image before attack:  [[5.8333414e-11]]
# The prediction of the image after 7 iterations of PGD attack: 0.999999
# No_DR(1264).png
# 255
# The prediction of the image before attack:  [[0.10088927]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1265).png
# 256
# The prediction of the image before attack:  [[1.570678e-08]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1266).png
# 257
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(590).png
# 258
# The prediction of the image before attack:  [[0.00053785]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1267).png
# 259
# The prediction of the image before attack:  [[0.00545474]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1268).png
# 260
# The prediction of the image before attack:  [[0.12402992]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(591).png
# 261
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1269).png
# 262
# The prediction of the image before attack:  [[0.00941937]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1270).png
# 263
# The prediction of the image before attack:  [[0.9252692]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(592).png
# 264
# The prediction of the image before attack:  [[0.9973008]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(593).png
# 265
# The prediction of the image before attack:  [[0.01052546]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(594).png
# 266
# The prediction of the image before attack:  [[0.00046271]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1271).png
# 267
# The prediction of the image before attack:  [[0.04496685]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(595).png
# 268
# The prediction of the image before attack:  [[0.05134135]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1272).png
# 269
# The prediction of the image before attack:  [[0.74848044]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1273).png
# 270
# The prediction of the image before attack:  [[0.08380187]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1274).png
# 271
# The prediction of the image before attack:  [[0.02085015]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1275).png
# 272
# The prediction of the image before attack:  [[0.8234446]]
# The prediction of the image after 4 iterations of PGD attack: 0.000000
# DR(596).png
# 273
# The prediction of the image before attack:  [[0.00435024]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1276).png
# 274
# The prediction of the image before attack:  [[0.5951768]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(597).png
# 275
# The prediction of the image before attack:  [[2.704636e-07]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1277).png
# 276
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1278).png
# 277
# The prediction of the image before attack:  [[0.4075514]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(598).png
# 278
# The prediction of the image before attack:  [[0.8890437]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(599).png
# 279
# The prediction of the image before attack:  [[0.00058558]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1279).png
# 280
# The prediction of the image before attack:  [[0.95366025]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(600).png
# 281
# The prediction of the image before attack:  [[0.00034569]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1280).png
# 282
# The prediction of the image before attack:  [[0.00759683]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(601).png
# 283
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1281).png
# 284
# The prediction of the image before attack:  [[0.179843]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(602).png
# 285
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1282).png
# 286
# The prediction of the image before attack:  [[0.2433236]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(603).png
# 287
# The prediction of the image before attack:  [[0.00124568]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(604).png
# 288
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1283).png
# 289
# The prediction of the image before attack:  [[0.9860833]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1284).png
# 290
# The prediction of the image before attack:  [[3.710513e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(605).png
# 291
# The prediction of the image before attack:  [[0.00040979]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1285).png
# 292
# The prediction of the image before attack:  [[0.12096673]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(606).png
# 293
# The prediction of the image before attack:  [[0.7567029]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1286).png
# 294
# The prediction of the image before attack:  [[0.48785657]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(607).png
# 295
# The prediction of the image before attack:  [[0.01021944]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1287).png
# 296
# The prediction of the image before attack:  [[0.00333084]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1288).png
# 297
# The prediction of the image before attack:  [[0.14624096]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1289).png
# 298
# The prediction of the image before attack:  [[0.00317826]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1290).png
# 299
# The prediction of the image before attack:  [[0.98851585]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1291).png
# 300
# The prediction of the image before attack:  [[0.4861517]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(608).png
# 301
# The prediction of the image before attack:  [[0.9657152]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1292).png
# 302
# The prediction of the image before attack:  [[0.929262]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(609).png
# 303
# The prediction of the image before attack:  [[5.2320927e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(610).png
# 304
# The prediction of the image before attack:  [[0.03564567]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1293).png
# 305
# The prediction of the image before attack:  [[0.02384421]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(611).png
# 306
# The prediction of the image before attack:  [[0.00550233]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1294).png
# 307
# The prediction of the image before attack:  [[0.00033384]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1295).png
# 308
# The prediction of the image before attack:  [[6.7619467e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1296).png
# 309
# The prediction of the image before attack:  [[0.00061567]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1297).png
# 310
# The prediction of the image before attack:  [[0.01271204]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1298).png
# 311
# The prediction of the image before attack:  [[0.89479744]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1299).png
# 312
# The prediction of the image before attack:  [[0.52247]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1300).png
# 313
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1301).png
# 314
# The prediction of the image before attack:  [[0.01466926]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(612).png
# 315
# The prediction of the image before attack:  [[0.00053785]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1302).png
# 316
# The prediction of the image before attack:  [[0.00040979]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1303).png
# 317
# The prediction of the image before attack:  [[9.441308e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(613).png
# 318
# The prediction of the image before attack:  [[2.9432851e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(614).png
# 319
# The prediction of the image before attack:  [[0.99919766]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1304).png
# 320
# The prediction of the image before attack:  [[1.7489676e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(615).png
# 321
# The prediction of the image before attack:  [[0.03836177]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1305).png
# 322
# The prediction of the image before attack:  [[0.00080311]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1306).png
# 323
# The prediction of the image before attack:  [[4.925735e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1307).png
# 324
# The prediction of the image before attack:  [[0.00060145]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1308).png
# 325
# The prediction of the image before attack:  [[1.4786311e-08]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1309).png
# 326
# The prediction of the image before attack:  [[0.01346724]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1310).png
# 327
# The prediction of the image before attack:  [[0.00201166]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1311).png
# 328
# The prediction of the image before attack:  [[0.00131614]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(616).png
# 329
# The prediction of the image before attack:  [[0.6392199]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(617).png
# 330
# The prediction of the image before attack:  [[0.00550233]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1312).png
# 331
# The prediction of the image before attack:  [[7.345336e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1313).png
# 332
# The prediction of the image before attack:  [[4.9967824e-17]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1314).png
# 333
# The prediction of the image before attack:  [[0.7265784]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1315).png
# 334
# The prediction of the image before attack:  [[4.6109665e-07]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(618).png
# 335
# The prediction of the image before attack:  [[0.00030149]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(619).png
# 336
# The prediction of the image before attack:  [[0.7836448]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(620).png
# 337
# The prediction of the image before attack:  [[0.6902253]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(621).png
# 338
# The prediction of the image before attack:  [[4.2945603e-06]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1316).png
# 339
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1317).png
# 340
# The prediction of the image before attack:  [[0.00548888]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(622).png
# 341
# The prediction of the image before attack:  [[0.29678828]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1318).png
# 342
# The prediction of the image before attack:  [[0.00014488]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1319).png
# 343
# The prediction of the image before attack:  [[3.7018464e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1320).png
# 344
# The prediction of the image before attack:  [[0.66341436]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1321).png
# 345
# The prediction of the image before attack:  [[4.8167774e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1322).png
# 346
# The prediction of the image before attack:  [[0.53757423]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(623).png
# 347
# The prediction of the image before attack:  [[0.00183374]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(624).png
# 348
# The prediction of the image before attack:  [[6.342159e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1323).png
# 349
# The prediction of the image before attack:  [[6.848939e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1324).png
# 350
# The prediction of the image before attack:  [[0.00011226]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1325).png
# 351
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1326).png
# 352
# The prediction of the image before attack:  [[0.53672755]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(625).png
# 353
# The prediction of the image before attack:  [[0.05108991]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1327).png
# 354
# The prediction of the image before attack:  [[0.82602227]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(626).png
# 355
# The prediction of the image before attack:  [[0.21740328]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1328).png
# 356
# The prediction of the image before attack:  [[1.3315479e-06]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1329).png
# 357
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1330).png
# 358
# The prediction of the image before attack:  [[0.92571294]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1331).png
# 359
# The prediction of the image before attack:  [[0.01001649]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1332).png
# 360
# The prediction of the image before attack:  [[4.6163215e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1333).png
# 361
# The prediction of the image before attack:  [[0.02906004]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1334).png
# 362
# The prediction of the image before attack:  [[2.8639932e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1335).png
# 363
# The prediction of the image before attack:  [[0.00054949]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1336).png
# 364
# The prediction of the image before attack:  [[0.0005608]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(627).png
# 365
# The prediction of the image before attack:  [[0.84532005]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1337).png
# 366
# The prediction of the image before attack:  [[0.08085898]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1338).png
# 367
# The prediction of the image before attack:  [[0.9743114]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(628).png
# 368
# The prediction of the image before attack:  [[0.15997481]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(629).png
# 369
# The prediction of the image before attack:  [[0.21155718]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(630).png
# 370
# The prediction of the image before attack:  [[5.3238047e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1339).png
# 371
# The prediction of the image before attack:  [[0.00045463]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1340).png
# 372
# The prediction of the image before attack:  [[0.10088927]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1341).png
# 373
# The prediction of the image before attack:  [[0.0006958]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1342).png
# 374
# The prediction of the image before attack:  [[1.9982024e-10]]
# The prediction of the image after 1 iterations of PGD attack: 0.000000
# DR(631).png
# 375
# The prediction of the image before attack:  [[0.00325594]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(632).png
# 376
# The prediction of the image before attack:  [[1.9497136e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1343).png
# 377
# The prediction of the image before attack:  [[0.21893604]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(633).png
# 378
# The prediction of the image before attack:  [[0.00906687]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(634).png
# 379
# The prediction of the image before attack:  [[0.6685875]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(635).png
# 380
# The prediction of the image before attack:  [[2.3138304e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(636).png
# 381
# The prediction of the image before attack:  [[0.29678828]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1344).png
# 382
# The prediction of the image before attack:  [[0.10651375]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(637).png
# 383
# The prediction of the image before attack:  [[0.00011226]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1345).png
# 384
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1346).png
# 385
# The prediction of the image before attack:  [[3.3532307e-12]]
# The prediction of the image after 6 iterations of PGD attack: 1.000000
# No_DR(1347).png
# 386
# The prediction of the image before attack:  [[0.98308635]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1348).png
# 387
# The prediction of the image before attack:  [[6.800973e-05]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1349).png
# 388
# The prediction of the image before attack:  [[0.9436395]]
# The prediction of the image after 2 iterations of PGD attack: 1.000000
# No_DR(1350).png
# 389
# The prediction of the image before attack:  [[1.9476756e-09]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1351).png
# 390
# The prediction of the image before attack:  [[0.03841821]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1352).png
# 391
# The prediction of the image before attack:  [[0.73098165]]
# The prediction of the image after 3 iterations of PGD attack: 0.000000
# DR(638).png
# 392
# The prediction of the image before attack:  [[0.01365414]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1353).png
# 393
# The prediction of the image before attack:  [[0.00324749]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1354).png
# 394
# The prediction of the image before attack:  [[3.6641464e-05]]
# The prediction of the image after 5 iterations of PGD attack: 1.000000
# No_DR(1355).png
# 395
# The prediction of the image before attack:  [[0.03841821]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1356).png
# 396
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 2 iterations of PGD attack: 0.000000
# DR(639).png
# 397
# The prediction of the image before attack:  [[0.0010892]]
# The prediction of the image after 4 iterations of PGD attack: 1.000000
# No_DR(1357).png
# 398
# The prediction of the image before attack:  [[0.9774889]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1358).png
# 399
# The prediction of the image before attack:  [[0.06923233]]
# The prediction of the image after 3 iterations of PGD attack: 1.000000
# No_DR(1359).png

# %%
# !zip -r ./PGD_BBA_perturbed_img.zip ./PGD_BBA_perturbed_img/
# Out:
#   adding: PGD_BBA_perturbed_img/ (stored 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/ (stored 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(877).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(744).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(762).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(255).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1184).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1089).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(986).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(771).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(187).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1317).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1335).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(43).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(503).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(607).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(221).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1310).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(816).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(566).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(81).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(458).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1180).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(584).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(401).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(501).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(822).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(215).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(635).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(625).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(415).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1271).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(229).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(968).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(917).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(497).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1352).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(847).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(971).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1080).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(652).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1010).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1288).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(631).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(141).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(15).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(946).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1275).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1131).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(386).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(593).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(751).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1253).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1149).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(321).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1121).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(75).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(929).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(350).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(537).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1111).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1000).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(972).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(667).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(235).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(421).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(585).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(175).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(117).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(549).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(901).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(236).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(538).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(428).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(297).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(278).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(721).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(925).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(628).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(247).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(193).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(831).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(591).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(129).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(101).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(736).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1319).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(621).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(69).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(163).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(717).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(260).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(722).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(760).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(668).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(797).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(325).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(480).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1103).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(478).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1177).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1068).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(367).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1345).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(598).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(893).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1126).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(846).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(711).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1129).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(127).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(300).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1203).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1192).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(230).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(700).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(395).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(337).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(863).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(531).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(605).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1301).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(257).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(248).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1125).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1339).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(676).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(976).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(586).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(124).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(220).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1017).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(708).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(524).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(918).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(482).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(32).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(326).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1279).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(56).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1226).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(332).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(552).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(769).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(733).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1065).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(418).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(882).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(859).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1015).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(900).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(681).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(806).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(137).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1082).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(21).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(942).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(172).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(494).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(474).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1236).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(992).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1072).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(178).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1004).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1053).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(836).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1085).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1096).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(873).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1115).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1038).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(515).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1354).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(116).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(216).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(437).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1295).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(961).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(119).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1167).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(897).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(830).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(923).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(252).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(381).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(370).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(739).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(439).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(289).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(77).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1029).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1155).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(490).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(256).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1331).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(686).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(48).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(205).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(956).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(324).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1048).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(813).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1257).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1308).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(90).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(930).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(843).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(965).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1171).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(815).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(679).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(957).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(445).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(140).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(134).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(895).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(978).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(347).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1195).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(113).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1277).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(214).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(135).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(99).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(451).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(648).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(24).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(629).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(886).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1193).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(10).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(298).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1255).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(606).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1333).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(273).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(639).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1124).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(442).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(753).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1248).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1220).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(11).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(899).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1107).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(176).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(713).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(434).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1084).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(453).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1160).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1294).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(600).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1289).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(123).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(131).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(693).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(82).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(267).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(544).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(790).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(59).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(517).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(496).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(943).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(903).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1305).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1323).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(73).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1260).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1217).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(459).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(661).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(498).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(670).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(817).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(808).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(758).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(292).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(492).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(142).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1040).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1134).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(532).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1297).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(866).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(810).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1187).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(952).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(703).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(384).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1216).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(807).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(97).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(902).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1311).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(546).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1256).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(353).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(838).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1135).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(339).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(385).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(850).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(587).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(725).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(44).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(518).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(440).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(291).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(95).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(203).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1249).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(592).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(924).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1258).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(196).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(951).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(157).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(856).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(128).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1097).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(697).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1190).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1003).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1232).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(112).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1178).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(609).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(551).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1321).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(485).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(735).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(637).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1174).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(387).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(921).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(47).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1268).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(166).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1329).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(564).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(469).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(618).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(105).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(540).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1119).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(655).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(186).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(928).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1280).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(31).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(183).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1175).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1233).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(25).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1170).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1290).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(14).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(905).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(208).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(334).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(536).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1066).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1313).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(691).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1099).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(824).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1026).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1070).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1067).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1208).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(349).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(694).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(766).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1318).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(132).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(819).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(100).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(879).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(197).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1008).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1198).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(476).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1211).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(765).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1296).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1241).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1348).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(167).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(638).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(932).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(57).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(20).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1137).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(369).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(338).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(559).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(288).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1179).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(46).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(767).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(284).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(184).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(669).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(407).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(519).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(317).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(164).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(774).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(608).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(915).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(110).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(448).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(223).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1344).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(872).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(340).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1229).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(941).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(226).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(973).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1218).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(975).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(463).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(878).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1019).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(805).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1110).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(589).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(104).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1357).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(755).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1214).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1043).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(327).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1183).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(199).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1123).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(242).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1342).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(645).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(138).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1186).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1005).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1158).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(997).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(657).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(835).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1035).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(898).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1127).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(696).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(673).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(582).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1130).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(202).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(438).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1139).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(118).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(38).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1246).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(779).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(720).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(715).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(405).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(227).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(171).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(341).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(456).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1133).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(821).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(931).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1022).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1191).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(801).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(642).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1270).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1059).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1200).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(237).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(177).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(27).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(832).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(663).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(219).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1006).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(301).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(471).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(460).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(74).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(309).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(89).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(330).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(170).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1244).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(535).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(756).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1338).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(447).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(441).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(429).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(683).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1299).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(192).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(523).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(662).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1215).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(419).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(358).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(446).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(426).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(238).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(966).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(699).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(8).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(841).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(318).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1324).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1128).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(9).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1118).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1136).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(98).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1027).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1343).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(464).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(834).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(0).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(704).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(121).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(161).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(680).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1138).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1036).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(916).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(770).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(788).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(234).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(45).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(632).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(303).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(403).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(783).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(716).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(261).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(246).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1146).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(107).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1024).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(106).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(351).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1239).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(262).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(844).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(400).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(849).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1039).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(516).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(754).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1182).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(281).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(435).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(87).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1064).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1281).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(643).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1013).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(883).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(19).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(417).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(2).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(800).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(880).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(998).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1145).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(23).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1050).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(550).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(144).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(355).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(602).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1112).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1197).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(151).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1052).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(475).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(63).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(85).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(969).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1162).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(541).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(967).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(936).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(315).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(554).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(571).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1114).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(290).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1243).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(375).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(26).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(947).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(502).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(148).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(964).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1014).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1108).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(804).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(934).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(266).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(251).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1189).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1227).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(329).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(889).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(864).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(620).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1020).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(511).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1156).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1221).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(553).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(672).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(319).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1341).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(617).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(397).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1164).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1231).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(231).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1353).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(465).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1153).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(354).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(989).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1141).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(892).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1032).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(780).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(509).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1057).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(979).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1266).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1116).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1091).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(650).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1304).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(802).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(91).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(200).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1041).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(65).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(174).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(40).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(357).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(212).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(3).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(823).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(484).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(500).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(457).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(922).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(312).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(706).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1303).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(198).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(768).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(854).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(254).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(114).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(644).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(30).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(787).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(356).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1350).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(323).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(542).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(422).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1325).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(687).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(876).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1147).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1078).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(240).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(955).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1025).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(688).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(919).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1196).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(191).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(912).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1316).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1291).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(37).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(695).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(894).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(316).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(259).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(103).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1169).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1230).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1261).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(7).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(959).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(506).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(743).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(489).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(993).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(548).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(1092).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(614).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/No_DR/No_DR(839).png (deflated 0%)
# ...
#   adding: PGD_BBA_perturbed_img/DR/DR(442).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(538).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(38).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(537).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(406).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(264).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(283).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(365).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(222).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(601).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(532).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(397).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(95).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(269).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(575).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(637).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(46).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(583).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(178).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(412).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(337).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(369).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(425).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(510).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(371).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(276).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(341).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(570).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(40).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(300).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(496).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(91).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(534).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(213).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(126).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(557).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(98).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(140).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(501).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(166).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(174).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(433).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(576).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(388).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(125).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(410).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(32).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(539).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(133).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(244).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(638).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(480).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(542).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(378).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(88).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(191).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(407).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(183).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(295).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(195).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(132).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(620).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(574).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(228).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(408).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(185).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(405).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(614).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(324).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(138).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(156).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(634).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(242).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(267).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(391).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(59).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(52).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(515).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(221).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(451).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(85).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(590).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(453).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(231).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(218).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(220).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(627).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(62).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(117).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(420).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(560).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(193).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(273).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(172).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(431).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(335).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(219).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(553).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(289).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(275).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(291).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(1).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(217).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(404).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(89).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(438).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(625).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(623).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(582).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(15).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(163).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(224).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(591).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(536).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(411).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(141).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(173).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(487).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(44).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(535).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(343).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(207).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(92).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(304).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(247).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(31).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(7).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(473).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(68).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(615).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(479).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(144).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(293).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(63).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(632).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(455).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(251).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(135).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(201).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(103).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(84).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(155).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(443).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(355).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(558).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(610).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(26).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(302).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(429).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(223).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(296).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(445).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(594).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(461).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(294).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(277).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(611).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(579).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(549).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(506).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(154).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(130).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(351).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(633).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(561).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(500).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(556).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(131).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(446).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(392).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(108).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(64).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(209).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(454).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(317).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(518).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(13).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(194).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(152).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(33).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(528).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(171).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(624).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(566).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(17).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(34).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(421).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(416).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(106).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(182).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(192).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(279).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(345).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(45).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(203).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(413).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(346).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(123).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(226).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(551).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(30).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(423).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(370).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(339).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(23).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(418).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(107).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(197).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(639).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(246).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(426).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(448).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(327).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(401).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(353).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(363).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(486).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(546).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(188).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(176).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(373).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(564).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(96).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(104).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(129).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(24).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(61).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(476).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(190).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(490).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(595).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(180).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(386).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(586).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(280).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(514).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(315).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(358).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(70).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(488).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(99).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(399).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(187).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(147).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(58).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(109).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(587).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(262).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(419).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(110).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(396).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(394).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(626).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(550).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(631).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(305).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(439).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(568).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(322).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(543).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(357).png (deflated 0%)
#   adding: PGD_BBA_perturbed_img/DR/DR(607).png (deflated 0%)

# %%
# !cp PGD_BBA_perturbed_img.zip 'drive/MyDrive/eye_pacs/Perturbed_images/PGD_BBA_perturbed_img.zip'
# Out:
# cp: cannot create regular file 'drive/MyDrive/eye_pacs/Perturbed_images/PGD_BBA_perturbed_img.zip': No such file or directory

# %% [markdown]
# # Faulty Prediction (PGD)

# %%
# !cp 'drive/MyDrive/eye_pacs/Perturbed_images/PGD_BBA_perturbed_img.zip' PGD_BBA_perturbed_img.zip
# Out:
# cp: cannot stat 'drive/MyDrive/eye_pacs/Perturbed_images/PGD_BBA_perturbed_img.zip': No such file or directory

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "PGD_BBA_perturbed_img.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    #zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %%
import cv2

dr_img = []
for data in os.listdir('PGD_BBA_perturbed_img/DR'):
        img_d = cv2.imread('PGD_BBA_perturbed_img/DR/{}'.format(data))
        dr_img.append(img_d)

        
no_dr_img = []        
for data in os.listdir('PGD_BBA_perturbed_img/No_DR'):
        img_d = cv2.imread('PGD_BBA_perturbed_img/No_DR/{}'.format(data))        
        no_dr_img.append(img_d)

# %%
dr_img = np.array(dr_img)
dr_pred_0 = model.predict(dr_img)

# %%
dr_img_pred_int = []
for i in dr_pred_0:
  if i < 0.5:
    dr_img_pred_int.append(0)
  else:
    dr_img_pred_int.append(1)

# %%
dr_img_pred_int = np.array(dr_img_pred_int)
no_zero = (dr_img_pred_int ==0).sum()
no_one = (dr_img_pred_int==1).sum()
print("Total no. of DR images = ", dr_pred_0.size)
print("Predicted as No DR = ",no_zero)
print("Predicted as DR = ", no_one)

plt.title('BBA - PGD perturbed images of DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.bar(["no_dr", "dr"], [no_zero, no_one] , color=["red", "green"])
plt.show()
# Out:
# Total no. of DR images =  640
# Predicted as No DR =  574
# Predicted as DR =  66

# %%
plt.title('BBA - PGD perturbed images of images with DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.hist(dr_pred_0.astype('float'))
plt.show()

# %%
no_dr_img = np.array(no_dr_img)
no_dr0_pred = model.predict(no_dr_img)

# %%
no_dr_img_pred_int = []
for i in no_dr0_pred:
  if i < 0.5:
    no_dr_img_pred_int.append(0)
  else:
    no_dr_img_pred_int.append(1)

# %%
no_dr_img_pred_int = np.array(no_dr_img_pred_int)
no_zero = (no_dr_img_pred_int ==0).sum()
no_one = (no_dr_img_pred_int==1).sum()
print("Total no. of No DR images = ", no_dr0_pred.size)
print("Predicted as No DR = ",no_zero)
print("Predicted as DR = ", no_one)


plt.title('BBA - PGD perturbed images of No DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.bar(["no_dr", "dr"], [no_zero, no_one] , color=["red", "green"])
plt.show()
# Out:
# Total no. of No DR images =  1360
# Predicted as No DR =  743
# Predicted as DR =  617

# %%
plt.title('BBA-PGD perturbed images for images with No-DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.hist(no_dr0_pred.astype('float'))
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = []
y_pred = []
for i in dr_img_pred_int:
  y_pred.append(i)
  y_true.append(1)

for i in no_dr_img_pred_int:
  y_pred.append(i)
  y_true.append(0)

cnf = confusion_matrix(y_true, y_pred)
cnf
disp = ConfusionMatrixDisplay(cnf,display_labels=["no_dr", "dr"])
disp.plot()

# %% [markdown]
# # BIM ATTACK

# %%
# !cp 'drive/MyDrive/models/vgg16__Retinopathy_attacker_model.zip' vgg16_Retinopathy_attacker.zip
# Out:
# cp: cannot stat 'drive/MyDrive/models/vgg16__Retinopathy_attacker_model.zip': No such file or directory

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "vgg16_retinopathy_attacker.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# attack_model/                                  2021-06-29 13:17:16            0
# attack_model/vgg16_Retinopathy_attacker/       2021-06-29 15:18:30            0
# attack_model/vgg16_Retinopathy_attacker/saved_model.pb 2021-06-29 15:18:30       377422
# attack_model/vgg16_Retinopathy_attacker/assets/ 2021-06-29 13:17:18            0
# attack_model/vgg16_Retinopathy_attacker/keras_metadata.pb 2021-06-29 15:18:30        53520
# attack_model/vgg16_Retinopathy_attacker/variables/ 2021-06-29 15:18:30            0
# attack_model/vgg16_Retinopathy_attacker/variables/variables.data-00000-of-00001 2021-06-29 15:18:30    367178320
# attack_model/vgg16_Retinopathy_attacker/variables/variables.index 2021-06-29 15:18:30         3191
# Extracting all the files now...
# Done!

# %%
#set the location to your model's location
# model_location = 'attack_model/vgg16_Retinopathy_attacker'

# from tensorflow.keras.models import load_model
# new_model = load_model(model_location)
# new_model.trainable = False

# %% [markdown]
# **FGSM**
#
# For an input image, this method uses the gradients of the loss with respect to the input image to create a new image that maximises the loss.

# %%
def fgsm(x, y_adv, epsilon):
    loss_func = tf.keras.losses.BinaryCrossentropy()
    with tf.GradientTape() as gt:
        gt.watch(x)
        
        label = new_model(x)
        loss = loss_func(y_adv, label)
        outputloss = loss.numpy()
        #print (loss)
        
    grad = gt.gradient(loss, x)
    gamma = epsilon * tf.sign(grad)
    
    return gamma, outputloss

# %% [markdown]
# **BIM**
#
# FGSM is performed certain number of times.
#
# In many cases, the number of iterations is already given.
#
# But here, a number of iterations are performed until we reach the target. Here, the attack stops once the loss for the given image goes below a particular value (2 in this case).
#
# On an average the number of iterations performed here is 3-4.
#
# The recursive function of BIM is:
#
# ![image.png](data:image/png;base64,...)

# %%
def BIM(x, y_adv, eps):
  alpha = eps/10
  itrs = 0
  while 1:
    noise, loss = fgsm(x, y_adv,alpha)
    #noise = tf.clip_by_value(x-noise-img, -eps, eps)
    x = x - noise

    #preds = new_model.predict(x)
    #print(preds)
    itrs+=1
    if loss<2 or itrs>10:
      break

  return x, itrs

# %% [markdown]
# This function takes in the image details and target value (to which the image has to change to) and saves the perturbed image in the given destination.

# %%
def create_perturb(image_name, fromfolder, tofolder, yval):
  old_img = cv2.imread(fromfolder+'/'+image_name)

  old_img = preprocessing_image(old_img)

  preds = new_model.predict(old_img)
  
  print(preds)

  intpred = round(preds[0][0])
  
  y_adv_label = yval
  
  y_adv = tf.reshape(y_adv_label, shape=[1, preds.shape[-1]])
 
  print(y_adv)
  x_adv = BIM(img, y_adv, 1.4)

  noise = x_adv - old_img
  
  newpreds = new_model.predict(x_adv)
  
  print(newpreds)
  save_img(tofolder+'/'+image_name, x_adv[0])

# %%
which_number = 4

#new_img = img[which_number][0]
#actual_label = img[which_number][1]

new_img = X_train[which_number]
actual_label = Y_train[which_number]

new_img = preprocessing_image(new_img)
y_label = 0
if actual_label==0:
  y_label = 1

old_pred = new_model.predict(new_img)
plt.imshow(new_img[0]/255)
plt.title('Original Image, Pred: '+str(old_pred[0][0]))
plt.show()

y_adv = tf.reshape(y_label, shape=[1, old_pred.shape[-1]])

x_adv, itrs = BIM(new_img, y_adv, 1.4)

noise = x_adv - new_img
plt.imshow(noise[0])
plt.title('Noise while trying to attack')
plt.show()

new_preds = new_model.predict(x_adv)
print("The prediction of the image after %d iterations of BIM attack %f" % ( itrs, new_preds[0][0]))

plt.imshow(x_adv[0]/255)
plt.title('Perturbed image Preds: '+str(new_preds[0][0]))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The prediction of the image after 1 iterations of BIM attack 0.000000

# %% [markdown]
# # perturbation creation

# %%
def create_perturb_bim(old_img, image_name, tofolder, y_val):
  #old_img = cv2.imread(fromfolder+'/'+image_name)
  old_img = preprocessing_image(old_img)

  #actual prediction by the model
  preds = new_model.predict(old_img)
  print("The prediction of the image before attack: ", preds)

  #y_val = 0
    
  #if preds[0][0]<0.5:
    #y_val = 1
    
  #target value
  y_adv_label = y_val
  y_adv = tf.reshape(y_adv_label, shape=[1, preds.shape[-1]])


  #adverserial image


  x_adv, itrs = BIM(old_img, y_adv, 1.4)

  #here noise is calculated to display it, it is not necessary to show the noise
  #noise = x_adv - img
  #plt.imshow(noise[0])
  #plt.show()


  #prediction by the model after adversarial attack
  newpreds = new_model.predict(x_adv)
  print("The prediction of the image after %d iterations of BIM attack: %f" % ( itrs, newpreds[0][0]))

  #saving image to the destination
  save_img(tofolder+'/'+image_name, x_adv[0])

# %%
# !mkdir BIM_BBA_perturbed_img
# !mkdir BIM_BBA_perturbed_img/No_DR
# !mkdir BIM_BBA_perturbed_img/DR

# %%
dr = 0
no_dr = 0

for i,d in enumerate(X_train):
  print(i)
  if Y_train[i] == 1:
    create_perturb_bim(d, 'DR('+str(dr)+').png', 'BIM_BBA_perturbed_img/DR/', 0)
    print('DR('+str(dr)+').png')
    dr+=1
  else:
    create_perturb_bim(d, 'No_DR('+str(no_dr)+').png', 'BIM_BBA_perturbed_img/No_DR/', 1)
    print('No_DR('+str(no_dr)+').png')
    no_dr+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# 350
# The prediction of the image before attack:  [[0.00308061]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(117).png
# 351
# The prediction of the image before attack:  [[1.0556156e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999980
# No_DR(233).png
# 352
# The prediction of the image before attack:  [[0.3999959]]
# The prediction of the image after 1 iterations of BIM attack: 0.000665
# DR(118).png
# 353
# The prediction of the image before attack:  [[0.7007907]]
# The prediction of the image after 1 iterations of BIM attack: 0.998961
# No_DR(234).png
# 354
# The prediction of the image before attack:  [[0.00025572]]
# The prediction of the image after 2 iterations of BIM attack: 0.999980
# No_DR(235).png
# 355
# The prediction of the image before attack:  [[0.9657152]]
# The prediction of the image after 1 iterations of BIM attack: 0.999869
# No_DR(236).png
# 356
# The prediction of the image before attack:  [[0.00436948]]
# The prediction of the image after 2 iterations of BIM attack: 0.999998
# No_DR(237).png
# 357
# The prediction of the image before attack:  [[0.14137271]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(119).png
# 358
# The prediction of the image before attack:  [[0.00044321]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(120).png
# 359
# The prediction of the image before attack:  [[0.55488294]]
# The prediction of the image after 1 iterations of BIM attack: 0.000192
# DR(121).png
# 360
# The prediction of the image before attack:  [[0.11842241]]
# The prediction of the image after 2 iterations of BIM attack: 0.999747
# No_DR(238).png
# 361
# The prediction of the image before attack:  [[0.76074356]]
# The prediction of the image after 1 iterations of BIM attack: 0.994018
# No_DR(239).png
# 362
# The prediction of the image before attack:  [[0.00038507]]
# The prediction of the image after 2 iterations of BIM attack: 0.997800
# No_DR(240).png
# 363
# The prediction of the image before attack:  [[4.551396e-08]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(122).png
# 364
# The prediction of the image before attack:  [[0.79690456]]
# The prediction of the image after 1 iterations of BIM attack: 0.000062
# DR(123).png
# 365
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(124).png
# 366
# The prediction of the image before attack:  [[0.00642736]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(125).png
# 367
# The prediction of the image before attack:  [[0.02609403]]
# The prediction of the image after 2 iterations of BIM attack: 0.998079
# No_DR(241).png
# 368
# The prediction of the image before attack:  [[0.00237168]]
# The prediction of the image after 2 iterations of BIM attack: 0.999946
# No_DR(242).png
# 369
# The prediction of the image before attack:  [[0.04075756]]
# The prediction of the image after 1 iterations of BIM attack: 0.000040
# DR(126).png
# 370
# The prediction of the image before attack:  [[0.53924215]]
# The prediction of the image after 1 iterations of BIM attack: 0.002832
# DR(127).png
# 371
# The prediction of the image before attack:  [[1.2438064e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999999
# No_DR(243).png
# 372
# The prediction of the image before attack:  [[0.6049641]]
# The prediction of the image after 1 iterations of BIM attack: 0.000012
# DR(128).png
# 373
# The prediction of the image before attack:  [[0.11820357]]
# The prediction of the image after 1 iterations of BIM attack: 0.000110
# DR(129).png
# 374
# The prediction of the image before attack:  [[0.00167728]]
# The prediction of the image after 2 iterations of BIM attack: 0.990802
# No_DR(244).png
# 375
# The prediction of the image before attack:  [[0.9996604]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(130).png
# 376
# The prediction of the image before attack:  [[0.00013524]]
# The prediction of the image after 2 iterations of BIM attack: 0.999824
# No_DR(245).png
# 377
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 2 iterations of BIM attack: 0.999823
# No_DR(246).png
# 378
# The prediction of the image before attack:  [[0.00281985]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(131).png
# 379
# The prediction of the image before attack:  [[0.00029971]]
# The prediction of the image after 2 iterations of BIM attack: 0.995479
# No_DR(247).png
# 380
# The prediction of the image before attack:  [[0.00098392]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(132).png
# 381
# The prediction of the image before attack:  [[0.02431036]]
# The prediction of the image after 1 iterations of BIM attack: 0.000033
# DR(133).png
# 382
# The prediction of the image before attack:  [[0.9998196]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(134).png
# 383
# The prediction of the image before attack:  [[1.80076e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999987
# No_DR(248).png
# 384
# The prediction of the image before attack:  [[0.00050446]]
# The prediction of the image after 2 iterations of BIM attack: 0.996511
# No_DR(249).png
# 385
# The prediction of the image before attack:  [[0.9746494]]
# The prediction of the image after 1 iterations of BIM attack: 0.999829
# No_DR(250).png
# 386
# The prediction of the image before attack:  [[0.00194008]]
# The prediction of the image after 2 iterations of BIM attack: 0.999651
# No_DR(251).png
# 387
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 3 iterations of BIM attack: 0.999718
# No_DR(252).png
# 388
# The prediction of the image before attack:  [[0.91776156]]
# The prediction of the image after 2 iterations of BIM attack: 0.000226
# DR(135).png
# 389
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 2 iterations of BIM attack: 0.999678
# No_DR(253).png
# 390
# The prediction of the image before attack:  [[0.00333084]]
# The prediction of the image after 2 iterations of BIM attack: 0.999984
# No_DR(254).png
# 391
# The prediction of the image before attack:  [[0.000794]]
# The prediction of the image after 2 iterations of BIM attack: 0.999534
# No_DR(255).png
# 392
# The prediction of the image before attack:  [[0.99462056]]
# The prediction of the image after 1 iterations of BIM attack: 1.000000
# No_DR(256).png
# 393
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 2 iterations of BIM attack: 0.999916
# No_DR(257).png
# 394
# The prediction of the image before attack:  [[0.00021997]]
# The prediction of the image after 2 iterations of BIM attack: 0.998410
# No_DR(258).png
# 395
# The prediction of the image before attack:  [[3.1753276e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.997245
# No_DR(259).png
# 396
# The prediction of the image before attack:  [[0.02906004]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(260).png
# 397
# The prediction of the image before attack:  [[0.2111554]]
# The prediction of the image after 1 iterations of BIM attack: 0.999496
# No_DR(261).png
# 398
# The prediction of the image before attack:  [[0.0980843]]
# The prediction of the image after 1 iterations of BIM attack: 0.000125
# DR(136).png
# 399
# The prediction of the image before attack:  [[0.20053637]]
# The prediction of the image after 1 iterations of BIM attack: 0.000797
# DR(137).png
# 400
# The prediction of the image before attack:  [[4.567325e-09]]
# The prediction of the image after 4 iterations of BIM attack: 0.999961
# No_DR(262).png
# 401
# The prediction of the image before attack:  [[0.22908147]]
# The prediction of the image after 1 iterations of BIM attack: 0.997000
# No_DR(263).png
# 402
# The prediction of the image before attack:  [[0.01048725]]
# The prediction of the image after 1 iterations of BIM attack: 0.000050
# DR(138).png
# 403
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 1 iterations of BIM attack: 0.000003
# DR(139).png
# 404
# The prediction of the image before attack:  [[0.6649728]]
# The prediction of the image after 1 iterations of BIM attack: 0.000020
# DR(140).png
# 405
# The prediction of the image before attack:  [[0.9998771]]
# The prediction of the image after 1 iterations of BIM attack: 1.000000
# No_DR(264).png
# 406
# The prediction of the image before attack:  [[0.01388274]]
# The prediction of the image after 2 iterations of BIM attack: 0.995336
# No_DR(265).png
# 407
# The prediction of the image before attack:  [[0.00425439]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(266).png
# 408
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999997
# No_DR(267).png
# 409
# The prediction of the image before attack:  [[6.873569e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999827
# No_DR(268).png
# 410
# The prediction of the image before attack:  [[0.91776156]]
# The prediction of the image after 2 iterations of BIM attack: 0.000226
# DR(141).png
# 411
# The prediction of the image before attack:  [[0.82776695]]
# The prediction of the image after 1 iterations of BIM attack: 0.998435
# No_DR(269).png
# 412
# The prediction of the image before attack:  [[1.1526508e-09]]
# The prediction of the image after 3 iterations of BIM attack: 0.999908
# No_DR(270).png
# 413
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 2 iterations of BIM attack: 0.999794
# No_DR(271).png
# 414
# The prediction of the image before attack:  [[0.00618463]]
# The prediction of the image after 2 iterations of BIM attack: 0.999922
# No_DR(272).png
# 415
# The prediction of the image before attack:  [[9.672188e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999712
# No_DR(273).png
# 416
# The prediction of the image before attack:  [[0.0001202]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(142).png
# 417
# The prediction of the image before attack:  [[2.7734975e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999979
# No_DR(274).png
# 418
# The prediction of the image before attack:  [[0.0006958]]
# The prediction of the image after 2 iterations of BIM attack: 0.995525
# No_DR(275).png
# 419
# The prediction of the image before attack:  [[0.00194008]]
# The prediction of the image after 2 iterations of BIM attack: 0.999651
# No_DR(276).png
# 420
# The prediction of the image before attack:  [[0.01250794]]
# The prediction of the image after 1 iterations of BIM attack: 0.000004
# DR(143).png
# 421
# The prediction of the image before attack:  [[0.98192775]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(144).png
# 422
# The prediction of the image before attack:  [[3.857305e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999995
# No_DR(277).png
# 423
# The prediction of the image before attack:  [[0.02159305]]
# The prediction of the image after 2 iterations of BIM attack: 0.999915
# No_DR(278).png
# 424
# The prediction of the image before attack:  [[0.01972254]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(279).png
# 425
# The prediction of the image before attack:  [[0.6849009]]
# The prediction of the image after 1 iterations of BIM attack: 0.010922
# DR(145).png
# 426
# The prediction of the image before attack:  [[0.02159305]]
# The prediction of the image after 2 iterations of BIM attack: 0.999915
# No_DR(280).png
# 427
# The prediction of the image before attack:  [[1.3902683e-06]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(146).png
# 428
# The prediction of the image before attack:  [[3.352865e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(147).png
# 429
# The prediction of the image before attack:  [[0.4075514]]
# The prediction of the image after 1 iterations of BIM attack: 0.000922
# DR(148).png
# 430
# The prediction of the image before attack:  [[0.9653203]]
# The prediction of the image after 1 iterations of BIM attack: 0.999999
# No_DR(281).png
# 431
# The prediction of the image before attack:  [[0.81141186]]
# The prediction of the image after 1 iterations of BIM attack: 0.010329
# DR(149).png
# 432
# The prediction of the image before attack:  [[8.2811246e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.996025
# No_DR(282).png
# 433
# The prediction of the image before attack:  [[0.9452299]]
# The prediction of the image after 1 iterations of BIM attack: 0.999668
# No_DR(283).png
# 434
# The prediction of the image before attack:  [[0.8812657]]
# The prediction of the image after 1 iterations of BIM attack: 0.997473
# No_DR(284).png
# 435
# The prediction of the image before attack:  [[0.00045607]]
# The prediction of the image after 2 iterations of BIM attack: 0.997527
# No_DR(285).png
# 436
# The prediction of the image before attack:  [[0.19288674]]
# The prediction of the image after 1 iterations of BIM attack: 0.000809
# DR(150).png
# 437
# The prediction of the image before attack:  [[2.8480761e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999896
# No_DR(286).png
# 438
# The prediction of the image before attack:  [[4.6686748e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(151).png
# 439
# The prediction of the image before attack:  [[0.00095634]]
# The prediction of the image after 2 iterations of BIM attack: 0.985775
# No_DR(287).png
# 440
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 2 iterations of BIM attack: 0.999678
# No_DR(288).png
# 441
# The prediction of the image before attack:  [[0.63804716]]
# The prediction of the image after 1 iterations of BIM attack: 0.999984
# No_DR(289).png
# 442
# The prediction of the image before attack:  [[0.93048275]]
# The prediction of the image after 2 iterations of BIM attack: 0.001102
# DR(152).png
# 443
# The prediction of the image before attack:  [[1.0214059e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999999
# No_DR(290).png
# 444
# The prediction of the image before attack:  [[0.02565962]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(153).png
# 445
# The prediction of the image before attack:  [[0.00108271]]
# The prediction of the image after 2 iterations of BIM attack: 0.999758
# No_DR(291).png
# 446
# The prediction of the image before attack:  [[0.00028064]]
# The prediction of the image after 2 iterations of BIM attack: 0.999863
# No_DR(292).png
# 447
# The prediction of the image before attack:  [[0.12639117]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(293).png
# 448
# The prediction of the image before attack:  [[0.00657429]]
# The prediction of the image after 2 iterations of BIM attack: 0.999980
# No_DR(294).png
# 449
# The prediction of the image before attack:  [[0.00240135]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(154).png
# 450
# The prediction of the image before attack:  [[0.00171243]]
# The prediction of the image after 2 iterations of BIM attack: 0.999179
# No_DR(295).png
# 451
# The prediction of the image before attack:  [[2.8797892e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999946
# No_DR(296).png
# 452
# The prediction of the image before attack:  [[1.0714039e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999594
# No_DR(297).png
# 453
# The prediction of the image before attack:  [[1.0972515e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999998
# No_DR(298).png
# 454
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 1 iterations of BIM attack: 0.000003
# DR(155).png
# 455
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 2 iterations of BIM attack: 0.999794
# No_DR(299).png
# 456
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 2 iterations of BIM attack: 0.999916
# No_DR(300).png
# 457
# The prediction of the image before attack:  [[0.05606256]]
# The prediction of the image after 2 iterations of BIM attack: 0.999993
# No_DR(301).png
# 458
# The prediction of the image before attack:  [[0.9849262]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(156).png
# 459
# The prediction of the image before attack:  [[0.9973008]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(157).png
# 460
# The prediction of the image before attack:  [[1.80076e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999987
# No_DR(302).png
# 461
# The prediction of the image before attack:  [[0.6805642]]
# The prediction of the image after 1 iterations of BIM attack: 0.999676
# No_DR(303).png
# 462
# The prediction of the image before attack:  [[0.31663716]]
# The prediction of the image after 1 iterations of BIM attack: 0.000138
# DR(158).png
# 463
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 1 iterations of BIM attack: 0.999993
# No_DR(304).png
# 464
# The prediction of the image before attack:  [[0.00064854]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(159).png
# 465
# The prediction of the image before attack:  [[0.14264268]]
# The prediction of the image after 1 iterations of BIM attack: 0.992953
# No_DR(305).png
# 466
# The prediction of the image before attack:  [[0.00092721]]
# The prediction of the image after 2 iterations of BIM attack: 0.999845
# No_DR(306).png
# 467
# The prediction of the image before attack:  [[0.09689156]]
# The prediction of the image after 2 iterations of BIM attack: 0.999884
# No_DR(307).png
# 468
# The prediction of the image before attack:  [[0.81115144]]
# The prediction of the image after 1 iterations of BIM attack: 0.996699
# No_DR(308).png
# 469
# The prediction of the image before attack:  [[0.91776156]]
# The prediction of the image after 2 iterations of BIM attack: 0.000226
# DR(160).png
# 470
# The prediction of the image before attack:  [[0.1556925]]
# The prediction of the image after 1 iterations of BIM attack: 0.000012
# DR(161).png
# 471
# The prediction of the image before attack:  [[3.52073e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999968
# No_DR(309).png
# 472
# The prediction of the image before attack:  [[0.00131614]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(162).png
# 473
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 1 iterations of BIM attack: 0.999988
# No_DR(310).png
# 474
# The prediction of the image before attack:  [[0.00906687]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(163).png
# 475
# The prediction of the image before attack:  [[0.00069425]]
# The prediction of the image after 2 iterations of BIM attack: 0.994528
# No_DR(311).png
# 476
# The prediction of the image before attack:  [[0.00549212]]
# The prediction of the image after 2 iterations of BIM attack: 0.998894
# No_DR(312).png
# 477
# The prediction of the image before attack:  [[0.3172152]]
# The prediction of the image after 1 iterations of BIM attack: 0.989058
# No_DR(313).png
# 478
# The prediction of the image before attack:  [[6.0126324e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(164).png
# 479
# The prediction of the image before attack:  [[0.0011865]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(165).png
# 480
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(314).png
# 481
# The prediction of the image before attack:  [[0.14195918]]
# The prediction of the image after 1 iterations of BIM attack: 0.000031
# DR(166).png
# 482
# The prediction of the image before attack:  [[0.00634325]]
# The prediction of the image after 1 iterations of BIM attack: 0.000025
# DR(167).png
# 483
# The prediction of the image before attack:  [[0.8196551]]
# The prediction of the image after 1 iterations of BIM attack: 0.013573
# DR(168).png
# 484
# The prediction of the image before attack:  [[3.5726886e-09]]
# The prediction of the image after 4 iterations of BIM attack: 0.999980
# No_DR(315).png
# 485
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(169).png
# 486
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 2 iterations of BIM attack: 0.998146
# No_DR(316).png
# 487
# The prediction of the image before attack:  [[0.28092766]]
# The prediction of the image after 1 iterations of BIM attack: 0.002598
# DR(170).png
# 488
# The prediction of the image before attack:  [[0.21893604]]
# The prediction of the image after 1 iterations of BIM attack: 0.001355
# DR(171).png
# 489
# The prediction of the image before attack:  [[0.64962786]]
# The prediction of the image after 1 iterations of BIM attack: 0.999326
# No_DR(317).png
# 490
# The prediction of the image before attack:  [[2.2648354e-07]]
# The prediction of the image after 3 iterations of BIM attack: 0.999842
# No_DR(318).png
# 491
# The prediction of the image before attack:  [[0.01919848]]
# The prediction of the image after 2 iterations of BIM attack: 0.999655
# No_DR(319).png
# 492
# The prediction of the image before attack:  [[0.00061567]]
# The prediction of the image after 3 iterations of BIM attack: 0.999765
# No_DR(320).png
# 493
# The prediction of the image before attack:  [[6.333943e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(172).png
# 494
# The prediction of the image before attack:  [[0.06742729]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(321).png
# 495
# The prediction of the image before attack:  [[0.00044614]]
# The prediction of the image after 2 iterations of BIM attack: 0.994803
# No_DR(322).png
# 496
# The prediction of the image before attack:  [[0.00088025]]
# The prediction of the image after 2 iterations of BIM attack: 0.999936
# No_DR(323).png
# 497
# The prediction of the image before attack:  [[9.8534194e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999981
# No_DR(324).png
# 498
# The prediction of the image before attack:  [[0.10651375]]
# The prediction of the image after 1 iterations of BIM attack: 0.000079
# DR(173).png
# 499
# The prediction of the image before attack:  [[6.7619467e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999488
# No_DR(325).png
# 500
# The prediction of the image before attack:  [[0.00032921]]
# The prediction of the image after 2 iterations of BIM attack: 0.988846
# No_DR(326).png
# 501
# The prediction of the image before attack:  [[0.4838058]]
# The prediction of the image after 1 iterations of BIM attack: 0.002548
# DR(174).png
# 502
# The prediction of the image before attack:  [[0.00016847]]
# The prediction of the image after 2 iterations of BIM attack: 0.999559
# No_DR(327).png
# 503
# The prediction of the image before attack:  [[0.92571294]]
# The prediction of the image after 1 iterations of BIM attack: 0.999999
# No_DR(328).png
# 504
# The prediction of the image before attack:  [[0.02404518]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(175).png
# 505
# The prediction of the image before attack:  [[0.9482253]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(176).png
# 506
# The prediction of the image before attack:  [[0.5842693]]
# The prediction of the image after 1 iterations of BIM attack: 0.000009
# DR(177).png
# 507
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 2 iterations of BIM attack: 0.998146
# No_DR(329).png
# 508
# The prediction of the image before attack:  [[0.06692699]]
# The prediction of the image after 1 iterations of BIM attack: 0.000058
# DR(178).png
# 509
# The prediction of the image before attack:  [[9.788784e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999968
# No_DR(330).png
# 510
# The prediction of the image before attack:  [[0.10658266]]
# The prediction of the image after 1 iterations of BIM attack: 0.000161
# DR(179).png
# 511
# The prediction of the image before attack:  [[0.3671662]]
# The prediction of the image after 1 iterations of BIM attack: 0.999998
# No_DR(331).png
# 512
# The prediction of the image before attack:  [[0.00658796]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(180).png
# 513
# The prediction of the image before attack:  [[0.00143322]]
# The prediction of the image after 2 iterations of BIM attack: 0.976805
# No_DR(332).png
# 514
# The prediction of the image before attack:  [[0.8812657]]
# The prediction of the image after 1 iterations of BIM attack: 0.997473
# No_DR(333).png
# 515
# The prediction of the image before attack:  [[9.559799e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(181).png
# 516
# The prediction of the image before attack:  [[0.00039309]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(334).png
# 517
# The prediction of the image before attack:  [[0.9757639]]
# The prediction of the image after 1 iterations of BIM attack: 0.999978
# No_DR(335).png
# 518
# The prediction of the image before attack:  [[0.13221613]]
# The prediction of the image after 2 iterations of BIM attack: 0.997799
# No_DR(336).png
# 519
# The prediction of the image before attack:  [[1.8413666e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999428
# No_DR(337).png
# 520
# The prediction of the image before attack:  [[8.7201696e-10]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(182).png
# 521
# The prediction of the image before attack:  [[0.48785657]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(183).png
# 522
# The prediction of the image before attack:  [[5.298946e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.988132
# No_DR(338).png
# 523
# The prediction of the image before attack:  [[0.22254983]]
# The prediction of the image after 1 iterations of BIM attack: 0.999216
# No_DR(339).png
# 524
# The prediction of the image before attack:  [[0.00056519]]
# The prediction of the image after 2 iterations of BIM attack: 0.999198
# No_DR(340).png
# 525
# The prediction of the image before attack:  [[0.14624096]]
# The prediction of the image after 1 iterations of BIM attack: 0.998752
# No_DR(341).png
# 526
# The prediction of the image before attack:  [[0.48151445]]
# The prediction of the image after 1 iterations of BIM attack: 0.000363
# DR(184).png
# 527
# The prediction of the image before attack:  [[2.607421e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(185).png
# 528
# The prediction of the image before attack:  [[7.7317134e-07]]
# The prediction of the image after 3 iterations of BIM attack: 0.999991
# No_DR(342).png
# 529
# The prediction of the image before attack:  [[6.9116404e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999770
# No_DR(343).png
# 530
# The prediction of the image before attack:  [[0.00050446]]
# The prediction of the image after 2 iterations of BIM attack: 0.996511
# No_DR(344).png
# 531
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999997
# No_DR(345).png
# 532
# The prediction of the image before attack:  [[2.704636e-07]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(346).png
# 533
# The prediction of the image before attack:  [[0.08791583]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(347).png
# 534
# The prediction of the image before attack:  [[9.667175e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(186).png
# 535
# The prediction of the image before attack:  [[0.00012458]]
# The prediction of the image after 2 iterations of BIM attack: 0.997660
# No_DR(348).png
# 536
# The prediction of the image before attack:  [[0.05894894]]
# The prediction of the image after 2 iterations of BIM attack: 0.999977
# No_DR(349).png
# 537
# The prediction of the image before attack:  [[7.345336e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999955
# No_DR(350).png
# 538
# The prediction of the image before attack:  [[0.01178681]]
# The prediction of the image after 1 iterations of BIM attack: 0.000006
# DR(187).png
# 539
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999997
# No_DR(351).png
# 540
# The prediction of the image before attack:  [[0.00064854]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(188).png
# 541
# The prediction of the image before attack:  [[0.72377217]]
# The prediction of the image after 1 iterations of BIM attack: 0.999951
# No_DR(352).png
# 542
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 1 iterations of BIM attack: 0.999993
# No_DR(353).png
# 543
# The prediction of the image before attack:  [[0.9425777]]
# The prediction of the image after 1 iterations of BIM attack: 0.999325
# No_DR(354).png
# 544
# The prediction of the image before attack:  [[0.91801476]]
# The prediction of the image after 1 iterations of BIM attack: 0.999435
# No_DR(355).png
# 545
# The prediction of the image before attack:  [[1.570678e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999944
# No_DR(356).png
# 546
# The prediction of the image before attack:  [[0.1524244]]
# The prediction of the image after 1 iterations of BIM attack: 0.947703
# No_DR(357).png
# 547
# The prediction of the image before attack:  [[0.82602227]]
# The prediction of the image after 1 iterations of BIM attack: 0.008435
# DR(189).png
# 548
# The prediction of the image before attack:  [[0.07602445]]
# The prediction of the image after 1 iterations of BIM attack: 0.000027
# DR(190).png
# 549
# The prediction of the image before attack:  [[0.45366988]]
# The prediction of the image after 1 iterations of BIM attack: 0.000015
# DR(191).png
# 550
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 3 iterations of BIM attack: 0.999718
# No_DR(358).png
# 551
# The prediction of the image before attack:  [[0.9866448]]
# The prediction of the image after 1 iterations of BIM attack: 0.999977
# No_DR(359).png
# 552
# The prediction of the image before attack:  [[0.7836448]]
# The prediction of the image after 1 iterations of BIM attack: 0.009530
# DR(192).png
# 553
# The prediction of the image before attack:  [[1.7084611e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.988021
# No_DR(360).png
# 554
# The prediction of the image before attack:  [[0.08337271]]
# The prediction of the image after 1 iterations of BIM attack: 0.000318
# DR(193).png
# 555
# The prediction of the image before attack:  [[0.06591602]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(361).png
# 556
# The prediction of the image before attack:  [[4.9967824e-17]]
# The prediction of the image after 4 iterations of BIM attack: 0.999998
# No_DR(362).png
# 557
# The prediction of the image before attack:  [[0.00060145]]
# The prediction of the image after 2 iterations of BIM attack: 0.991418
# No_DR(363).png
# 558
# The prediction of the image before attack:  [[0.99988794]]
# The prediction of the image after 2 iterations of BIM attack: 0.000211
# DR(194).png
# 559
# The prediction of the image before attack:  [[0.00243411]]
# The prediction of the image after 1 iterations of BIM attack: 0.000002
# DR(195).png
# 560
# The prediction of the image before attack:  [[0.00032921]]
# The prediction of the image after 2 iterations of BIM attack: 0.988846
# No_DR(364).png
# 561
# The prediction of the image before attack:  [[6.800973e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999629
# No_DR(365).png
# 562
# The prediction of the image before attack:  [[0.04678323]]
# The prediction of the image after 2 iterations of BIM attack: 0.997762
# No_DR(366).png
# 563
# The prediction of the image before attack:  [[0.00194008]]
# The prediction of the image after 2 iterations of BIM attack: 0.999651
# No_DR(367).png
# 564
# The prediction of the image before attack:  [[0.99999833]]
# The prediction of the image after 1 iterations of BIM attack: 1.000000
# No_DR(368).png
# 565
# The prediction of the image before attack:  [[0.02384421]]
# The prediction of the image after 1 iterations of BIM attack: 0.000083
# DR(196).png
# 566
# The prediction of the image before attack:  [[0.91801476]]
# The prediction of the image after 1 iterations of BIM attack: 0.999435
# No_DR(369).png
# 567
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(197).png
# 568
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 1 iterations of BIM attack: 0.999988
# No_DR(370).png
# 569
# The prediction of the image before attack:  [[2.7630045e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999967
# No_DR(371).png
# 570
# The prediction of the image before attack:  [[0.1833121]]
# The prediction of the image after 1 iterations of BIM attack: 0.998753
# No_DR(372).png
# 571
# The prediction of the image before attack:  [[0.6224208]]
# The prediction of the image after 1 iterations of BIM attack: 0.000753
# DR(198).png
# 572
# The prediction of the image before attack:  [[0.03587515]]
# The prediction of the image after 1 iterations of BIM attack: 0.000007
# DR(199).png
# 573
# The prediction of the image before attack:  [[0.53757423]]
# The prediction of the image after 1 iterations of BIM attack: 0.004416
# DR(200).png
# 574
# The prediction of the image before attack:  [[0.95027727]]
# The prediction of the image after 1 iterations of BIM attack: 0.999935
# No_DR(373).png
# 575
# The prediction of the image before attack:  [[0.00398282]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(201).png
# 576
# The prediction of the image before attack:  [[0.00160271]]
# The prediction of the image after 2 iterations of BIM attack: 0.999590
# No_DR(374).png
# 577
# The prediction of the image before attack:  [[0.03679655]]
# The prediction of the image after 1 iterations of BIM attack: 0.000023
# DR(202).png
# 578
# The prediction of the image before attack:  [[0.9950217]]
# The prediction of the image after 2 iterations of BIM attack: 0.008831
# DR(203).png
# 579
# The prediction of the image before attack:  [[0.00016781]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(204).png
# 580
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 1 iterations of BIM attack: 0.999976
# No_DR(375).png
# 581
# The prediction of the image before attack:  [[0.39527103]]
# The prediction of the image after 1 iterations of BIM attack: 0.963466
# No_DR(376).png
# 582
# The prediction of the image before attack:  [[3.6705593e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999254
# No_DR(377).png
# 583
# The prediction of the image before attack:  [[0.9999608]]
# The prediction of the image after 2 iterations of BIM attack: 0.000167
# DR(205).png
# 584
# The prediction of the image before attack:  [[0.00060364]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(206).png
# 585
# The prediction of the image before attack:  [[0.995852]]
# The prediction of the image after 2 iterations of BIM attack: 0.000275
# DR(207).png
# 586
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(208).png
# 587
# The prediction of the image before attack:  [[0.05576917]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(209).png
# 588
# The prediction of the image before attack:  [[0.06591602]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(378).png
# 589
# The prediction of the image before attack:  [[0.01226045]]
# The prediction of the image after 2 iterations of BIM attack: 0.999971
# No_DR(379).png
# 590
# The prediction of the image before attack:  [[0.01052546]]
# The prediction of the image after 1 iterations of BIM attack: 0.000021
# DR(210).png
# 591
# The prediction of the image before attack:  [[0.9237534]]
# The prediction of the image after 1 iterations of BIM attack: 0.999586
# No_DR(380).png
# 592
# The prediction of the image before attack:  [[5.595746e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999278
# No_DR(381).png
# 593
# The prediction of the image before attack:  [[0.12399739]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(382).png
# 594
# The prediction of the image before attack:  [[0.00877646]]
# The prediction of the image after 2 iterations of BIM attack: 0.999959
# No_DR(383).png
# 595
# The prediction of the image before attack:  [[0.22254983]]
# The prediction of the image after 1 iterations of BIM attack: 0.999216
# No_DR(384).png
# 596
# The prediction of the image before attack:  [[0.00149528]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(211).png
# 597
# The prediction of the image before attack:  [[0.08085898]]
# The prediction of the image after 2 iterations of BIM attack: 0.999742
# No_DR(385).png
# 598
# The prediction of the image before attack:  [[0.97145647]]
# The prediction of the image after 2 iterations of BIM attack: 0.000003
# DR(212).png
# 599
# The prediction of the image before attack:  [[0.9977506]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(213).png
# 600
# The prediction of the image before attack:  [[0.36040846]]
# The prediction of the image after 1 iterations of BIM attack: 0.000826
# DR(214).png
# 601
# The prediction of the image before attack:  [[0.0015113]]
# The prediction of the image after 2 iterations of BIM attack: 0.997074
# No_DR(386).png
# 602
# The prediction of the image before attack:  [[0.94158846]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(215).png
# 603
# The prediction of the image before attack:  [[0.9818131]]
# The prediction of the image after 2 iterations of BIM attack: 0.000001
# DR(216).png
# 604
# The prediction of the image before attack:  [[0.93315125]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(217).png
# 605
# The prediction of the image before attack:  [[0.08976168]]
# The prediction of the image after 1 iterations of BIM attack: 0.000007
# DR(218).png
# 606
# The prediction of the image before attack:  [[0.00791752]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(219).png
# 607
# The prediction of the image before attack:  [[0.36287826]]
# The prediction of the image after 1 iterations of BIM attack: 0.961046
# No_DR(387).png
# 608
# The prediction of the image before attack:  [[0.01090473]]
# The prediction of the image after 2 iterations of BIM attack: 0.999974
# No_DR(388).png
# 609
# The prediction of the image before attack:  [[0.02565962]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(220).png
# 610
# The prediction of the image before attack:  [[0.00901614]]
# The prediction of the image after 2 iterations of BIM attack: 0.999953
# No_DR(389).png
# 611
# The prediction of the image before attack:  [[3.425824e-08]]
# The prediction of the image after 5 iterations of BIM attack: 0.998652
# No_DR(390).png
# 612
# The prediction of the image before attack:  [[0.51017857]]
# The prediction of the image after 1 iterations of BIM attack: 0.978867
# No_DR(391).png
# 613
# The prediction of the image before attack:  [[1.2588877e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(221).png
# 614
# The prediction of the image before attack:  [[0.00100879]]
# The prediction of the image after 2 iterations of BIM attack: 0.999054
# No_DR(392).png
# 615
# The prediction of the image before attack:  [[0.02159305]]
# The prediction of the image after 2 iterations of BIM attack: 0.999915
# No_DR(393).png
# 616
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 3 iterations of BIM attack: 0.998934
# No_DR(394).png
# 617
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 1 iterations of BIM attack: 0.999831
# No_DR(395).png
# 618
# The prediction of the image before attack:  [[0.7967367]]
# The prediction of the image after 1 iterations of BIM attack: 0.997736
# No_DR(396).png
# 619
# The prediction of the image before attack:  [[0.00185376]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(222).png
# 620
# The prediction of the image before attack:  [[0.00050446]]
# The prediction of the image after 2 iterations of BIM attack: 0.996511
# No_DR(397).png
# 621
# The prediction of the image before attack:  [[0.01965475]]
# The prediction of the image after 2 iterations of BIM attack: 0.995412
# No_DR(398).png
# 622
# The prediction of the image before attack:  [[0.00149925]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(399).png
# 623
# The prediction of the image before attack:  [[5.298946e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.988132
# No_DR(400).png
# 624
# The prediction of the image before attack:  [[0.03156444]]
# The prediction of the image after 1 iterations of BIM attack: 0.000025
# DR(223).png
# 625
# The prediction of the image before attack:  [[0.00157976]]
# The prediction of the image after 2 iterations of BIM attack: 0.999623
# No_DR(401).png
# 626
# The prediction of the image before attack:  [[0.0004024]]
# The prediction of the image after 2 iterations of BIM attack: 0.998579
# No_DR(402).png
# 627
# The prediction of the image before attack:  [[0.00143322]]
# The prediction of the image after 2 iterations of BIM attack: 0.976805
# No_DR(403).png
# 628
# The prediction of the image before attack:  [[0.00056069]]
# The prediction of the image after 3 iterations of BIM attack: 0.999279
# No_DR(404).png
# 629
# The prediction of the image before attack:  [[0.04591046]]
# The prediction of the image after 1 iterations of BIM attack: 0.000075
# DR(224).png
# 630
# The prediction of the image before attack:  [[0.8502883]]
# The prediction of the image after 1 iterations of BIM attack: 0.001514
# DR(225).png
# 631
# The prediction of the image before attack:  [[0.07359327]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(405).png
# 632
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 2 iterations of BIM attack: 0.999794
# No_DR(406).png
# 633
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(407).png
# 634
# The prediction of the image before attack:  [[0.99736905]]
# The prediction of the image after 2 iterations of BIM attack: 0.000001
# DR(226).png
# 635
# The prediction of the image before attack:  [[0.9514641]]
# The prediction of the image after 2 iterations of BIM attack: 0.000008
# DR(227).png
# 636
# The prediction of the image before attack:  [[0.99407274]]
# The prediction of the image after 2 iterations of BIM attack: 0.000113
# DR(228).png
# 637
# The prediction of the image before attack:  [[0.61422247]]
# The prediction of the image after 1 iterations of BIM attack: 0.003346
# DR(229).png
# 638
# The prediction of the image before attack:  [[7.002205e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.997766
# No_DR(408).png
# 639
# The prediction of the image before attack:  [[0.07510153]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(409).png
# 640
# The prediction of the image before attack:  [[3.753372e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999997
# No_DR(410).png
# 641
# The prediction of the image before attack:  [[0.00053785]]
# The prediction of the image after 2 iterations of BIM attack: 0.999790
# No_DR(411).png
# 642
# The prediction of the image before attack:  [[0.07510153]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(412).png
# 643
# The prediction of the image before attack:  [[0.3550741]]
# The prediction of the image after 1 iterations of BIM attack: 0.999847
# No_DR(413).png
# 644
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 2 iterations of BIM attack: 0.999823
# No_DR(414).png
# 645
# The prediction of the image before attack:  [[0.04460326]]
# The prediction of the image after 2 iterations of BIM attack: 0.999798
# No_DR(415).png
# 646
# The prediction of the image before attack:  [[0.00045607]]
# The prediction of the image after 2 iterations of BIM attack: 0.997527
# No_DR(416).png
# 647
# The prediction of the image before attack:  [[4.473232e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999159
# No_DR(417).png
# 648
# The prediction of the image before attack:  [[0.00073064]]
# The prediction of the image after 2 iterations of BIM attack: 0.997530
# No_DR(418).png
# 649
# The prediction of the image before attack:  [[0.98245037]]
# The prediction of the image after 1 iterations of BIM attack: 0.999856
# No_DR(419).png
# 650
# The prediction of the image before attack:  [[0.00365365]]
# The prediction of the image after 2 iterations of BIM attack: 0.999765
# No_DR(420).png
# 651
# The prediction of the image before attack:  [[0.00028699]]
# The prediction of the image after 2 iterations of BIM attack: 0.985997
# No_DR(421).png
# 652
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 1 iterations of BIM attack: 0.999831
# No_DR(422).png
# 653
# The prediction of the image before attack:  [[4.6163215e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999480
# No_DR(423).png
# 654
# The prediction of the image before attack:  [[0.82776695]]
# The prediction of the image after 1 iterations of BIM attack: 0.998435
# No_DR(424).png
# 655
# The prediction of the image before attack:  [[1.3685975e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999720
# No_DR(425).png
# 656
# The prediction of the image before attack:  [[0.14876297]]
# The prediction of the image after 1 iterations of BIM attack: 0.986299
# No_DR(426).png
# 657
# The prediction of the image before attack:  [[0.02345846]]
# The prediction of the image after 1 iterations of BIM attack: 0.000033
# DR(230).png
# 658
# The prediction of the image before attack:  [[0.60213625]]
# The prediction of the image after 1 iterations of BIM attack: 0.995233
# No_DR(427).png
# 659
# The prediction of the image before attack:  [[0.00260435]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(231).png
# 660
# The prediction of the image before attack:  [[0.02366401]]
# The prediction of the image after 2 iterations of BIM attack: 0.999962
# No_DR(428).png
# 661
# The prediction of the image before attack:  [[0.0001089]]
# The prediction of the image after 2 iterations of BIM attack: 0.999943
# No_DR(429).png
# 662
# The prediction of the image before attack:  [[0.00403929]]
# The prediction of the image after 1 iterations of BIM attack: 0.000006
# DR(232).png
# 663
# The prediction of the image before attack:  [[0.13539086]]
# The prediction of the image after 1 iterations of BIM attack: 0.999903
# No_DR(430).png
# 664
# The prediction of the image before attack:  [[1.9194299e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(233).png
# 665
# The prediction of the image before attack:  [[0.9406184]]
# The prediction of the image after 2 iterations of BIM attack: 0.000007
# DR(234).png
# 666
# The prediction of the image before attack:  [[8.69548e-06]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(235).png
# 667
# The prediction of the image before attack:  [[0.03836177]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(431).png
# 668
# The prediction of the image before attack:  [[0.02345846]]
# The prediction of the image after 1 iterations of BIM attack: 0.000033
# DR(236).png
# 669
# The prediction of the image before attack:  [[5.327553e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999686
# No_DR(432).png
# 670
# The prediction of the image before attack:  [[4.473232e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999159
# No_DR(433).png
# 671
# The prediction of the image before attack:  [[0.21155718]]
# The prediction of the image after 1 iterations of BIM attack: 0.000026
# DR(237).png
# 672
# The prediction of the image before attack:  [[0.00326598]]
# The prediction of the image after 2 iterations of BIM attack: 0.999271
# No_DR(434).png
# 673
# The prediction of the image before attack:  [[0.4470897]]
# ...
# No_DR(1005).png
# 1494
# The prediction of the image before attack:  [[0.00521278]]
# The prediction of the image after 2 iterations of BIM attack: 0.992071
# No_DR(1006).png
# 1495
# The prediction of the image before attack:  [[9.788784e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999968
# No_DR(1007).png
# 1496
# The prediction of the image before attack:  [[2.3138304e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(488).png
# 1497
# The prediction of the image before attack:  [[0.00138076]]
# The prediction of the image after 2 iterations of BIM attack: 0.999981
# No_DR(1008).png
# 1498
# The prediction of the image before attack:  [[0.8823319]]
# The prediction of the image after 1 iterations of BIM attack: 0.999310
# No_DR(1009).png
# 1499
# The prediction of the image before attack:  [[0.00310539]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(489).png
# 1500
# The prediction of the image before attack:  [[0.00261813]]
# The prediction of the image after 2 iterations of BIM attack: 0.998216
# No_DR(1010).png
# 1501
# The prediction of the image before attack:  [[0.39107764]]
# The prediction of the image after 1 iterations of BIM attack: 0.997247
# No_DR(1011).png
# 1502
# The prediction of the image before attack:  [[0.00029284]]
# The prediction of the image after 2 iterations of BIM attack: 0.999541
# No_DR(1012).png
# 1503
# The prediction of the image before attack:  [[0.00199972]]
# The prediction of the image after 2 iterations of BIM attack: 0.999518
# No_DR(1013).png
# 1504
# The prediction of the image before attack:  [[0.24016888]]
# The prediction of the image after 1 iterations of BIM attack: 0.995622
# No_DR(1014).png
# 1505
# The prediction of the image before attack:  [[7.908018e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999835
# No_DR(1015).png
# 1506
# The prediction of the image before attack:  [[8.9093476e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.988546
# No_DR(1016).png
# 1507
# The prediction of the image before attack:  [[3.5726886e-09]]
# The prediction of the image after 4 iterations of BIM attack: 0.999980
# No_DR(1017).png
# 1508
# The prediction of the image before attack:  [[0.05858029]]
# The prediction of the image after 2 iterations of BIM attack: 0.993707
# No_DR(1018).png
# 1509
# The prediction of the image before attack:  [[0.2757057]]
# The prediction of the image after 1 iterations of BIM attack: 0.975520
# No_DR(1019).png
# 1510
# The prediction of the image before attack:  [[0.15997481]]
# The prediction of the image after 1 iterations of BIM attack: 0.000014
# DR(490).png
# 1511
# The prediction of the image before attack:  [[1.0480946e-12]]
# The prediction of the image after 3 iterations of BIM attack: 0.998094
# No_DR(1020).png
# 1512
# The prediction of the image before attack:  [[0.23375365]]
# The prediction of the image after 1 iterations of BIM attack: 0.999636
# No_DR(1021).png
# 1513
# The prediction of the image before attack:  [[0.00511268]]
# The prediction of the image after 2 iterations of BIM attack: 0.999826
# No_DR(1022).png
# 1514
# The prediction of the image before attack:  [[5.3096286e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.998273
# No_DR(1023).png
# 1515
# The prediction of the image before attack:  [[0.00032962]]
# The prediction of the image after 2 iterations of BIM attack: 0.999874
# No_DR(1024).png
# 1516
# The prediction of the image before attack:  [[0.00742758]]
# The prediction of the image after 2 iterations of BIM attack: 0.999961
# No_DR(1025).png
# 1517
# The prediction of the image before attack:  [[0.9216149]]
# The prediction of the image after 2 iterations of BIM attack: 0.000005
# DR(491).png
# 1518
# The prediction of the image before attack:  [[2.704636e-07]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(1026).png
# 1519
# The prediction of the image before attack:  [[0.00045607]]
# The prediction of the image after 2 iterations of BIM attack: 0.997527
# No_DR(1027).png
# 1520
# The prediction of the image before attack:  [[0.00103255]]
# The prediction of the image after 2 iterations of BIM attack: 0.997828
# No_DR(1028).png
# 1521
# The prediction of the image before attack:  [[0.14727314]]
# The prediction of the image after 1 iterations of BIM attack: 0.922245
# No_DR(1029).png
# 1522
# The prediction of the image before attack:  [[2.6512302e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(492).png
# 1523
# The prediction of the image before attack:  [[2.9034663e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999612
# No_DR(1030).png
# 1524
# The prediction of the image before attack:  [[3.030244e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999446
# No_DR(1031).png
# 1525
# The prediction of the image before attack:  [[0.03129081]]
# The prediction of the image after 2 iterations of BIM attack: 0.999647
# No_DR(1032).png
# 1526
# The prediction of the image before attack:  [[0.7265784]]
# The prediction of the image after 1 iterations of BIM attack: 0.999909
# No_DR(1033).png
# 1527
# The prediction of the image before attack:  [[0.04678323]]
# The prediction of the image after 2 iterations of BIM attack: 0.997762
# No_DR(1034).png
# 1528
# The prediction of the image before attack:  [[1.206994e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.967392
# No_DR(1035).png
# 1529
# The prediction of the image before attack:  [[0.45545417]]
# The prediction of the image after 1 iterations of BIM attack: 0.999378
# No_DR(1036).png
# 1530
# The prediction of the image before attack:  [[8.084696e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1037).png
# 1531
# The prediction of the image before attack:  [[9.291316e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999517
# No_DR(1038).png
# 1532
# The prediction of the image before attack:  [[0.9866448]]
# The prediction of the image after 1 iterations of BIM attack: 0.999977
# No_DR(1039).png
# 1533
# The prediction of the image before attack:  [[4.5706916e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.998140
# No_DR(1040).png
# 1534
# The prediction of the image before attack:  [[0.9207249]]
# The prediction of the image after 2 iterations of BIM attack: 0.000008
# DR(493).png
# 1535
# The prediction of the image before attack:  [[9.0500784e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(494).png
# 1536
# The prediction of the image before attack:  [[0.00033168]]
# The prediction of the image after 2 iterations of BIM attack: 0.995990
# No_DR(1041).png
# 1537
# The prediction of the image before attack:  [[1.6197973e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999938
# No_DR(1042).png
# 1538
# The prediction of the image before attack:  [[0.00943055]]
# The prediction of the image after 2 iterations of BIM attack: 0.999811
# No_DR(1043).png
# 1539
# The prediction of the image before attack:  [[0.04642906]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1044).png
# 1540
# The prediction of the image before attack:  [[0.3550741]]
# The prediction of the image after 1 iterations of BIM attack: 0.999847
# No_DR(1045).png
# 1541
# The prediction of the image before attack:  [[0.00126557]]
# The prediction of the image after 2 iterations of BIM attack: 0.968065
# No_DR(1046).png
# 1542
# The prediction of the image before attack:  [[0.12745546]]
# The prediction of the image after 2 iterations of BIM attack: 0.999989
# No_DR(1047).png
# 1543
# The prediction of the image before attack:  [[0.9792875]]
# The prediction of the image after 2 iterations of BIM attack: 0.000003
# DR(495).png
# 1544
# The prediction of the image before attack:  [[0.00012458]]
# The prediction of the image after 2 iterations of BIM attack: 0.997660
# No_DR(1048).png
# 1545
# The prediction of the image before attack:  [[0.97103506]]
# The prediction of the image after 1 iterations of BIM attack: 0.999974
# No_DR(1049).png
# 1546
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 1 iterations of BIM attack: 0.999848
# No_DR(1050).png
# 1547
# The prediction of the image before attack:  [[0.644052]]
# The prediction of the image after 1 iterations of BIM attack: 0.993695
# No_DR(1051).png
# 1548
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 1 iterations of BIM attack: 0.999988
# No_DR(1052).png
# 1549
# The prediction of the image before attack:  [[0.9964263]]
# The prediction of the image after 1 iterations of BIM attack: 0.999983
# No_DR(1053).png
# 1550
# The prediction of the image before attack:  [[3.8865826e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.998190
# No_DR(1054).png
# 1551
# The prediction of the image before attack:  [[0.03687299]]
# The prediction of the image after 2 iterations of BIM attack: 0.998810
# No_DR(1055).png
# 1552
# The prediction of the image before attack:  [[6.9116404e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999770
# No_DR(1056).png
# 1553
# The prediction of the image before attack:  [[8.230261e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999493
# No_DR(1057).png
# 1554
# The prediction of the image before attack:  [[0.9774889]]
# The prediction of the image after 1 iterations of BIM attack: 0.999922
# No_DR(1058).png
# 1555
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 2 iterations of BIM attack: 0.999678
# No_DR(1059).png
# 1556
# The prediction of the image before attack:  [[0.6945233]]
# The prediction of the image after 1 iterations of BIM attack: 0.010974
# DR(496).png
# 1557
# The prediction of the image before attack:  [[0.05108991]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1060).png
# 1558
# The prediction of the image before attack:  [[0.9571061]]
# The prediction of the image after 1 iterations of BIM attack: 0.999998
# No_DR(1061).png
# 1559
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 3 iterations of BIM attack: 0.998934
# No_DR(1062).png
# 1560
# The prediction of the image before attack:  [[0.00160271]]
# The prediction of the image after 2 iterations of BIM attack: 0.999590
# No_DR(1063).png
# 1561
# The prediction of the image before attack:  [[0.0050884]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(497).png
# 1562
# The prediction of the image before attack:  [[1.9054237e-12]]
# The prediction of the image after 4 iterations of BIM attack: 0.999752
# No_DR(1064).png
# 1563
# The prediction of the image before attack:  [[0.7967367]]
# The prediction of the image after 1 iterations of BIM attack: 0.997736
# No_DR(1065).png
# 1564
# The prediction of the image before attack:  [[0.0065155]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(1066).png
# 1565
# The prediction of the image before attack:  [[4.0940467e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(498).png
# 1566
# The prediction of the image before attack:  [[0.00013427]]
# The prediction of the image after 3 iterations of BIM attack: 0.999469
# No_DR(1067).png
# 1567
# The prediction of the image before attack:  [[1.4545836e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.996718
# No_DR(1068).png
# 1568
# The prediction of the image before attack:  [[3.9369195e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999907
# No_DR(1069).png
# 1569
# The prediction of the image before attack:  [[2.4135594e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999949
# No_DR(1070).png
# 1570
# The prediction of the image before attack:  [[0.0050884]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(499).png
# 1571
# The prediction of the image before attack:  [[0.01116391]]
# The prediction of the image after 2 iterations of BIM attack: 0.999840
# No_DR(1071).png
# 1572
# The prediction of the image before attack:  [[1.496588e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(500).png
# 1573
# The prediction of the image before attack:  [[0.00032962]]
# The prediction of the image after 2 iterations of BIM attack: 0.999874
# No_DR(1072).png
# 1574
# The prediction of the image before attack:  [[0.9747]]
# The prediction of the image after 2 iterations of BIM attack: 0.000039
# DR(501).png
# 1575
# The prediction of the image before attack:  [[2.607421e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(502).png
# 1576
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(503).png
# 1577
# The prediction of the image before attack:  [[5.6514627e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999972
# No_DR(1073).png
# 1578
# The prediction of the image before attack:  [[0.00067976]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(504).png
# 1579
# The prediction of the image before attack:  [[1.7467291e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999996
# No_DR(1074).png
# 1580
# The prediction of the image before attack:  [[0.00665907]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(505).png
# 1581
# The prediction of the image before attack:  [[0.09100016]]
# The prediction of the image after 2 iterations of BIM attack: 0.999774
# No_DR(1075).png
# 1582
# The prediction of the image before attack:  [[0.02402207]]
# The prediction of the image after 2 iterations of BIM attack: 0.992474
# No_DR(1076).png
# 1583
# The prediction of the image before attack:  [[0.16997996]]
# The prediction of the image after 1 iterations of BIM attack: 0.000002
# DR(506).png
# 1584
# The prediction of the image before attack:  [[0.00042179]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(507).png
# 1585
# The prediction of the image before attack:  [[0.11996242]]
# The prediction of the image after 2 iterations of BIM attack: 0.999998
# No_DR(1077).png
# 1586
# The prediction of the image before attack:  [[0.9998504]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(508).png
# 1587
# The prediction of the image before attack:  [[0.9863614]]
# The prediction of the image after 1 iterations of BIM attack: 0.999912
# No_DR(1078).png
# 1588
# The prediction of the image before attack:  [[0.00032921]]
# The prediction of the image after 2 iterations of BIM attack: 0.988846
# No_DR(1079).png
# 1589
# The prediction of the image before attack:  [[1.6281061e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999777
# No_DR(1080).png
# 1590
# The prediction of the image before attack:  [[0.01972254]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1081).png
# 1591
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 1 iterations of BIM attack: 0.999993
# No_DR(1082).png
# 1592
# The prediction of the image before attack:  [[0.35573596]]
# The prediction of the image after 1 iterations of BIM attack: 0.000011
# DR(509).png
# 1593
# The prediction of the image before attack:  [[2.8639932e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999444
# No_DR(1083).png
# 1594
# The prediction of the image before attack:  [[4.4849956e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(510).png
# 1595
# The prediction of the image before attack:  [[0.9996081]]
# The prediction of the image after 2 iterations of BIM attack: 0.000625
# DR(511).png
# 1596
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 1 iterations of BIM attack: 0.999848
# No_DR(1084).png
# 1597
# The prediction of the image before attack:  [[7.1238894e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.998139
# No_DR(1085).png
# 1598
# The prediction of the image before attack:  [[5.56557e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.982236
# No_DR(1086).png
# 1599
# The prediction of the image before attack:  [[8.230261e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999493
# No_DR(1087).png

# %%
for i,d in enumerate(X_test):
  print(i)
  if Y_test[i] == 1:
    create_perturb_bim(d, 'DR('+str(dr)+').png', 'BIM_BBA_perturbed_img/DR/', 0)
    print('DR('+str(dr)+').png')
    dr+=1
  else:
    create_perturb_bim(d, 'No_DR('+str(no_dr)+').png', 'BIM_BBA_perturbed_img/No_DR/', 1)
    print('No_DR('+str(no_dr)+').png')
    no_dr+=1
# Out:
# 0
# The prediction of the image before attack:  [[0.95027727]]
# The prediction of the image after 1 iterations of BIM attack: 0.999935
# No_DR(1088).png
# 1
# The prediction of the image before attack:  [[0.8282469]]
# The prediction of the image after 1 iterations of BIM attack: 0.999812
# No_DR(1089).png
# 2
# The prediction of the image before attack:  [[0.00511268]]
# The prediction of the image after 2 iterations of BIM attack: 0.999826
# No_DR(1090).png
# 3
# The prediction of the image before attack:  [[0.0001213]]
# The prediction of the image after 2 iterations of BIM attack: 0.997608
# No_DR(1091).png
# 4
# The prediction of the image before attack:  [[1.5924453e-08]]
# The prediction of the image after 4 iterations of BIM attack: 0.999897
# No_DR(1092).png
# 5
# The prediction of the image before attack:  [[0.10658266]]
# The prediction of the image after 1 iterations of BIM attack: 0.000161
# DR(512).png
# 6
# The prediction of the image before attack:  [[0.35441938]]
# The prediction of the image after 1 iterations of BIM attack: 0.000012
# DR(513).png
# 7
# The prediction of the image before attack:  [[0.9849262]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(514).png
# 8
# The prediction of the image before attack:  [[0.81115144]]
# The prediction of the image after 1 iterations of BIM attack: 0.996699
# No_DR(1093).png
# 9
# The prediction of the image before attack:  [[0.2297796]]
# The prediction of the image after 1 iterations of BIM attack: 0.000042
# DR(515).png
# 10
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 1 iterations of BIM attack: 0.000003
# DR(516).png
# 11
# The prediction of the image before attack:  [[5.2572952e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999933
# No_DR(1094).png
# 12
# The prediction of the image before attack:  [[0.01768238]]
# The prediction of the image after 1 iterations of BIM attack: 0.000003
# DR(517).png
# 13
# The prediction of the image before attack:  [[0.5207427]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(518).png
# 14
# The prediction of the image before attack:  [[1.0556156e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999980
# No_DR(1095).png
# 15
# The prediction of the image before attack:  [[0.12940425]]
# The prediction of the image after 2 iterations of BIM attack: 0.999998
# No_DR(1096).png
# 16
# The prediction of the image before attack:  [[0.16997996]]
# The prediction of the image after 1 iterations of BIM attack: 0.000002
# DR(519).png
# 17
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 1 iterations of BIM attack: 0.999848
# No_DR(1097).png
# 18
# The prediction of the image before attack:  [[7.1540067e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999961
# No_DR(1098).png
# 19
# The prediction of the image before attack:  [[0.00025167]]
# The prediction of the image after 2 iterations of BIM attack: 0.999902
# No_DR(1099).png
# 20
# The prediction of the image before attack:  [[0.9657152]]
# The prediction of the image after 1 iterations of BIM attack: 0.999869
# No_DR(1100).png
# 21
# The prediction of the image before attack:  [[0.9818131]]
# The prediction of the image after 2 iterations of BIM attack: 0.000001
# DR(520).png
# 22
# The prediction of the image before attack:  [[0.00073064]]
# The prediction of the image after 2 iterations of BIM attack: 0.997530
# No_DR(1101).png
# 23
# The prediction of the image before attack:  [[0.0085095]]
# The prediction of the image after 2 iterations of BIM attack: 0.994880
# No_DR(1102).png
# 24
# The prediction of the image before attack:  [[2.4621357e-12]]
# The prediction of the image after 3 iterations of BIM attack: 0.999908
# No_DR(1103).png
# 25
# The prediction of the image before attack:  [[2.3138304e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(521).png
# 26
# The prediction of the image before attack:  [[0.00010947]]
# The prediction of the image after 2 iterations of BIM attack: 0.999253
# No_DR(1104).png
# 27
# The prediction of the image before attack:  [[0.99953496]]
# The prediction of the image after 3 iterations of BIM attack: 0.000036
# DR(522).png
# 28
# The prediction of the image before attack:  [[0.03346151]]
# The prediction of the image after 2 iterations of BIM attack: 0.999054
# No_DR(1105).png
# 29
# The prediction of the image before attack:  [[2.7734975e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999979
# No_DR(1106).png
# 30
# The prediction of the image before attack:  [[0.00652593]]
# The prediction of the image after 2 iterations of BIM attack: 0.999599
# No_DR(1107).png
# 31
# The prediction of the image before attack:  [[0.01226045]]
# The prediction of the image after 2 iterations of BIM attack: 0.999971
# No_DR(1108).png
# 32
# The prediction of the image before attack:  [[0.3671662]]
# The prediction of the image after 1 iterations of BIM attack: 0.999998
# No_DR(1109).png
# 33
# The prediction of the image before attack:  [[0.07399887]]
# The prediction of the image after 2 iterations of BIM attack: 0.999994
# No_DR(1110).png
# 34
# The prediction of the image before attack:  [[0.00126557]]
# The prediction of the image after 2 iterations of BIM attack: 0.968065
# No_DR(1111).png
# 35
# The prediction of the image before attack:  [[1.0344526e-06]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(523).png
# 36
# The prediction of the image before attack:  [[1.6133988e-07]]
# The prediction of the image after 3 iterations of BIM attack: 1.000000
# No_DR(1112).png
# 37
# The prediction of the image before attack:  [[0.5131379]]
# The prediction of the image after 1 iterations of BIM attack: 0.999968
# No_DR(1113).png
# 38
# The prediction of the image before attack:  [[0.16997996]]
# The prediction of the image after 1 iterations of BIM attack: 0.000002
# DR(524).png
# 39
# The prediction of the image before attack:  [[0.00171243]]
# The prediction of the image after 2 iterations of BIM attack: 0.999179
# No_DR(1114).png
# 40
# The prediction of the image before attack:  [[0.00211565]]
# The prediction of the image after 2 iterations of BIM attack: 0.999950
# No_DR(1115).png
# 41
# The prediction of the image before attack:  [[0.19161919]]
# The prediction of the image after 1 iterations of BIM attack: 0.999308
# No_DR(1116).png
# 42
# The prediction of the image before attack:  [[0.07618525]]
# The prediction of the image after 2 iterations of BIM attack: 0.999970
# No_DR(1117).png
# 43
# The prediction of the image before attack:  [[0.11886895]]
# The prediction of the image after 2 iterations of BIM attack: 0.999354
# No_DR(1118).png
# 44
# The prediction of the image before attack:  [[0.00567226]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(1119).png
# 45
# The prediction of the image before attack:  [[0.755463]]
# The prediction of the image after 1 iterations of BIM attack: 0.000014
# DR(525).png
# 46
# The prediction of the image before attack:  [[0.05439005]]
# The prediction of the image after 1 iterations of BIM attack: 0.000101
# DR(526).png
# 47
# The prediction of the image before attack:  [[8.0108954e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.978227
# No_DR(1120).png
# 48
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 3 iterations of BIM attack: 0.998934
# No_DR(1121).png
# 49
# The prediction of the image before attack:  [[0.0010417]]
# The prediction of the image after 2 iterations of BIM attack: 0.999998
# No_DR(1122).png
# 50
# The prediction of the image before attack:  [[0.00943055]]
# The prediction of the image after 2 iterations of BIM attack: 0.999811
# No_DR(1123).png
# 51
# The prediction of the image before attack:  [[0.21893604]]
# The prediction of the image after 1 iterations of BIM attack: 0.001355
# DR(527).png
# 52
# The prediction of the image before attack:  [[0.00308061]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(528).png
# 53
# The prediction of the image before attack:  [[0.87203944]]
# The prediction of the image after 1 iterations of BIM attack: 0.999237
# No_DR(1124).png
# 54
# The prediction of the image before attack:  [[0.18038169]]
# The prediction of the image after 1 iterations of BIM attack: 0.000314
# DR(529).png
# 55
# The prediction of the image before attack:  [[0.00281357]]
# The prediction of the image after 2 iterations of BIM attack: 0.999912
# No_DR(1125).png
# 56
# The prediction of the image before attack:  [[2.5735055e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999992
# No_DR(1126).png
# 57
# The prediction of the image before attack:  [[0.08380187]]
# The prediction of the image after 2 iterations of BIM attack: 0.999773
# No_DR(1127).png
# 58
# The prediction of the image before attack:  [[0.00261813]]
# The prediction of the image after 2 iterations of BIM attack: 0.998216
# No_DR(1128).png
# 59
# The prediction of the image before attack:  [[0.98308635]]
# The prediction of the image after 1 iterations of BIM attack: 0.999997
# No_DR(1129).png
# 60
# The prediction of the image before attack:  [[0.9665322]]
# The prediction of the image after 1 iterations of BIM attack: 0.999489
# No_DR(1130).png
# 61
# The prediction of the image before attack:  [[0.00124306]]
# The prediction of the image after 2 iterations of BIM attack: 0.999915
# No_DR(1131).png
# 62
# The prediction of the image before attack:  [[8.69548e-06]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(530).png
# 63
# The prediction of the image before attack:  [[0.48151445]]
# The prediction of the image after 1 iterations of BIM attack: 0.000363
# DR(531).png
# 64
# The prediction of the image before attack:  [[0.9664462]]
# The prediction of the image after 1 iterations of BIM attack: 0.999996
# No_DR(1132).png
# 65
# The prediction of the image before attack:  [[0.98851585]]
# The prediction of the image after 1 iterations of BIM attack: 0.999982
# No_DR(1133).png
# 66
# The prediction of the image before attack:  [[0.9514641]]
# The prediction of the image after 2 iterations of BIM attack: 0.000008
# DR(532).png
# 67
# The prediction of the image before attack:  [[0.63804716]]
# The prediction of the image after 1 iterations of BIM attack: 0.999984
# No_DR(1134).png
# 68
# The prediction of the image before attack:  [[0.02670408]]
# The prediction of the image after 2 iterations of BIM attack: 0.999944
# No_DR(1135).png
# 69
# The prediction of the image before attack:  [[0.91366065]]
# The prediction of the image after 2 iterations of BIM attack: 0.000005
# DR(533).png
# 70
# The prediction of the image before attack:  [[9.983456e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999981
# No_DR(1136).png
# 71
# The prediction of the image before attack:  [[0.00080311]]
# The prediction of the image after 2 iterations of BIM attack: 0.981686
# No_DR(1137).png
# 72
# The prediction of the image before attack:  [[2.8402103e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999790
# No_DR(1138).png
# 73
# The prediction of the image before attack:  [[1.1336475e-08]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(534).png
# 74
# The prediction of the image before attack:  [[0.00294215]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(1139).png
# 75
# The prediction of the image before attack:  [[4.925735e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999892
# No_DR(1140).png
# 76
# The prediction of the image before attack:  [[0.48785657]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(535).png
# 77
# The prediction of the image before attack:  [[0.77484065]]
# The prediction of the image after 1 iterations of BIM attack: 0.999579
# No_DR(1141).png
# 78
# The prediction of the image before attack:  [[0.0006984]]
# The prediction of the image after 2 iterations of BIM attack: 0.993253
# No_DR(1142).png
# 79
# The prediction of the image before attack:  [[0.72377217]]
# The prediction of the image after 1 iterations of BIM attack: 0.999951
# No_DR(1143).png
# 80
# The prediction of the image before attack:  [[0.99462056]]
# The prediction of the image after 1 iterations of BIM attack: 1.000000
# No_DR(1144).png
# 81
# The prediction of the image before attack:  [[2.8402103e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999790
# No_DR(1145).png
# 82
# The prediction of the image before attack:  [[4.6879666e-07]]
# The prediction of the image after 2 iterations of BIM attack: 0.999990
# No_DR(1146).png
# 83
# The prediction of the image before attack:  [[0.06239355]]
# The prediction of the image after 2 iterations of BIM attack: 0.999900
# No_DR(1147).png
# 84
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 2 iterations of BIM attack: 0.998146
# No_DR(1148).png
# 85
# The prediction of the image before attack:  [[0.01233116]]
# The prediction of the image after 2 iterations of BIM attack: 0.999994
# No_DR(1149).png
# 86
# The prediction of the image before attack:  [[8.0108954e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.978227
# No_DR(1150).png
# 87
# The prediction of the image before attack:  [[0.00124568]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(536).png
# 88
# The prediction of the image before attack:  [[2.7734975e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999979
# No_DR(1151).png
# 89
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(1152).png
# 90
# The prediction of the image before attack:  [[4.473232e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999159
# No_DR(1153).png
# 91
# The prediction of the image before attack:  [[0.00011643]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(537).png
# 92
# The prediction of the image before attack:  [[0.00064249]]
# The prediction of the image after 2 iterations of BIM attack: 0.983880
# No_DR(1154).png
# 93
# The prediction of the image before attack:  [[0.96418]]
# The prediction of the image after 2 iterations of BIM attack: 0.000030
# DR(538).png
# 94
# The prediction of the image before attack:  [[0.8763002]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(539).png
# 95
# The prediction of the image before attack:  [[0.9959706]]
# The prediction of the image after 1 iterations of BIM attack: 0.999993
# No_DR(1155).png
# 96
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(540).png
# 97
# The prediction of the image before attack:  [[1.7467291e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999996
# No_DR(1156).png
# 98
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 1 iterations of BIM attack: 0.999831
# No_DR(1157).png
# 99
# The prediction of the image before attack:  [[5.8333414e-11]]
# The prediction of the image after 4 iterations of BIM attack: 0.992434
# No_DR(1158).png
# 100
# The prediction of the image before attack:  [[0.00016683]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(541).png
# 101
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 2 iterations of BIM attack: 0.999916
# No_DR(1159).png
# 102
# The prediction of the image before attack:  [[0.08380187]]
# The prediction of the image after 2 iterations of BIM attack: 0.999773
# No_DR(1160).png
# 103
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 1 iterations of BIM attack: 0.999976
# No_DR(1161).png
# 104
# The prediction of the image before attack:  [[0.00029304]]
# The prediction of the image after 3 iterations of BIM attack: 0.999962
# No_DR(1162).png
# 105
# The prediction of the image before attack:  [[0.55745065]]
# The prediction of the image after 1 iterations of BIM attack: 0.000724
# DR(542).png
# 106
# The prediction of the image before attack:  [[0.7343615]]
# The prediction of the image after 1 iterations of BIM attack: 0.997633
# No_DR(1163).png
# 107
# The prediction of the image before attack:  [[0.80058706]]
# The prediction of the image after 1 iterations of BIM attack: 0.999023
# No_DR(1164).png
# 108
# The prediction of the image before attack:  [[0.19224326]]
# The prediction of the image after 1 iterations of BIM attack: 0.962443
# No_DR(1165).png
# 109
# The prediction of the image before attack:  [[0.00187634]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(543).png
# 110
# The prediction of the image before attack:  [[0.00033384]]
# The prediction of the image after 2 iterations of BIM attack: 0.994210
# No_DR(1166).png
# 111
# The prediction of the image before attack:  [[0.01890841]]
# The prediction of the image after 2 iterations of BIM attack: 0.997314
# No_DR(1167).png
# 112
# The prediction of the image before attack:  [[0.01252573]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(1168).png
# 113
# The prediction of the image before attack:  [[0.15997481]]
# The prediction of the image after 1 iterations of BIM attack: 0.000014
# DR(544).png
# 114
# The prediction of the image before attack:  [[0.80625325]]
# The prediction of the image after 1 iterations of BIM attack: 0.999747
# No_DR(1169).png
# 115
# The prediction of the image before attack:  [[0.00059036]]
# The prediction of the image after 2 iterations of BIM attack: 0.999505
# No_DR(1170).png
# 116
# The prediction of the image before attack:  [[0.1524244]]
# The prediction of the image after 1 iterations of BIM attack: 0.947703
# No_DR(1171).png
# 117
# The prediction of the image before attack:  [[0.01731405]]
# The prediction of the image after 2 iterations of BIM attack: 0.999809
# No_DR(1172).png
# 118
# The prediction of the image before attack:  [[0.00092721]]
# The prediction of the image after 2 iterations of BIM attack: 0.999845
# No_DR(1173).png
# 119
# The prediction of the image before attack:  [[0.00521278]]
# The prediction of the image after 2 iterations of BIM attack: 0.992071
# No_DR(1174).png
# 120
# The prediction of the image before attack:  [[0.00229791]]
# The prediction of the image after 2 iterations of BIM attack: 0.998384
# No_DR(1175).png
# 121
# The prediction of the image before attack:  [[0.35244268]]
# The prediction of the image after 1 iterations of BIM attack: 0.991542
# No_DR(1176).png
# 122
# The prediction of the image before attack:  [[0.00065558]]
# The prediction of the image after 2 iterations of BIM attack: 0.999908
# No_DR(1177).png
# 123
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 1 iterations of BIM attack: 0.999848
# No_DR(1178).png
# 124
# The prediction of the image before attack:  [[0.00111131]]
# The prediction of the image after 2 iterations of BIM attack: 0.999703
# No_DR(1179).png
# 125
# The prediction of the image before attack:  [[0.23375365]]
# The prediction of the image after 1 iterations of BIM attack: 0.999636
# No_DR(1180).png
# 126
# The prediction of the image before attack:  [[0.01410274]]
# The prediction of the image after 1 iterations of BIM attack: 0.000005
# DR(545).png
# 127
# The prediction of the image before attack:  [[0.06591602]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(1181).png
# 128
# The prediction of the image before attack:  [[0.0001047]]
# The prediction of the image after 2 iterations of BIM attack: 0.994170
# No_DR(1182).png
# 129
# The prediction of the image before attack:  [[3.9192833e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999767
# No_DR(1183).png
# 130
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 1 iterations of BIM attack: 0.999848
# No_DR(1184).png
# 131
# The prediction of the image before attack:  [[0.00041705]]
# The prediction of the image after 2 iterations of BIM attack: 0.977052
# No_DR(1185).png
# 132
# The prediction of the image before attack:  [[0.7680307]]
# The prediction of the image after 1 iterations of BIM attack: 0.998841
# No_DR(1186).png
# 133
# The prediction of the image before attack:  [[0.9641809]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(546).png
# 134
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 1 iterations of BIM attack: 0.999976
# No_DR(1187).png
# 135
# The prediction of the image before attack:  [[0.82776695]]
# The prediction of the image after 1 iterations of BIM attack: 0.998435
# No_DR(1188).png
# 136
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 3 iterations of BIM attack: 0.999718
# No_DR(1189).png
# 137
# The prediction of the image before attack:  [[0.89291495]]
# The prediction of the image after 2 iterations of BIM attack: 0.000007
# DR(547).png
# 138
# The prediction of the image before attack:  [[0.34635127]]
# The prediction of the image after 1 iterations of BIM attack: 0.997997
# No_DR(1190).png
# 139
# The prediction of the image before attack:  [[0.9746494]]
# The prediction of the image after 1 iterations of BIM attack: 0.999829
# No_DR(1191).png
# 140
# The prediction of the image before attack:  [[3.309812e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.998950
# No_DR(1192).png
# 141
# The prediction of the image before attack:  [[0.98245037]]
# The prediction of the image after 1 iterations of BIM attack: 0.999856
# No_DR(1193).png
# 142
# The prediction of the image before attack:  [[0.06171538]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(1194).png
# 143
# The prediction of the image before attack:  [[0.01090473]]
# The prediction of the image after 2 iterations of BIM attack: 0.999974
# No_DR(1195).png
# 144
# The prediction of the image before attack:  [[0.11996242]]
# The prediction of the image after 2 iterations of BIM attack: 0.999998
# No_DR(1196).png
# 145
# The prediction of the image before attack:  [[0.7537676]]
# The prediction of the image after 1 iterations of BIM attack: 0.000164
# DR(548).png
# 146
# The prediction of the image before attack:  [[0.2899885]]
# The prediction of the image after 1 iterations of BIM attack: 0.000255
# DR(549).png
# 147
# The prediction of the image before attack:  [[0.01508688]]
# The prediction of the image after 2 iterations of BIM attack: 0.999625
# No_DR(1197).png
# 148
# The prediction of the image before attack:  [[0.9062649]]
# The prediction of the image after 1 iterations of BIM attack: 0.999110
# No_DR(1198).png
# 149
# The prediction of the image before attack:  [[2.0621967e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.998522
# No_DR(1199).png
# 150
# The prediction of the image before attack:  [[3.8281373e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.998609
# No_DR(1200).png
# 151
# The prediction of the image before attack:  [[2.0023249e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999652
# No_DR(1201).png
# 152
# The prediction of the image before attack:  [[0.48479295]]
# The prediction of the image after 1 iterations of BIM attack: 0.994367
# No_DR(1202).png
# 153
# The prediction of the image before attack:  [[0.0014462]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(550).png
# 154
# The prediction of the image before attack:  [[0.99832517]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(551).png
# 155
# The prediction of the image before attack:  [[0.9989748]]
# The prediction of the image after 1 iterations of BIM attack: 0.999984
# No_DR(1203).png
# 156
# The prediction of the image before attack:  [[0.03687299]]
# The prediction of the image after 2 iterations of BIM attack: 0.998810
# No_DR(1204).png
# 157
# The prediction of the image before attack:  [[0.9571061]]
# The prediction of the image after 1 iterations of BIM attack: 0.999998
# No_DR(1205).png
# 158
# The prediction of the image before attack:  [[0.13221613]]
# The prediction of the image after 2 iterations of BIM attack: 0.997799
# No_DR(1206).png
# 159
# The prediction of the image before attack:  [[0.6224208]]
# The prediction of the image after 1 iterations of BIM attack: 0.000753
# DR(552).png
# 160
# The prediction of the image before attack:  [[0.2574256]]
# The prediction of the image after 1 iterations of BIM attack: 0.999463
# No_DR(1207).png
# 161
# The prediction of the image before attack:  [[5.3238047e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999629
# No_DR(1208).png
# 162
# The prediction of the image before attack:  [[1.7388478e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(553).png
# 163
# The prediction of the image before attack:  [[0.00046021]]
# The prediction of the image after 2 iterations of BIM attack: 0.995040
# No_DR(1209).png
# 164
# The prediction of the image before attack:  [[0.00044321]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(554).png
# 165
# The prediction of the image before attack:  [[0.8282469]]
# The prediction of the image after 1 iterations of BIM attack: 0.999812
# No_DR(1210).png
# 166
# The prediction of the image before attack:  [[0.02437929]]
# The prediction of the image after 2 iterations of BIM attack: 0.996438
# No_DR(1211).png
# 167
# The prediction of the image before attack:  [[0.5951768]]
# The prediction of the image after 1 iterations of BIM attack: 0.000609
# DR(555).png
# 168
# The prediction of the image before attack:  [[0.00401406]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(556).png
# 169
# The prediction of the image before attack:  [[3.5208173e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(1212).png
# 170
# The prediction of the image before attack:  [[0.644052]]
# The prediction of the image after 1 iterations of BIM attack: 0.993695
# No_DR(1213).png
# 171
# The prediction of the image before attack:  [[5.2572952e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999933
# No_DR(1214).png
# 172
# The prediction of the image before attack:  [[0.8502883]]
# The prediction of the image after 1 iterations of BIM attack: 0.001514
# DR(557).png
# 173
# The prediction of the image before attack:  [[0.9757639]]
# The prediction of the image after 1 iterations of BIM attack: 0.999978
# No_DR(1215).png
# 174
# The prediction of the image before attack:  [[0.35244268]]
# The prediction of the image after 1 iterations of BIM attack: 0.991542
# No_DR(1216).png
# 175
# The prediction of the image before attack:  [[0.8022036]]
# The prediction of the image after 1 iterations of BIM attack: 0.999848
# No_DR(1217).png
# 176
# The prediction of the image before attack:  [[0.08085898]]
# The prediction of the image after 2 iterations of BIM attack: 0.999742
# No_DR(1218).png
# 177
# The prediction of the image before attack:  [[0.07602445]]
# The prediction of the image after 1 iterations of BIM attack: 0.000027
# DR(558).png
# 178
# The prediction of the image before attack:  [[0.0523413]]
# The prediction of the image after 1 iterations of BIM attack: 0.000071
# DR(559).png
# 179
# The prediction of the image before attack:  [[0.53924215]]
# The prediction of the image after 1 iterations of BIM attack: 0.002832
# DR(560).png
# 180
# The prediction of the image before attack:  [[0.00038719]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(561).png
# 181
# The prediction of the image before attack:  [[0.0340356]]
# The prediction of the image after 2 iterations of BIM attack: 0.998799
# No_DR(1219).png
# 182
# The prediction of the image before attack:  [[0.04642906]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1220).png
# 183
# The prediction of the image before attack:  [[0.92924917]]
# The prediction of the image after 2 iterations of BIM attack: 0.000026
# DR(562).png
# 184
# The prediction of the image before attack:  [[2.0023249e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999652
# No_DR(1221).png
# 185
# The prediction of the image before attack:  [[0.44018596]]
# The prediction of the image after 1 iterations of BIM attack: 0.999853
# No_DR(1222).png
# 186
# The prediction of the image before attack:  [[0.05402877]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(563).png
# 187
# The prediction of the image before attack:  [[0.19161919]]
# The prediction of the image after 1 iterations of BIM attack: 0.999308
# No_DR(1223).png
# 188
# The prediction of the image before attack:  [[3.5726886e-09]]
# The prediction of the image after 4 iterations of BIM attack: 0.999980
# No_DR(1224).png
# 189
# The prediction of the image before attack:  [[7.345336e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999955
# No_DR(1225).png
# 190
# The prediction of the image before attack:  [[1.7489676e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(564).png
# 191
# The prediction of the image before attack:  [[0.06118567]]
# The prediction of the image after 1 iterations of BIM attack: 0.000288
# DR(565).png
# 192
# The prediction of the image before attack:  [[6.1810056e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.998403
# No_DR(1226).png
# 193
# The prediction of the image before attack:  [[4.9366975e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(566).png
# 194
# The prediction of the image before attack:  [[0.18038169]]
# The prediction of the image after 1 iterations of BIM attack: 0.000314
# DR(567).png
# 195
# The prediction of the image before attack:  [[0.51295435]]
# The prediction of the image after 1 iterations of BIM attack: 0.001898
# DR(568).png
# 196
# The prediction of the image before attack:  [[0.5924966]]
# The prediction of the image after 1 iterations of BIM attack: 0.000050
# DR(569).png
# 197
# The prediction of the image before attack:  [[0.0585801]]
# The prediction of the image after 1 iterations of BIM attack: 0.000028
# DR(570).png
# 198
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 2 iterations of BIM attack: 0.999823
# No_DR(1227).png
# 199
# The prediction of the image before attack:  [[0.03637663]]
# The prediction of the image after 1 iterations of BIM attack: 0.000021
# DR(571).png
# 200
# The prediction of the image before attack:  [[0.82602227]]
# The prediction of the image after 1 iterations of BIM attack: 0.008435
# DR(572).png
# 201
# The prediction of the image before attack:  [[0.46801025]]
# The prediction of the image after 1 iterations of BIM attack: 0.000561
# DR(573).png
# 202
# The prediction of the image before attack:  [[0.95526206]]
# The prediction of the image after 1 iterations of BIM attack: 0.999994
# No_DR(1228).png
# 203
# The prediction of the image before attack:  [[1.357162e-10]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(574).png
# 204
# The prediction of the image before attack:  [[1.55166e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999959
# No_DR(1229).png
# 205
# The prediction of the image before attack:  [[0.00056709]]
# The prediction of the image after 3 iterations of BIM attack: 0.998934
# No_DR(1230).png
# 206
# The prediction of the image before attack:  [[0.8231158]]
# The prediction of the image after 1 iterations of BIM attack: 0.998208
# No_DR(1231).png
# 207
# The prediction of the image before attack:  [[7.546458e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999797
# No_DR(1232).png
# 208
# The prediction of the image before attack:  [[0.2549423]]
# The prediction of the image after 1 iterations of BIM attack: 0.998845
# No_DR(1233).png
# 209
# The prediction of the image before attack:  [[0.00818116]]
# The prediction of the image after 1 iterations of BIM attack: 0.000023
# DR(575).png
# 210
# The prediction of the image before attack:  [[0.0111364]]
# The prediction of the image after 2 iterations of BIM attack: 0.996633
# No_DR(1234).png
# 211
# The prediction of the image before attack:  [[0.9252692]]
# The prediction of the image after 2 iterations of BIM attack: 0.000001
# DR(576).png
# 212
# The prediction of the image before attack:  [[0.08791583]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(1235).png
# 213
# The prediction of the image before attack:  [[0.00012458]]
# The prediction of the image after 2 iterations of BIM attack: 0.997660
# No_DR(1236).png
# 214
# The prediction of the image before attack:  [[3.6641464e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999987
# No_DR(1237).png
# 215
# The prediction of the image before attack:  [[0.00427582]]
# The prediction of the image after 1 iterations of BIM attack: 0.000002
# DR(577).png
# 216
# The prediction of the image before attack:  [[0.79659384]]
# The prediction of the image after 1 iterations of BIM attack: 0.997810
# No_DR(1238).png
# 217
# The prediction of the image before attack:  [[0.02769594]]
# The prediction of the image after 1 iterations of BIM attack: 0.000002
# DR(578).png
# 218
# The prediction of the image before attack:  [[0.01079439]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(579).png
# 219
# The prediction of the image before attack:  [[0.04496685]]
# The prediction of the image after 1 iterations of BIM attack: 0.000079
# DR(580).png
# 220
# The prediction of the image before attack:  [[4.0403347e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.994359
# No_DR(1239).png
# 221
# The prediction of the image before attack:  [[1.596684e-07]]
# The prediction of the image after 3 iterations of BIM attack: 1.000000
# No_DR(1240).png
# 222
# The prediction of the image before attack:  [[0.51295435]]
# The prediction of the image after 1 iterations of BIM attack: 0.001898
# DR(581).png
# 223
# The prediction of the image before attack:  [[0.1701446]]
# The prediction of the image after 1 iterations of BIM attack: 0.000147
# DR(582).png
# 224
# The prediction of the image before attack:  [[0.00020043]]
# The prediction of the image after 3 iterations of BIM attack: 0.999718
# No_DR(1241).png
# 225
# The prediction of the image before attack:  [[2.4343742e-06]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(583).png
# 226
# The prediction of the image before attack:  [[0.12737097]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(584).png
# 227
# The prediction of the image before attack:  [[0.9436395]]
# The prediction of the image after 1 iterations of BIM attack: 1.000000
# No_DR(1242).png
# 228
# The prediction of the image before attack:  [[0.9870738]]
# The prediction of the image after 1 iterations of BIM attack: 0.999774
# No_DR(1243).png
# 229
# The prediction of the image before attack:  [[0.00021997]]
# The prediction of the image after 2 iterations of BIM attack: 0.998410
# No_DR(1244).png
# 230
# The prediction of the image before attack:  [[0.00237168]]
# The prediction of the image after 2 iterations of BIM attack: 0.999946
# No_DR(1245).png
# 231
# The prediction of the image before attack:  [[0.04380035]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1246).png
# 232
# The prediction of the image before attack:  [[0.12462782]]
# The prediction of the image after 1 iterations of BIM attack: 0.001034
# DR(585).png
# 233
# The prediction of the image before attack:  [[0.00030531]]
# The prediction of the image after 2 iterations of BIM attack: 0.999736
# No_DR(1247).png
# 234
# The prediction of the image before attack:  [[0.01196312]]
# The prediction of the image after 2 iterations of BIM attack: 0.999978
# No_DR(1248).png
# 235
# The prediction of the image before attack:  [[8.69548e-06]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(586).png
# 236
# The prediction of the image before attack:  [[0.9800371]]
# The prediction of the image after 1 iterations of BIM attack: 0.999988
# No_DR(1249).png
# 237
# The prediction of the image before attack:  [[9.8534194e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999981
# No_DR(1250).png
# 238
# The prediction of the image before attack:  [[0.00038507]]
# The prediction of the image after 2 iterations of BIM attack: 0.997800
# No_DR(1251).png
# 239
# The prediction of the image before attack:  [[0.99462056]]
# The prediction of the image after 1 iterations of BIM attack: 1.000000
# No_DR(1252).png
# 240
# The prediction of the image before attack:  [[8.171725e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(587).png
# 241
# The prediction of the image before attack:  [[3.8281373e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.998609
# No_DR(1253).png
# 242
# The prediction of the image before attack:  [[1.5924453e-08]]
# The prediction of the image after 4 iterations of BIM attack: 0.999897
# No_DR(1254).png
# 243
# The prediction of the image before attack:  [[0.01064173]]
# The prediction of the image after 2 iterations of BIM attack: 0.998674
# No_DR(1255).png
# 244
# The prediction of the image before attack:  [[0.91801476]]
# The prediction of the image after 1 iterations of BIM attack: 0.999435
# No_DR(1256).png
# 245
# The prediction of the image before attack:  [[0.77233565]]
# The prediction of the image after 1 iterations of BIM attack: 0.999996
# No_DR(1257).png
# 246
# The prediction of the image before attack:  [[0.00029679]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(588).png
# 247
# The prediction of the image before attack:  [[1.220644e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999932
# No_DR(1258).png
# 248
# The prediction of the image before attack:  [[6.602297e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999796
# No_DR(1259).png
# 249
# The prediction of the image before attack:  [[0.00246892]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(589).png
# 250
# The prediction of the image before attack:  [[6.7619467e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999488
# No_DR(1260).png
# 251
# The prediction of the image before attack:  [[6.36641e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999525
# No_DR(1261).png
# 252
# The prediction of the image before attack:  [[0.00736253]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1262).png
# 253
# The prediction of the image before attack:  [[0.02114774]]
# The prediction of the image after 2 iterations of BIM attack: 0.999801
# No_DR(1263).png
# 254
# The prediction of the image before attack:  [[5.8333414e-11]]
# The prediction of the image after 4 iterations of BIM attack: 0.992434
# No_DR(1264).png
# 255
# The prediction of the image before attack:  [[0.10088927]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1265).png
# 256
# The prediction of the image before attack:  [[1.570678e-08]]
# The prediction of the image after 3 iterations of BIM attack: 0.999944
# No_DR(1266).png
# 257
# The prediction of the image before attack:  [[0.00154332]]
# The prediction of the image after 1 iterations of BIM attack: 0.000003
# DR(590).png
# 258
# The prediction of the image before attack:  [[0.00053785]]
# The prediction of the image after 2 iterations of BIM attack: 0.999790
# No_DR(1267).png
# 259
# The prediction of the image before attack:  [[0.00545474]]
# The prediction of the image after 2 iterations of BIM attack: 0.999777
# No_DR(1268).png
# 260
# The prediction of the image before attack:  [[0.12402992]]
# The prediction of the image after 1 iterations of BIM attack: 0.000006
# DR(591).png
# 261
# The prediction of the image before attack:  [[0.00020808]]
# The prediction of the image after 2 iterations of BIM attack: 0.999794
# No_DR(1269).png
# 262
# The prediction of the image before attack:  [[0.00941937]]
# The prediction of the image after 2 iterations of BIM attack: 0.999950
# No_DR(1270).png
# 263
# The prediction of the image before attack:  [[0.9252692]]
# The prediction of the image after 2 iterations of BIM attack: 0.000001
# DR(592).png
# 264
# The prediction of the image before attack:  [[0.9973008]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(593).png
# 265
# The prediction of the image before attack:  [[0.01052546]]
# The prediction of the image after 1 iterations of BIM attack: 0.000021
# DR(594).png
# 266
# The prediction of the image before attack:  [[0.00046271]]
# The prediction of the image after 3 iterations of BIM attack: 0.999800
# No_DR(1271).png
# 267
# The prediction of the image before attack:  [[0.04496685]]
# The prediction of the image after 1 iterations of BIM attack: 0.000079
# DR(595).png
# 268
# The prediction of the image before attack:  [[0.05134135]]
# The prediction of the image after 2 iterations of BIM attack: 0.999994
# No_DR(1272).png
# 269
# The prediction of the image before attack:  [[0.74848044]]
# The prediction of the image after 1 iterations of BIM attack: 0.999986
# No_DR(1273).png
# 270
# The prediction of the image before attack:  [[0.08380187]]
# The prediction of the image after 2 iterations of BIM attack: 0.999773
# No_DR(1274).png
# 271
# The prediction of the image before attack:  [[0.02085015]]
# The prediction of the image after 2 iterations of BIM attack: 0.999889
# No_DR(1275).png
# 272
# The prediction of the image before attack:  [[0.8234446]]
# The prediction of the image after 1 iterations of BIM attack: 0.027260
# DR(596).png
# 273
# The prediction of the image before attack:  [[0.00435024]]
# The prediction of the image after 2 iterations of BIM attack: 0.998552
# No_DR(1276).png
# 274
# The prediction of the image before attack:  [[0.5951768]]
# The prediction of the image after 1 iterations of BIM attack: 0.000609
# DR(597).png
# 275
# The prediction of the image before attack:  [[2.704636e-07]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(1277).png
# 276
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 2 iterations of BIM attack: 0.998146
# No_DR(1278).png
# 277
# The prediction of the image before attack:  [[0.4075514]]
# The prediction of the image after 1 iterations of BIM attack: 0.000922
# DR(598).png
# 278
# The prediction of the image before attack:  [[0.8890437]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(599).png
# 279
# The prediction of the image before attack:  [[0.00058558]]
# The prediction of the image after 2 iterations of BIM attack: 0.999990
# No_DR(1279).png
# 280
# The prediction of the image before attack:  [[0.95366025]]
# The prediction of the image after 2 iterations of BIM attack: 0.000007
# DR(600).png
# 281
# The prediction of the image before attack:  [[0.00034569]]
# The prediction of the image after 2 iterations of BIM attack: 0.993538
# No_DR(1280).png
# 282
# The prediction of the image before attack:  [[0.00759683]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(601).png
# 283
# The prediction of the image before attack:  [[0.00297441]]
# The prediction of the image after 2 iterations of BIM attack: 0.998146
# No_DR(1281).png
# 284
# The prediction of the image before attack:  [[0.179843]]
# The prediction of the image after 1 iterations of BIM attack: 0.000187
# DR(602).png
# 285
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 1 iterations of BIM attack: 0.999831
# No_DR(1282).png
# 286
# The prediction of the image before attack:  [[0.2433236]]
# The prediction of the image after 1 iterations of BIM attack: 0.000080
# DR(603).png
# 287
# The prediction of the image before attack:  [[0.00124568]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(604).png
# 288
# The prediction of the image before attack:  [[1.1999263e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999997
# No_DR(1283).png
# 289
# The prediction of the image before attack:  [[0.9860833]]
# The prediction of the image after 1 iterations of BIM attack: 0.999891
# No_DR(1284).png
# 290
# The prediction of the image before attack:  [[3.710513e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(605).png
# 291
# The prediction of the image before attack:  [[0.00040979]]
# The prediction of the image after 2 iterations of BIM attack: 0.996362
# No_DR(1285).png
# 292
# The prediction of the image before attack:  [[0.12096673]]
# The prediction of the image after 1 iterations of BIM attack: 0.000019
# DR(606).png
# 293
# The prediction of the image before attack:  [[0.7567029]]
# The prediction of the image after 1 iterations of BIM attack: 0.999613
# No_DR(1286).png
# 294
# The prediction of the image before attack:  [[0.48785657]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(607).png
# 295
# The prediction of the image before attack:  [[0.01021944]]
# The prediction of the image after 2 iterations of BIM attack: 0.999807
# No_DR(1287).png
# 296
# The prediction of the image before attack:  [[0.00333084]]
# The prediction of the image after 2 iterations of BIM attack: 0.999984
# No_DR(1288).png
# 297
# The prediction of the image before attack:  [[0.14624096]]
# The prediction of the image after 1 iterations of BIM attack: 0.998752
# No_DR(1289).png
# 298
# The prediction of the image before attack:  [[0.00317826]]
# The prediction of the image after 2 iterations of BIM attack: 0.999739
# No_DR(1290).png
# 299
# The prediction of the image before attack:  [[0.98851585]]
# The prediction of the image after 1 iterations of BIM attack: 0.999982
# No_DR(1291).png
# 300
# The prediction of the image before attack:  [[0.4861517]]
# The prediction of the image after 1 iterations of BIM attack: 0.000414
# DR(608).png
# 301
# The prediction of the image before attack:  [[0.9657152]]
# The prediction of the image after 1 iterations of BIM attack: 0.999869
# No_DR(1292).png
# 302
# The prediction of the image before attack:  [[0.929262]]
# The prediction of the image after 2 iterations of BIM attack: 0.000001
# DR(609).png
# 303
# The prediction of the image before attack:  [[5.2320927e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(610).png
# 304
# The prediction of the image before attack:  [[0.03564567]]
# The prediction of the image after 2 iterations of BIM attack: 0.999503
# No_DR(1293).png
# 305
# The prediction of the image before attack:  [[0.02384421]]
# The prediction of the image after 1 iterations of BIM attack: 0.000083
# DR(611).png
# 306
# The prediction of the image before attack:  [[0.00550233]]
# The prediction of the image after 2 iterations of BIM attack: 0.994736
# No_DR(1294).png
# 307
# The prediction of the image before attack:  [[0.00033384]]
# The prediction of the image after 2 iterations of BIM attack: 0.994210
# No_DR(1295).png
# 308
# The prediction of the image before attack:  [[6.7619467e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999488
# No_DR(1296).png
# 309
# The prediction of the image before attack:  [[0.00061567]]
# The prediction of the image after 3 iterations of BIM attack: 0.999765
# No_DR(1297).png
# 310
# The prediction of the image before attack:  [[0.01271204]]
# The prediction of the image after 2 iterations of BIM attack: 0.999963
# No_DR(1298).png
# 311
# The prediction of the image before attack:  [[0.89479744]]
# The prediction of the image after 1 iterations of BIM attack: 0.999686
# No_DR(1299).png
# 312
# The prediction of the image before attack:  [[0.52247]]
# The prediction of the image after 1 iterations of BIM attack: 0.997760
# No_DR(1300).png
# 313
# The prediction of the image before attack:  [[0.5385056]]
# The prediction of the image after 1 iterations of BIM attack: 0.999976
# No_DR(1301).png
# 314
# The prediction of the image before attack:  [[0.01466926]]
# The prediction of the image after 1 iterations of BIM attack: 0.000035
# DR(612).png
# 315
# The prediction of the image before attack:  [[0.00053785]]
# The prediction of the image after 2 iterations of BIM attack: 0.999790
# No_DR(1302).png
# 316
# The prediction of the image before attack:  [[0.00040979]]
# The prediction of the image after 2 iterations of BIM attack: 0.996362
# No_DR(1303).png
# 317
# The prediction of the image before attack:  [[9.441308e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(613).png
# 318
# The prediction of the image before attack:  [[2.9432851e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(614).png
# 319
# The prediction of the image before attack:  [[0.99919766]]
# The prediction of the image after 1 iterations of BIM attack: 0.999995
# No_DR(1304).png
# 320
# The prediction of the image before attack:  [[1.7489676e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(615).png
# 321
# The prediction of the image before attack:  [[0.03836177]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(1305).png
# 322
# The prediction of the image before attack:  [[0.00080311]]
# The prediction of the image after 2 iterations of BIM attack: 0.981686
# No_DR(1306).png
# 323
# The prediction of the image before attack:  [[4.925735e-06]]
# The prediction of the image after 2 iterations of BIM attack: 0.999892
# No_DR(1307).png
# 324
# The prediction of the image before attack:  [[0.00060145]]
# The prediction of the image after 2 iterations of BIM attack: 0.991418
# No_DR(1308).png
# 325
# The prediction of the image before attack:  [[1.4786311e-08]]
# The prediction of the image after 4 iterations of BIM attack: 0.999885
# No_DR(1309).png
# 326
# The prediction of the image before attack:  [[0.01346724]]
# The prediction of the image after 2 iterations of BIM attack: 0.999961
# No_DR(1310).png
# 327
# The prediction of the image before attack:  [[0.00201166]]
# The prediction of the image after 2 iterations of BIM attack: 0.999766
# No_DR(1311).png
# 328
# The prediction of the image before attack:  [[0.00131614]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(616).png
# 329
# The prediction of the image before attack:  [[0.6392199]]
# The prediction of the image after 1 iterations of BIM attack: 0.000067
# DR(617).png
# 330
# The prediction of the image before attack:  [[0.00550233]]
# The prediction of the image after 2 iterations of BIM attack: 0.994736
# No_DR(1312).png
# 331
# The prediction of the image before attack:  [[7.345336e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999955
# No_DR(1313).png
# 332
# The prediction of the image before attack:  [[4.9967824e-17]]
# The prediction of the image after 4 iterations of BIM attack: 0.999998
# No_DR(1314).png
# 333
# The prediction of the image before attack:  [[0.7265784]]
# The prediction of the image after 1 iterations of BIM attack: 0.999909
# No_DR(1315).png
# 334
# The prediction of the image before attack:  [[4.6109665e-07]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(618).png
# 335
# The prediction of the image before attack:  [[0.00030149]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(619).png
# 336
# The prediction of the image before attack:  [[0.7836448]]
# The prediction of the image after 1 iterations of BIM attack: 0.009530
# DR(620).png
# 337
# The prediction of the image before attack:  [[0.6902253]]
# The prediction of the image after 1 iterations of BIM attack: 0.001842
# DR(621).png
# 338
# The prediction of the image before attack:  [[4.2945603e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999787
# No_DR(1316).png
# 339
# The prediction of the image before attack:  [[0.9770982]]
# The prediction of the image after 1 iterations of BIM attack: 0.999831
# No_DR(1317).png
# 340
# The prediction of the image before attack:  [[0.00548888]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(622).png
# 341
# The prediction of the image before attack:  [[0.29678828]]
# The prediction of the image after 1 iterations of BIM attack: 0.998232
# No_DR(1318).png
# 342
# The prediction of the image before attack:  [[0.00014488]]
# The prediction of the image after 3 iterations of BIM attack: 0.999568
# No_DR(1319).png
# 343
# The prediction of the image before attack:  [[3.7018464e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.993338
# No_DR(1320).png
# 344
# The prediction of the image before attack:  [[0.66341436]]
# The prediction of the image after 1 iterations of BIM attack: 0.999024
# No_DR(1321).png
# 345
# The prediction of the image before attack:  [[4.8167774e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.998265
# No_DR(1322).png
# 346
# The prediction of the image before attack:  [[0.53757423]]
# The prediction of the image after 1 iterations of BIM attack: 0.004416
# DR(623).png
# 347
# The prediction of the image before attack:  [[0.00183374]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(624).png
# 348
# The prediction of the image before attack:  [[6.342159e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999816
# No_DR(1323).png
# 349
# The prediction of the image before attack:  [[6.848939e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999446
# No_DR(1324).png
# 350
# The prediction of the image before attack:  [[0.00011226]]
# The prediction of the image after 3 iterations of BIM attack: 0.999925
# No_DR(1325).png
# 351
# The prediction of the image before attack:  [[0.01103881]]
# The prediction of the image after 2 iterations of BIM attack: 0.999916
# No_DR(1326).png
# 352
# The prediction of the image before attack:  [[0.53672755]]
# The prediction of the image after 1 iterations of BIM attack: 0.001487
# DR(625).png
# 353
# The prediction of the image before attack:  [[0.05108991]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1327).png
# 354
# The prediction of the image before attack:  [[0.82602227]]
# The prediction of the image after 1 iterations of BIM attack: 0.008435
# DR(626).png
# 355
# The prediction of the image before attack:  [[0.21740328]]
# The prediction of the image after 1 iterations of BIM attack: 0.953955
# No_DR(1328).png
# 356
# The prediction of the image before attack:  [[1.3315479e-06]]
# The prediction of the image after 3 iterations of BIM attack: 0.999994
# No_DR(1329).png
# 357
# The prediction of the image before attack:  [[0.00119437]]
# The prediction of the image after 2 iterations of BIM attack: 0.999823
# No_DR(1330).png
# 358
# The prediction of the image before attack:  [[0.92571294]]
# The prediction of the image after 1 iterations of BIM attack: 0.999999
# No_DR(1331).png
# 359
# The prediction of the image before attack:  [[0.01001649]]
# The prediction of the image after 2 iterations of BIM attack: 0.999988
# No_DR(1332).png
# 360
# The prediction of the image before attack:  [[4.6163215e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999480
# No_DR(1333).png
# 361
# The prediction of the image before attack:  [[0.02906004]]
# The prediction of the image after 2 iterations of BIM attack: 0.999995
# No_DR(1334).png
# 362
# The prediction of the image before attack:  [[2.8639932e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999444
# No_DR(1335).png
# 363
# The prediction of the image before attack:  [[0.00054949]]
# The prediction of the image after 3 iterations of BIM attack: 0.999203
# No_DR(1336).png
# 364
# The prediction of the image before attack:  [[0.0005608]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(627).png
# 365
# The prediction of the image before attack:  [[0.84532005]]
# The prediction of the image after 1 iterations of BIM attack: 0.999968
# No_DR(1337).png
# 366
# The prediction of the image before attack:  [[0.08085898]]
# The prediction of the image after 2 iterations of BIM attack: 0.999742
# No_DR(1338).png
# 367
# The prediction of the image before attack:  [[0.9743114]]
# The prediction of the image after 2 iterations of BIM attack: 0.000000
# DR(628).png
# 368
# The prediction of the image before attack:  [[0.15997481]]
# The prediction of the image after 1 iterations of BIM attack: 0.000014
# DR(629).png
# 369
# The prediction of the image before attack:  [[0.21155718]]
# The prediction of the image after 1 iterations of BIM attack: 0.000026
# DR(630).png
# 370
# The prediction of the image before attack:  [[5.3238047e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999629
# No_DR(1339).png
# 371
# The prediction of the image before attack:  [[0.00045463]]
# The prediction of the image after 2 iterations of BIM attack: 0.999504
# No_DR(1340).png
# 372
# The prediction of the image before attack:  [[0.10088927]]
# The prediction of the image after 2 iterations of BIM attack: 0.999999
# No_DR(1341).png
# 373
# The prediction of the image before attack:  [[0.0006958]]
# The prediction of the image after 2 iterations of BIM attack: 0.995525
# No_DR(1342).png
# 374
# The prediction of the image before attack:  [[1.9982024e-10]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(631).png
# 375
# The prediction of the image before attack:  [[0.00325594]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(632).png
# 376
# The prediction of the image before attack:  [[1.9497136e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.996876
# No_DR(1343).png
# 377
# The prediction of the image before attack:  [[0.21893604]]
# The prediction of the image after 1 iterations of BIM attack: 0.001355
# DR(633).png
# 378
# The prediction of the image before attack:  [[0.00906687]]
# The prediction of the image after 1 iterations of BIM attack: 0.000001
# DR(634).png
# 379
# The prediction of the image before attack:  [[0.6685875]]
# The prediction of the image after 1 iterations of BIM attack: 0.000730
# DR(635).png
# 380
# The prediction of the image before attack:  [[2.3138304e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(636).png
# 381
# The prediction of the image before attack:  [[0.29678828]]
# The prediction of the image after 1 iterations of BIM attack: 0.998232
# No_DR(1344).png
# 382
# The prediction of the image before attack:  [[0.10651375]]
# The prediction of the image after 1 iterations of BIM attack: 0.000079
# DR(637).png
# 383
# The prediction of the image before attack:  [[0.00011226]]
# The prediction of the image after 3 iterations of BIM attack: 0.999925
# No_DR(1345).png
# 384
# The prediction of the image before attack:  [[0.0189086]]
# The prediction of the image after 2 iterations of BIM attack: 0.999678
# No_DR(1346).png
# 385
# The prediction of the image before attack:  [[3.3532307e-12]]
# The prediction of the image after 4 iterations of BIM attack: 0.999696
# No_DR(1347).png
# 386
# The prediction of the image before attack:  [[0.98308635]]
# The prediction of the image after 1 iterations of BIM attack: 0.999997
# No_DR(1348).png
# 387
# The prediction of the image before attack:  [[6.800973e-05]]
# The prediction of the image after 2 iterations of BIM attack: 0.999629
# No_DR(1349).png
# 388
# The prediction of the image before attack:  [[0.9436395]]
# The prediction of the image after 1 iterations of BIM attack: 1.000000
# No_DR(1350).png
# 389
# The prediction of the image before attack:  [[1.9476756e-09]]
# The prediction of the image after 3 iterations of BIM attack: 0.999997
# No_DR(1351).png
# 390
# The prediction of the image before attack:  [[0.03841821]]
# The prediction of the image after 2 iterations of BIM attack: 0.999859
# No_DR(1352).png
# 391
# The prediction of the image before attack:  [[0.73098165]]
# The prediction of the image after 1 iterations of BIM attack: 0.000081
# DR(638).png
# 392
# The prediction of the image before attack:  [[0.01365414]]
# The prediction of the image after 2 iterations of BIM attack: 0.999976
# No_DR(1353).png
# 393
# The prediction of the image before attack:  [[0.00324749]]
# The prediction of the image after 2 iterations of BIM attack: 0.999993
# No_DR(1354).png
# 394
# The prediction of the image before attack:  [[3.6641464e-05]]
# The prediction of the image after 3 iterations of BIM attack: 0.999987
# No_DR(1355).png
# 395
# The prediction of the image before attack:  [[0.03841821]]
# The prediction of the image after 2 iterations of BIM attack: 0.999859
# No_DR(1356).png
# 396
# The prediction of the image before attack:  [[2.6700036e-05]]
# The prediction of the image after 1 iterations of BIM attack: 0.000000
# DR(639).png
# 397
# The prediction of the image before attack:  [[0.0010892]]
# The prediction of the image after 2 iterations of BIM attack: 0.997143
# No_DR(1357).png
# 398
# The prediction of the image before attack:  [[0.9774889]]
# The prediction of the image after 1 iterations of BIM attack: 0.999922
# No_DR(1358).png
# 399
# The prediction of the image before attack:  [[0.06923233]]
# The prediction of the image after 2 iterations of BIM attack: 1.000000
# No_DR(1359).png

# %%
# !zip -r ./BIM_BBA_perturbed_img.zip ./BIM_BBA_perturbed_img/
# Out:
#   adding: BIM_BBA_perturbed_img/ (stored 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/ (stored 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(877).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(744).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(762).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(255).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1184).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1089).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(986).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(771).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(187).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1317).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1335).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(43).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(503).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(607).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(221).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1310).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(816).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(566).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(81).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(458).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1180).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(584).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(401).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(501).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(822).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(215).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(635).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(625).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(415).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1271).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(229).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(968).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(917).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(497).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1352).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(847).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(971).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1080).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(652).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1010).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1288).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(631).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(141).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(15).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(946).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1275).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1131).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(386).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(593).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(751).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1253).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1149).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(321).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1121).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(75).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(929).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(350).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(537).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1111).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1000).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(972).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(667).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(235).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(421).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(585).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(175).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(117).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(549).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(901).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(236).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(538).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(428).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(297).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(278).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(721).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(925).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(628).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(247).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(193).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(831).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(591).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(129).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(101).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(736).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1319).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(621).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(69).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(163).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(717).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(260).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(722).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(760).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(668).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(797).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(325).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(480).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1103).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(478).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1177).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1068).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(367).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1345).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(598).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(893).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1126).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(846).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(711).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1129).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(127).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(300).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1203).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1192).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(230).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(700).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(395).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(337).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(863).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(531).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(605).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1301).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(257).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(248).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1125).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1339).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(676).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(976).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(586).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(124).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(220).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1017).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(708).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(524).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(918).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(482).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(32).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(326).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1279).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(56).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1226).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(332).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(552).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(769).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(733).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1065).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(418).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(882).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(859).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1015).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(900).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(681).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(806).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(137).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1082).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(21).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(942).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(172).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(494).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(474).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1236).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(992).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1072).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(178).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1004).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1053).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(836).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1085).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1096).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(873).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1115).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1038).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(515).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1354).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(116).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(216).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(437).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1295).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(961).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(119).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1167).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(897).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(830).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(923).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(252).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(381).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(370).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(739).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(439).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(289).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(77).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1029).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1155).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(490).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(256).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1331).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(686).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(48).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(205).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(956).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(324).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1048).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(813).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1257).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1308).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(90).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(930).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(843).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(965).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1171).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(815).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(679).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(957).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(445).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(140).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(134).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(895).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(978).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(347).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1195).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(113).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1277).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(214).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(135).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(99).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(451).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(648).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(24).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(629).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(886).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1193).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(10).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(298).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1255).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(606).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1333).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(273).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(639).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1124).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(442).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(753).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1248).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1220).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(11).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(899).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1107).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(176).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(713).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(434).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1084).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(453).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1160).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1294).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(600).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1289).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(123).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(131).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(693).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(82).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(267).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(544).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(790).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(59).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(517).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(496).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(943).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(903).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1305).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1323).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(73).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1260).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1217).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(459).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(661).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(498).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(670).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(817).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(808).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(758).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(292).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(492).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(142).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1040).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1134).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(532).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1297).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(866).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(810).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1187).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(952).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(703).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(384).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1216).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(807).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(97).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(902).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1311).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(546).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1256).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(353).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(838).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1135).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(339).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(385).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(850).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(587).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(725).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(44).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(518).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(440).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(291).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(95).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(203).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1249).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(592).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(924).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1258).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(196).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(951).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(157).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(856).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(128).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1097).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(697).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1190).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1003).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1232).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(112).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1178).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(609).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(551).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1321).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(485).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(735).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(637).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1174).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(387).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(921).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(47).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1268).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(166).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1329).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(564).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(469).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(618).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(105).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(540).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1119).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(655).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(186).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(928).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1280).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(31).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(183).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1175).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1233).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(25).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1170).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1290).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(14).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(905).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(208).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(334).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(536).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1066).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1313).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(691).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1099).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(824).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1026).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1070).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1067).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1208).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(349).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(694).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(766).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1318).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(132).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(819).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(100).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(879).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(197).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1008).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1198).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(476).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1211).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(765).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1296).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1241).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1348).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(167).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(638).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(932).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(57).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(20).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1137).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(369).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(338).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(559).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(288).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1179).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(46).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(767).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(284).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(184).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(669).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(407).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(519).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(317).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(164).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(774).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(608).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(915).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(110).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(448).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(223).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1344).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(872).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(340).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1229).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(941).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(226).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(973).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1218).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(975).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(463).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(878).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1019).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(805).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1110).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(589).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(104).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1357).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(755).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1214).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1043).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(327).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1183).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(199).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1123).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(242).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1342).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(645).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(138).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1186).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1005).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1158).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(997).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(657).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(835).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1035).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(898).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1127).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(696).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(673).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(582).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1130).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(202).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(438).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1139).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(118).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(38).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1246).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(779).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(720).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(715).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(405).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(227).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(171).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(341).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(456).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1133).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(821).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(931).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1022).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1191).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(801).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(642).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1270).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1059).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1200).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(237).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(177).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(27).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(832).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(663).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(219).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1006).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(301).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(471).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(460).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(74).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(309).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(89).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(330).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(170).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1244).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(535).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(756).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1338).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(447).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(441).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(429).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(683).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1299).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(192).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(523).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(662).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1215).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(419).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(358).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(446).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(426).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(238).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(966).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(699).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(8).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(841).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(318).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1324).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1128).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(9).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1118).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1136).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(98).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1027).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1343).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(464).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(834).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(0).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(704).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(121).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(161).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(680).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1138).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1036).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(916).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(770).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(788).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(234).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(45).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(632).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(303).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(403).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(783).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(716).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(261).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(246).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1146).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(107).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1024).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(106).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(351).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1239).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(262).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(844).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(400).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(849).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1039).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(516).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(754).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1182).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(281).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(435).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(87).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1064).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1281).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(643).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1013).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(883).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(19).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(417).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(2).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(800).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(880).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(998).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1145).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(23).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1050).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(550).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(144).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(355).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(602).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1112).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1197).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(151).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1052).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(475).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(63).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(85).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(969).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1162).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(541).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(967).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(936).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(315).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(554).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(571).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1114).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(290).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1243).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(375).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(26).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(947).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(502).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(148).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(964).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1014).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1108).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(804).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(934).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(266).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(251).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1189).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1227).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(329).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(889).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(864).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(620).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1020).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(511).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1156).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1221).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(553).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(672).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(319).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1341).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(617).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(397).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1164).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1231).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(231).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1353).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(465).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1153).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(354).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(989).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1141).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(892).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1032).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(780).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(509).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1057).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(979).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1266).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1116).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1091).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(650).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1304).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(802).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(91).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(200).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1041).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(65).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(174).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(40).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(357).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(212).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(3).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(823).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(484).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(500).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(457).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(922).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(312).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(706).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1303).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(198).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(768).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(854).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(254).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(114).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(644).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(30).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(787).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(356).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1350).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(323).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(542).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(422).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1325).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(687).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(876).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1147).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1078).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(240).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(955).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1025).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(688).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(919).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1196).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(191).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(912).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1316).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1291).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(37).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(695).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(894).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(316).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(259).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(103).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1169).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1230).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1261).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(7).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(959).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(506).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(743).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(489).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(993).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(548).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(1092).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(614).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/No_DR/No_DR(839).png (deflated 0%)
# ...
#   adding: BIM_BBA_perturbed_img/DR/DR(442).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(538).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(38).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(537).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(406).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(264).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(283).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(365).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(222).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(601).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(532).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(397).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(95).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(269).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(575).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(637).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(46).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(583).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(178).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(412).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(337).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(369).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(425).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(510).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(371).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(276).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(341).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(570).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(40).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(300).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(496).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(91).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(534).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(213).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(126).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(557).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(98).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(140).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(501).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(166).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(174).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(433).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(576).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(388).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(125).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(410).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(32).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(539).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(133).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(244).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(638).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(480).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(542).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(378).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(88).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(191).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(407).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(183).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(295).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(195).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(132).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(620).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(574).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(228).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(408).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(185).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(405).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(614).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(324).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(138).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(156).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(634).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(242).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(267).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(391).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(59).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(52).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(515).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(221).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(451).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(85).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(590).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(453).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(231).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(218).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(220).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(627).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(62).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(117).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(420).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(560).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(193).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(273).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(172).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(431).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(335).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(219).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(553).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(289).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(275).png (deflated 1%)
#   adding: BIM_BBA_perturbed_img/DR/DR(291).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(1).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(217).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(404).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(89).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(438).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(625).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(623).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(582).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(15).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(163).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(224).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(591).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(536).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(411).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(141).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(173).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(487).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(44).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(535).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(343).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(207).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(92).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(304).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(247).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(31).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(7).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(473).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(68).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(615).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(479).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(144).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(293).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(63).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(632).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(455).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(251).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(135).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(201).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(103).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(84).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(155).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(443).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(355).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(558).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(610).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(26).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(302).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(429).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(223).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(296).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(445).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(594).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(461).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(294).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(277).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(611).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(579).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(549).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(506).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(154).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(130).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(351).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(633).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(561).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(500).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(556).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(131).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(446).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(392).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(108).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(64).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(209).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(454).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(317).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(518).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(13).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(194).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(152).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(33).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(528).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(171).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(624).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(566).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(17).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(34).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(421).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(416).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(106).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(182).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(192).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(279).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(345).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(45).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(203).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(413).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(346).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(123).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(226).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(551).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(30).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(423).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(370).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(339).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(23).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(418).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(107).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(197).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(639).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(246).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(426).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(448).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(327).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(401).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(353).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(363).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(486).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(546).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(188).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(176).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(373).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(564).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(96).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(104).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(129).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(24).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(61).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(476).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(190).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(490).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(595).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(180).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(386).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(586).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(280).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(514).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(315).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(358).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(70).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(488).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(99).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(399).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(187).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(147).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(58).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(109).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(587).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(262).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(419).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(110).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(396).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(394).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(626).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(550).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(631).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(305).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(439).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(568).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(322).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(543).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(357).png (deflated 0%)
#   adding: BIM_BBA_perturbed_img/DR/DR(607).png (deflated 0%)

# %%
# !cp BIM_BBA_perturbed_img.zip 'drive/MyDrive/eye_pacs/Perturbed_images/BIM_BBA_perturbed_img.zip'
# Out:
# cp: cannot create regular file 'drive/MyDrive/eye_pacs/Perturbed_images/BIM_BBA_perturbed_img.zip': No such file or directory

# %% [markdown]
# # Faulty Prediction (BIM)

# %%
# !cp 'drive/MyDrive/eye_pacs/Perturbed_images/BIM_BBA_perturbed_img.zip' BIM_BBA_perturbed_img.zip
# Out:
# cp: cannot stat 'drive/MyDrive/eye_pacs/Perturbed_images/BIM_BBA_perturbed_img.zip': No such file or directory

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "BIM_BBA_perturbed_img.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    #zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %%
import cv2

dr_img = []
for data in os.listdir('BIM_BBA_perturbed_img/DR'):
        img_d = cv2.imread('BIM_BBA_perturbed_img/DR/{}'.format(data))
        dr_img.append(img_d)

        
no_dr_img = []        
for data in os.listdir('BIM_BBA_perturbed_img/No_DR'):
        img_d = cv2.imread('BIM_BBA_perturbed_img/No_DR/{}'.format(data))        
        no_dr_img.append(img_d)

# %%
dr_img = np.array(dr_img)
dr_pred_0 = model.predict(dr_img)

# %%
dr_img_pred_int = []
for i in dr_pred_0:
  if i < 0.5:
    dr_img_pred_int.append(0)
  else:
    dr_img_pred_int.append(1)

# %%
dr_img_pred_int = np.array(dr_img_pred_int)
no_zero = (dr_img_pred_int ==0).sum()
no_one = (dr_img_pred_int==1).sum()
print("Total no. of DR images = ", dr_pred_0.size)
print("Predicted as No DR = ",no_zero)
print("Predicted as DR = ", no_one)

plt.title('BBA - PGD perturbed images of DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.bar(["no_dr", "dr"], [no_zero, no_one] , color=["red", "green"])
plt.show()
# Out:
# Total no. of DR images =  640
# Predicted as No DR =  530
# Predicted as DR =  110

# %%
plt.title('BBA - BIM perturbed images of DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.hist(dr_pred_0.astype('float'))
plt.show()

# %%
no_dr_img = np.array(no_dr_img)
no_dr0_pred = model.predict(no_dr_img)

# %%
no_dr_img_pred_int = []
for i in no_dr0_pred:
  if i < 0.5:
    no_dr_img_pred_int.append(0)
  else:
    no_dr_img_pred_int.append(1)

# %%
no_dr_img_pred_int = np.array(no_dr_img_pred_int)
no_zero = (no_dr_img_pred_int ==0).sum()
no_one = (no_dr_img_pred_int==1).sum()
print("Total no. of No DR images = ", no_dr0_pred.size)
print("Predicted as No DR = ",no_zero)
print("Predicted as DR = ", no_one)


plt.title('BBA - PGD perturbed images of No DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.bar(["no_dr", "dr"], [no_zero, no_one] , color=["red", "green"])
plt.show()
# Out:
# Total no. of No DR images =  1360
# Predicted as No DR =  983
# Predicted as DR =  377

# %%
plt.title('BBA=BIM perturbed images of No_DR')
plt.ylabel('No. of images')
plt.xlabel('Prediction value')
plt.hist(no_dr0_pred.astype('float'))
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = []
y_pred = []
for i in dr_img_pred_int:
  y_pred.append(i)
  y_true.append(1)

for i in no_dr_img_pred_int:
  y_pred.append(i)
  y_true.append(0)

cnf = confusion_matrix(y_true, y_pred)
cnf
disp = ConfusionMatrixDisplay(cnf,display_labels=["no_dr", "dr"])
disp.plot()
